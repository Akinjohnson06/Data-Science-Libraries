# %%
# Pandas is built on numpy

import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Desktop\Libray Series\Pandas\survey_results_public.csv")

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                          Web development or web design  ...
# 3      Computer science, computer engineering, or sof...  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
# shape gives you the total rows and column
df.shape
# Out:
# (88883, 85)

# %%
# info() gives number of rows, column, and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
#  14  Age1stCode              87634 non-null  object
#  15  YearsCodePro            74331 non-null  object
#  16  CareerSat               72847 non-null  object
#  17  JobSat                  70988 non-null  object
#  18  MgrIdiot                61159 non-null  object
#  19  MgrMoney                61157 non-null  object
#  20  MgrWant                 61232 non-null  object
#  21  JobSeek                 80555 non-null  object
#  22  LastHireDate            79854 non-null  object
#  23  LastInt                 67155 non-null  object
#  24  FizzBuzz                71344 non-null  object
#  25  JobFactors              79371 non-null  object
#  26  ResumeUpdate            77877 non-null  object
#  27  CurrencySymbol          71392 non-null  object
#  28  CurrencyDesc            71392 non-null  object
#  29  CompTotal               55945 non-null  float64
#  30  CompFreq                63268 non-null  object
#  31  ConvertedComp           55823 non-null  float64
#  32  WorkWeekHrs             64503 non-null  float64
#  33  WorkPlan                68914 non-null  object
#  34  WorkChallenge           68141 non-null  object
#  35  WorkRemote              70284 non-null  object
#  36  WorkLoc                 70055 non-null  object
#  37  ImpSyn                  71779 non-null  object
#  38  CodeRev                 70390 non-null  object
#  39  CodeRevHrs              49790 non-null  float64
#  40  UnitTests               62668 non-null  object
#  41  PurchaseHow             61108 non-null  object
#  42  PurchaseWhat            62029 non-null  object
#  43  LanguageWorkedWith      87569 non-null  object
#  44  LanguageDesireNextYear  84088 non-null  object
#  45  DatabaseWorkedWith      76026 non-null  object
#  46  DatabaseDesireNextYear  69147 non-null  object
#  47  PlatformWorkedWith      80714 non-null  object
#  48  PlatformDesireNextYear  77443 non-null  object
#  49  WebFrameWorkedWith      65022 non-null  object
#  50  WebFrameDesireNextYear  62944 non-null  object
#  51  MiscTechWorkedWith      59586 non-null  object
#  52  MiscTechDesireNextYear  64511 non-null  object
#  53  DevEnviron              87317 non-null  object
#  54  OpSys                   87851 non-null  object
#  55  Containers              85366 non-null  object
#  56  BlockchainOrg           48175 non-null  object
#  57  BlockchainIs            60165 non-null  object
#  58  BetterLife              86269 non-null  object
#  59  ITperson                87141 non-null  object
#  60  OffOn                   86663 non-null  object
#  61  SocialMedia             84437 non-null  object
#  62  Extraversion            87305 non-null  object
#  63  ScreenName              80486 non-null  object
#  64  SOVisit1st              83877 non-null  object
#  65  SOVisitFreq             88263 non-null  object
#  66  SOVisitTo               88086 non-null  object
#  67  SOFindAnswer            87816 non-null  object
#  68  SOTimeSaved             86344 non-null  object
#  69  SOHowMuchTime           68378 non-null  object
#  70  SOAccount               87828 non-null  object
#  71  SOPartFreq              74692 non-null  object
#  72  SOJobs                  88066 non-null  object
#  73  EntTeams                87841 non-null  object
#  74  SOComm                  88131 non-null  object
#  75  WelcomeChange           85855 non-null  object
#  76  SONewContent            69560 non-null  object
#  77  Age                     79210 non-null  float64
#  78  Gender                  85406 non-null  object
#  79  Trans                   83607 non-null  object
#  80  Sexuality               76147 non-null  object
#  81  Ethnicity               76668 non-null  object
#  82  Dependents              83059 non-null  object
#  83  SurveyLength            86984 non-null  object
#  84  SurveyEase              87081 non-null  object
# dtypes: float64(5), int64(1), object(79)
# memory usage: 57.6+ MB

# %%
# Notice that our dataframe above was truncated. So we were not able to see all of the columns
# See below for code that allows us see all columns
pd.set_option('display.max_columns', 85) # the 85 here is the number of columns you want to display

# %%
# so we run the dataframe again
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         OrgSize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  DevType YearsCode Age1stCode  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            YearsCodePro           CareerSat                 JobSat  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    MgrIdiot  MgrMoney   MgrWant  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  JobSeek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                LastHireDate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  LastInt FizzBuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               JobFactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             ResumeUpdate CurrencySymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 WorkPlan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            WorkChallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              WorkRemote WorkLoc                  ImpSyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        CodeRev  CodeRevHrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            UnitTests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              PurchaseHow  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                               Not sure
# 3      Developers typically have the most influence o...
# 4                                               Not sure
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                         PurchaseWhat  \
# 0                                NaN
# 1                                NaN
# 2      I have little or no influence
# 3      I have little or no influence
# 4      I have little or no influence
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                       LanguageWorkedWith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   LanguageDesireNextYear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      DatabaseWorkedWith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   DatabaseDesireNextYear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       PlatformWorkedWith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   PlatformDesireNextYear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 WebFrameWorkedWith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              WebFrameDesireNextYear      MiscTechWorkedWith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          MiscTechDesireNextYear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               DevEnviron        OpSys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers BlockchainOrg  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             BlockchainIs BetterLife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        ITperson  OffOn SocialMedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    Extraversion ScreenName        SOVisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            SOVisitFreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                SOVisitTo  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer                         SOTimeSaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        SOHowMuchTime SOAccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   SOJobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 EntTeams           SOComm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
schema_df = pd.read_csv(r"C:\Users\DELL\Desktop\Libray Series\Pandas\survey_results_schema.csv")

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
# Notice that our dataframe above was concatinated. So we were not able to see all of the rows
# See below for code that allows us see all rows
pd.set_option('display.max_rows', 85) # the 85 here is the number of rows you want to display

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# 11                 OrgSize  Approximately how many people are employed by ...
# 12                 DevType  Which of the following describe you? Please se...
# 13               YearsCode  Including any education, how many years have y...
# 14              Age1stCode  At what age did you write your first line of c...
# 15            YearsCodePro  How many years have you coded professionally (...
# 16               CareerSat  Overall, how satisfied are you with your caree...
# 17                  JobSat  How satisfied are you with your current job? (...
# 18                MgrIdiot  How confident are you that your manager knows ...
# 19                MgrMoney  Do you believe that you need to be a manager t...
# 20                 MgrWant  Do you want to become a manager yourself in th...
# 21                 JobSeek  Which of the following best describes your cur...
# 22            LastHireDate  When was the last time that you took a job wit...
# 23                 LastInt  In your most recent successful job interview (...
# 24                FizzBuzz  Have you ever been asked to solve FizzBuzz in ...
# 25              JobFactors  Imagine that you are deciding between two job ...
# 26            ResumeUpdate  Think back to the last time you updated your r...
# 27          CurrencySymbol  Which currency do you use day-to-day? If your ...
# 28            CurrencyDesc  Which currency do you use day-to-day? If your ...
# 29               CompTotal  What is your current total compensation (salar...
# 30                CompFreq   Is that compensation weekly, monthly, or yearly?
# 31           ConvertedComp  Salary converted to annual USD salaries using ...
# 32             WorkWeekHrs   On average, how many hours per week do you work?
# 33                WorkPlan            How structured or planned is your work?
# 34           WorkChallenge  Of these options, what are your greatest chall...
# 35              WorkRemote                    How often do you work remotely?
# 36                 WorkLoc                    Where would you prefer to work?
# 37                  ImpSyn  For the specific work you do, and the years of...
# 38                 CodeRev           Do you review code as part of your work?
# 39              CodeRevHrs  On average, how many hours per week do you spe...
# 40               UnitTests  Does your company regularly employ unit tests ...
# 41             PurchaseHow  How does your company make decisions about pur...
# 42            PurchaseWhat  What level of influence do you, personally, ha...
# 43      LanguageWorkedWith  Which of the following programming, scripting,...
# 44  LanguageDesireNextYear  Which of the following programming, scripting,...
# 45      DatabaseWorkedWith  Which of the following database environments h...
# 46  DatabaseDesireNextYear  Which of the following database environments h...
# 47      PlatformWorkedWith  Which of the following platforms have you done...
# 48  PlatformDesireNextYear  Which of the following platforms have you done...
# 49      WebFrameWorkedWith  Which of the following web frameworks have you...
# 50  WebFrameDesireNextYear  Which of the following web frameworks have you...
# 51      MiscTechWorkedWith  Which of the following other frameworks, libra...
# 52  MiscTechDesireNextYear  Which of the following other frameworks, libra...
# 53              DevEnviron  Which development environment(s) do you use re...
# 54                   OpSys  What is the primary operating system in which ...
# 55              Containers  How do you use containers (Docker, Open Contai...
# 56           BlockchainOrg  How is your organization thinking about or imp...
# 57            BlockchainIs  Blockchain / cryptocurrency technology is prim...
# 58              BetterLife  Do you think people born today will have a bet...
# 59                ITperson   Are you the "IT support person" for your family?
# 60                   OffOn        Have you tried turning it off and on again?
# 61             SocialMedia        What social media site do you use the most?
# 62            Extraversion    Do you prefer online chat or IRL conversations?
# 63              ScreenName                               What do you call it?
# 64              SOVisit1st  To the best of your memory, when did you first...
# 65             SOVisitFreq  How frequently would you say you visit Stack O...
# 66               SOVisitTo  I visit Stack Overflow to... (check all that a...
# 67            SOFindAnswer  On average, how many times a week do you find ...
# 68             SOTimeSaved  Think back to the last time you solved a codin...
# 69           SOHowMuchTime  About how much time did you save? If you're no...
# 70               SOAccount              Do you have a Stack Overflow account?
# 71              SOPartFreq  How frequently would you say you participate i...
# 72                  SOJobs  Have you ever used or visited Stack Overflow J...
# 73                EntTeams  Have you ever used Stack Overflow for Enterpri...
# 74                  SOComm  Do you consider yourself a member of the Stack...
# 75           WelcomeChange  Compared to last year, how welcome do you feel...
# 76            SONewContent  Would you like to see any of the following on ...
# 77                     Age  What is your age (in years)? If you prefer not...
# 78                  Gender  Which of the following do you currently identi...
# 79                   Trans                    Do you identify as transgender?
# 80               Sexuality  Which of the following do you currently identi...
# 81               Ethnicity  Which of the following do you identify as? Ple...
# 82              Dependents  Do you have any dependents (e.g., children, el...
# 83            SurveyLength  How do you feel about the length of the survey...
# 84              SurveyEase  How easy or difficult was this survey to compl...

# %%
# first n rows
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                                NaN
# 1                                                NaN
# 2                      Web development or web design
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                                             EduOther  \
# 0  Taught yourself a new language, framework, or ...
# 1  Taken an online course in programming or softw...
# 2  Taught yourself a new language, framework, or ...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
#
#                     OrgSize  \
# 0                       NaN
# 1                       NaN
# 2      100 to 499 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType YearsCode Age1stCode  \
# 0                                                NaN         4         10
# 1  Developer, desktop or enterprise applications;...       NaN         17
# 2  Designer;Developer, back-end;Developer, front-...         3         22
# 3                              Developer, full-stack         3         16
# 4  Academic researcher;Developer, desktop or ente...        16         14
#
#        YearsCodePro           CareerSat                 JobSat  \
# 0               NaN                 NaN                    NaN
# 1               NaN                 NaN                    NaN
# 2                 1  Slightly satisfied     Slightly satisfied
# 3  Less than 1 year      Very satisfied     Slightly satisfied
# 4                 9   Very dissatisfied  Slightly dissatisfied
#
#                MgrIdiot  MgrMoney   MgrWant  \
# 0                   NaN       NaN       NaN
# 1                   NaN       NaN       NaN
# 2  Not at all confident  Not sure  Not sure
# 3        Very confident        No  Not sure
# 4    Somewhat confident       Yes        No
#
#                                              JobSeek          LastHireDate  \
# 0                                                NaN                   NaN
# 1                    I am actively looking for a job  I've never had a job
# 2  I’m not actively looking, but I am open to new...         1-2 years ago
# 3       I am not interested in new job opportunities  Less than a year ago
# 4       I am not interested in new job opportunities  Less than a year ago
#
#                                              LastInt FizzBuzz  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                Interview with people in peer roles       No
# 3  Write code by hand (e.g., on a whiteboard);Int...       No
# 4  Write any code;Write code by hand (e.g., on a ...       No
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
# 2  Languages, frameworks, and other technologies ...
# 3  Languages, frameworks, and other technologies ...
# 4  Industry that I'd be working in;Languages, fra...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
# 2                   I was preparing for a job search            THB
# 3                   I was preparing for a job search            USD
# 4                   I was preparing for a job search            UAH
#
#            CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                   NaN        NaN      NaN            NaN          NaN
# 1                   NaN        NaN      NaN            NaN          NaN
# 2             Thai baht    23000.0  Monthly         8820.0         40.0
# 3  United States dollar    61000.0   Yearly        61000.0         80.0
# 4     Ukrainian hryvnia        NaN      NaN            NaN         55.0
#
#                                             WorkPlan  \
# 0                                                NaN
# 1                                                NaN
# 2  There's no schedule or spec; I work on what se...
# 3  There's no schedule or spec; I work on what se...
# 4  There is a schedule and/or spec (made by me or...
#
#                                        WorkChallenge  \
# 0                                                NaN
# 1                                                NaN
# 2  Distracting work environment;Inadequate access...
# 3                                                NaN
# 4  Being tasked with non-development work;Inadequ...
#
#                          WorkRemote WorkLoc                  ImpSyn  \
# 0                               NaN     NaN                     NaN
# 1                               NaN     NaN                     NaN
# 2  Less than once per month / Never    Home                 Average
# 3  Less than once per month / Never    Home  A little below average
# 4             A few days each month  Office  A little above average
#
#                                    CodeRev  CodeRevHrs  \
# 0                                      NaN         NaN
# 1                                      NaN         NaN
# 2                                       No         NaN
# 3                                       No         NaN
# 4  Yes, because I see value in code review         NaN
#
#                        UnitTests  \
# 0                            NaN
# 1                            NaN
# 2      No, but I think we should
# 3      No, but I think we should
# 4  Yes, it's part of our process
#
#                                          PurchaseHow  \
# 0                                                NaN
# 1                                                NaN
# 2                                           Not sure
# 3  Developers typically have the most influence o...
# 4                                           Not sure
#
#                     PurchaseWhat                           LanguageWorkedWith  \
# 0                            NaN              HTML/CSS;Java;JavaScript;Python
# 1                            NaN                          C++;HTML/CSS;Python
# 2  I have little or no influence                                     HTML/CSS
# 3  I have little or no influence                          C;C++;C#;Python;SQL
# 4  I have little or no influence  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                             LanguageDesireNextYear  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                      C++;HTML/CSS;JavaScript;SQL
# 2                                  Elixir;HTML/CSS
# 3                              C;C#;JavaScript;SQL
# 4         HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                  DatabaseWorkedWith  \
# 0                                            SQLite
# 1                                               NaN
# 2                                        PostgreSQL
# 3                                      MySQL;SQLite
# 4  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                               DatabaseDesireNextYear  \
# 0                                              MySQL
# 1                                              MySQL
# 2                                         PostgreSQL
# 3                                       MySQL;SQLite
# 4  Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                   PlatformWorkedWith                 PlatformDesireNextYear  \
# 0                      MacOS;Windows                Android;Arduino;Windows
# 1                            Windows                                Windows
# 2                                NaN                                    NaN
# 3                      Linux;Windows                          Linux;Windows
# 4  Android;Linux;MacOS;Slack;Windows  Android;Docker;Kubernetes;Linux;Slack
#
#                             WebFrameWorkedWith        WebFrameDesireNextYear  \
# 0                                 Django;Flask                  Flask;jQuery
# 1                                       Django                        Django
# 2                                          NaN                     Other(s):
# 3                                          NaN                           NaN
# 4  Django;Express;Flask;jQuery;React.js;Spring  Flask;jQuery;React.js;Spring
#
#   MiscTechWorkedWith                    MiscTechDesireNextYear  \
# 0            Node.js                                   Node.js
# 1                NaN                                       NaN
# 2                NaN                                       NaN
# 3               .NET                                      .NET
# 4    Cordova;Node.js  Apache Spark;Hadoop;Node.js;React Native
#
#                                      DevEnviron        OpSys  \
# 0                    IntelliJ;Notepad++;PyCharm      Windows
# 1                                  Atom;PyCharm      Windows
# 2                        Vim;Visual Studio Code  Linux-based
# 3  Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                        IntelliJ;Notepad++;Vim  Linux-based
#
#                                Containers BlockchainOrg  \
# 0                 I do not use containers           NaN
# 1                 I do not use containers           NaN
# 2                 I do not use containers           NaN
# 3                 I do not use containers    Not at all
# 4  Outside of work, for personal projects    Not at all
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
# 2                                                NaN        Yes
# 3  Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                NaN        Yes
#
#                                    ITperson OffOn SocialMedia  \
# 0  Fortunately, someone else has that title   Yes     Twitter
# 1                                       Yes   Yes   Instagram
# 2                                       Yes   Yes      Reddit
# 3                                      SIGH   Yes      Reddit
# 4                                  Also Yes   Yes    Facebook
#
#                Extraversion ScreenName        SOVisit1st  \
# 0                    Online   Username              2017
# 1                    Online   Username              2017
# 2  In real life (in person)   Username              2011
# 3  In real life (in person)   Username              2014
# 4  In real life (in person)   Username  I don't remember
#
#                        SOVisitFreq  \
# 0  A few times per month or weekly
# 1            Daily or almost daily
# 2             A few times per week
# 3            Daily or almost daily
# 4           Multiple times per day
#
#                                            SOVisitTo  \
# 0  Find answers to specific questions;Learn how t...
# 1  Find answers to specific questions;Learn how t...
# 2  Find answers to specific questions;Learn how t...
# 3  Find answers to specific questions;Pass the ti...
# 4                 Find answers to specific questions
#
#                   SOFindAnswer                     SOTimeSaved  SOHowMuchTime  \
# 0           3-5 times per week  Stack Overflow was much faster  31-60 minutes
# 1           3-5 times per week  Stack Overflow was much faster  11-30 minutes
# 2          6-10 times per week        They were about the same            NaN
# 3           1-2 times per week  Stack Overflow was much faster  31-60 minutes
# 4  More than 10 times per week  Stack Overflow was much faster            NaN
#
#   SOAccount                           SOPartFreq  \
# 0        No                                  NaN
# 1       Yes      A few times per month or weekly
# 2       Yes  Less than once per month or monthly
# 3       Yes  Less than once per month or monthly
# 4       Yes      A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
# 2                                                Yes
# 3                                                Yes
# 4  No, I knew that Stack Overflow had a job board...
#
#                                             EntTeams           SOComm  \
# 0                No, and I don't know what those are          Neutral
# 1                No, and I don't know what those are    Yes, somewhat
# 2  No, I've heard of them, but I am not part of a...          Neutral
# 3                No, and I don't know what those are   No, not really
# 4  No, I've heard of them, but I am not part of a...  Yes, definitely
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy

# %%
# last n rows
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment Country  \
# 88878             Not employed, and not looking for work  Canada
# 88879                                                NaN     NaN
# 88880                                 Employed full-time     NaN
# 88881  Independent contractor, freelancer, or self-em...     NaN
# 88882             Not employed, and not looking for work   Spain
#
#               Student                             EdLevel  \
# 88878              No           Primary/elementary school
# 88879             NaN                                 NaN
# 88880             NaN                                 NaN
# 88881             NaN                                 NaN
# 88882  Yes, full-time  Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther OrgSize DevType  \
# 88878  Taught yourself a new language, framework, or ...     NaN     NaN
# 88879                                                NaN     NaN     NaN
# 88880                                                NaN     NaN     NaN
# 88881                                                NaN     NaN     NaN
# 88882  Taken an online course in programming or softw...     NaN     NaN
#
#       YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 88878       NaN        NaN          NaN       NaN    NaN      NaN      NaN
# 88879       NaN        NaN          NaN       NaN    NaN      NaN      NaN
# 88880       NaN        NaN          NaN       NaN    NaN      NaN      NaN
# 88881       NaN        NaN          NaN       NaN    NaN      NaN      NaN
# 88882         8         11            3       NaN    NaN      NaN      NaN
#
#       MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 88878     NaN     NaN          NaN     NaN      NaN        NaN          NaN
# 88879     NaN     NaN          NaN     NaN      NaN        NaN          NaN
# 88880     NaN     NaN          NaN     NaN      NaN        NaN          NaN
# 88881     NaN     NaN          NaN     NaN      NaN        NaN          NaN
# 88882     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
#       CurrencySymbol CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# 88878            NaN          NaN        NaN      NaN            NaN
# 88879            NaN          NaN        NaN      NaN            NaN
# 88880            NaN          NaN        NaN      NaN            NaN
# 88881            NaN          NaN        NaN      NaN            NaN
# 88882            NaN          NaN        NaN      NaN            NaN
#
#        WorkWeekHrs WorkPlan WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  \
# 88878          NaN      NaN           NaN        NaN     NaN    NaN     NaN
# 88879          NaN      NaN           NaN        NaN     NaN    NaN     NaN
# 88880          NaN      NaN           NaN        NaN     NaN    NaN     NaN
# 88881          NaN      NaN           NaN        NaN     NaN    NaN     NaN
# 88882          NaN      NaN           NaN        NaN     NaN    NaN     NaN
#
#        CodeRevHrs UnitTests PurchaseHow PurchaseWhat  \
# 88878         NaN       NaN         NaN          NaN
# 88879         NaN       NaN         NaN          NaN
# 88880         NaN       NaN         NaN          NaN
# 88881         NaN       NaN         NaN          NaN
# 88882         NaN       NaN         NaN          NaN
#
#                                       LanguageWorkedWith  \
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   LanguageDesireNextYear  \
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                 DatabaseWorkedWith  \
# 88878                              Firebase;SQLite
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882  DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#             DatabaseDesireNextYear         PlatformWorkedWith  \
# 88878        Firebase;MySQL;SQLite                      Linux
# 88879                          NaN                        NaN
# 88880                          NaN                        NaN
# 88881                          NaN                        NaN
# 88882  MariaDB;MySQL;Oracle;SQLite  iOS;Linux;MacOS;WordPress
#
#                                   PlatformDesireNextYear  \
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#            WebFrameWorkedWith WebFrameDesireNextYear      MiscTechWorkedWith  \
# 88878                  jQuery          jQuery;Vue.js                 Node.js
# 88879                     NaN                    NaN                     NaN
# 88880                     NaN                    NaN                     NaN
# 88881                     NaN                    NaN                     NaN
# 88882  Django;jQuery;React.js                 Django  Unity 3D;Unreal Engine
#
#                     MiscTechDesireNextYear  \
# 88878  React Native;Unity 3D;Unreal Engine
# 88879                                  NaN
# 88880                                  NaN
# 88881                                  NaN
# 88882                                  NaN
#
#                                               DevEnviron        OpSys  \
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                     Containers BlockchainOrg  \
# 88878  I do not use containers           NaN
# 88879                      NaN           NaN
# 88880                      NaN           NaN
# 88881                      NaN           NaN
# 88882               Production           NaN
#
#                                             BlockchainIs BetterLife  ITperson  \
# 88878  Useful across many domains and could change ma...        Yes       Yes
# 88879                                                NaN        NaN       NaN
# 88880                                                NaN        NaN       NaN
# 88881                                                NaN        NaN       NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes  Also Yes
#
#        OffOn SocialMedia              Extraversion ScreenName  \
# 88878  What?     YouTube                       NaN   Username
# 88879    NaN         NaN                       NaN        NaN
# 88880    NaN         NaN                       NaN        NaN
# 88881    NaN         NaN                       NaN        NaN
# 88882    Yes    WhatsApp  In real life (in person)        NaN
#
#              SOVisit1st            SOVisitFreq  \
# 88878  I don't remember   A few times per week
# 88879               NaN                    NaN
# 88880               NaN                    NaN
# 88881               NaN                    NaN
# 88882              2012  Daily or almost daily
#
#                                                SOVisitTo         SOFindAnswer  \
# 88878  Find answers to specific questions;Learn how t...   3-5 times per week
# 88879                                                NaN                  NaN
# 88880                                                NaN                  NaN
# 88881                                                NaN                  NaN
# 88882  Find answers to specific questions;Learn how t...  6-10 times per week
#
#                               SOTimeSaved  SOHowMuchTime SOAccount  \
# 88878  Stack Overflow was slightly faster  11-30 minutes       Yes
# 88879                                 NaN            NaN       NaN
# 88880                                 NaN            NaN       NaN
# 88881                                 NaN            NaN       NaN
# 88882      Stack Overflow was much faster  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   SOJobs  \
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 EntTeams          SOComm  \
# 88878  No, I've heard of them, but I am not part of a...  No, not at all
# 88879                                                NaN             NaN
# 88880                                                NaN             NaN
# 88881                                                NaN             NaN
# 88882  No, I've heard of them, but I am not part of a...   Yes, somewhat
#
#                                   WelcomeChange  \
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength SurveyEase
# 88878  Appropriate in length       Easy
# 88879                    NaN        NaN
# 88880                    NaN        NaN
# 88881                    NaN        NaN
# 88882  Appropriate in length       Easy

# %%
# List of all columns in our dataframe
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
# assessing column
df.Hobbyist
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
# another way

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
# to get the count of unique values
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
# assessing rows based on interger location
# we use iloc[]
df.iloc[0] #the first row. 0 meaning integer zero.. which returns a series
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# YearsCode                                                                 4
# Age1stCode                                                               10
# YearsCodePro                                                            NaN
# CareerSat                                                               NaN
# JobSat                                                                  NaN
# MgrIdiot                                                                NaN
# MgrMoney                                                                NaN
# MgrWant                                                                 NaN
# JobSeek                                                                 NaN
# LastHireDate                                                            NaN
# LastInt                                                                 NaN
# FizzBuzz                                                                NaN
# JobFactors                                                              NaN
# ResumeUpdate                                                            NaN
# CurrencySymbol                                                          NaN
# CurrencyDesc                                                            NaN
# CompTotal                                                               NaN
# CompFreq                                                                NaN
# ConvertedComp                                                           NaN
# WorkWeekHrs                                                             NaN
# WorkPlan                                                                NaN
# WorkChallenge                                                           NaN
# WorkRemote                                                              NaN
# WorkLoc                                                                 NaN
# ImpSyn                                                                  NaN
# CodeRev                                                                 NaN
# CodeRevHrs                                                              NaN
# UnitTests                                                               NaN
# PurchaseHow                                                             NaN
# PurchaseWhat                                                            NaN
# LanguageWorkedWith                          HTML/CSS;Java;JavaScript;Python
# LanguageDesireNextYear      C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# DatabaseWorkedWith                                                   SQLite
# DatabaseDesireNextYear                                                MySQL
# PlatformWorkedWith                                            MacOS;Windows
# PlatformDesireNextYear                              Android;Arduino;Windows
# WebFrameWorkedWith                                             Django;Flask
# WebFrameDesireNextYear                                         Flask;jQuery
# MiscTechWorkedWith                                                  Node.js
# MiscTechDesireNextYear                                              Node.js
# DevEnviron                                       IntelliJ;Notepad++;PyCharm
# OpSys                                                               Windows
# Containers                                          I do not use containers
# BlockchainOrg                                                           NaN
# BlockchainIs                                                            NaN
# BetterLife                                                              Yes
# ITperson                           Fortunately, someone else has that title
# OffOn                                                                   Yes
# SocialMedia                                                         Twitter
# Extraversion                                                         Online
# ScreenName                                                         Username
# SOVisit1st                                                             2017
# SOVisitFreq                                 A few times per month or weekly
# SOVisitTo                 Find answers to specific questions;Learn how t...
# SOFindAnswer                                             3-5 times per week
# SOTimeSaved                                  Stack Overflow was much faster
# SOHowMuchTime                                                 31-60 minutes
# SOAccount                                                                No
# SOPartFreq                                                              NaN
# SOJobs                    No, I didn't know that Stack Overflow had a jo...
# EntTeams                                No, and I don't know what those are
# SOComm                                                              Neutral
# WelcomeChange                       Just as welcome now as I felt last year
# SONewContent              Tech articles written by other developers;Indu...
# Age                                                                    14.0
# Gender                                                                  Man
# Trans                                                                    No
# Sexuality                                           Straight / Heterosexual
# Ethnicity                                                               NaN
# Dependents                                                               No
# SurveyLength                                          Appropriate in length
# SurveyEase                                       Neither easy nor difficult
# Name: 0, dtype: object

# %%
# assessing more than one row based on interger location
# we use iloc[]
df.iloc[[0,1]] #the two rows. 0 meaning integer zero and 1 meaning integer one.. which returns a datframe
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# 0            NaN  Taught yourself a new language, framework, or ...     NaN
# 1            NaN  Taken an online course in programming or softw...     NaN
#
#                                              DevType YearsCode Age1stCode  \
# 0                                                NaN         4         10
# 1  Developer, desktop or enterprise applications;...       NaN         17
#
#   YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant  \
# 0          NaN       NaN    NaN      NaN      NaN     NaN
# 1          NaN       NaN    NaN      NaN      NaN     NaN
#
#                            JobSeek          LastHireDate LastInt FizzBuzz  \
# 0                              NaN                   NaN     NaN      NaN
# 1  I am actively looking for a job  I've never had a job     NaN      NaN
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
#
#   CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan  \
# 0          NaN        NaN      NaN            NaN          NaN      NaN
# 1          NaN        NaN      NaN            NaN          NaN      NaN
#
#   WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests  \
# 0           NaN        NaN     NaN    NaN     NaN         NaN       NaN
# 1           NaN        NaN     NaN    NaN     NaN         NaN       NaN
#
#   PurchaseHow PurchaseWhat               LanguageWorkedWith  \
# 0         NaN          NaN  HTML/CSS;Java;JavaScript;Python
# 1         NaN          NaN              C++;HTML/CSS;Python
#
#                             LanguageDesireNextYear DatabaseWorkedWith  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite
# 1                      C++;HTML/CSS;JavaScript;SQL                NaN
#
#   DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith  \
# 0       Django;Flask           Flask;jQuery            Node.js
# 1             Django                 Django                NaN
#
#   MiscTechDesireNextYear                  DevEnviron    OpSys  \
# 0                Node.js  IntelliJ;Notepad++;PyCharm  Windows
# 1                    NaN                Atom;PyCharm  Windows
#
#                 Containers BlockchainOrg  \
# 0  I do not use containers           NaN
# 1  I do not use containers           NaN
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
#
#                                    ITperson OffOn SocialMedia Extraversion  \
# 0  Fortunately, someone else has that title   Yes     Twitter       Online
# 1                                       Yes   Yes   Instagram       Online
#
#   ScreenName SOVisit1st                      SOVisitFreq  \
# 0   Username       2017  A few times per month or weekly
# 1   Username       2017            Daily or almost daily
#
#                                            SOVisitTo        SOFindAnswer  \
# 0  Find answers to specific questions;Learn how t...  3-5 times per week
# 1  Find answers to specific questions;Learn how t...  3-5 times per week
#
#                       SOTimeSaved  SOHowMuchTime SOAccount  \
# 0  Stack Overflow was much faster  31-60 minutes        No
# 1  Stack Overflow was much faster  11-30 minutes       Yes
#
#                         SOPartFreq  \
# 0                              NaN
# 1  A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
#
#                               EntTeams         SOComm  \
# 0  No, and I don't know what those are        Neutral
# 1  No, and I don't know what those are  Yes, somewhat
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
# 1  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SurveyEase
# 0  Neither easy nor difficult
# 1  Neither easy nor difficult

# %%
# assessing more than one row, with a specfic column based on interger location
# we use iloc[]
df.iloc[[0,1], 5] #the two rows. 0 meaning index zero, 1 meaning index one and 5 meaning index five for columns
#which returns a series
# Out:
# 0    Not employed, and not looking for work
# 1        Not employed, but looking for work
# Name: Employment, dtype: object

# %%
# assesing a row based on location
# we use loc[]
df.loc[0]  #the first row. 0 meaning index zero.. which returns a series
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# YearsCode                                                                 4
# Age1stCode                                                               10
# YearsCodePro                                                            NaN
# CareerSat                                                               NaN
# JobSat                                                                  NaN
# MgrIdiot                                                                NaN
# MgrMoney                                                                NaN
# MgrWant                                                                 NaN
# JobSeek                                                                 NaN
# LastHireDate                                                            NaN
# LastInt                                                                 NaN
# FizzBuzz                                                                NaN
# JobFactors                                                              NaN
# ResumeUpdate                                                            NaN
# CurrencySymbol                                                          NaN
# CurrencyDesc                                                            NaN
# CompTotal                                                               NaN
# CompFreq                                                                NaN
# ConvertedComp                                                           NaN
# WorkWeekHrs                                                             NaN
# WorkPlan                                                                NaN
# WorkChallenge                                                           NaN
# WorkRemote                                                              NaN
# WorkLoc                                                                 NaN
# ImpSyn                                                                  NaN
# CodeRev                                                                 NaN
# CodeRevHrs                                                              NaN
# UnitTests                                                               NaN
# PurchaseHow                                                             NaN
# PurchaseWhat                                                            NaN
# LanguageWorkedWith                          HTML/CSS;Java;JavaScript;Python
# LanguageDesireNextYear      C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# DatabaseWorkedWith                                                   SQLite
# DatabaseDesireNextYear                                                MySQL
# PlatformWorkedWith                                            MacOS;Windows
# PlatformDesireNextYear                              Android;Arduino;Windows
# WebFrameWorkedWith                                             Django;Flask
# WebFrameDesireNextYear                                         Flask;jQuery
# MiscTechWorkedWith                                                  Node.js
# MiscTechDesireNextYear                                              Node.js
# DevEnviron                                       IntelliJ;Notepad++;PyCharm
# OpSys                                                               Windows
# Containers                                          I do not use containers
# BlockchainOrg                                                           NaN
# BlockchainIs                                                            NaN
# BetterLife                                                              Yes
# ITperson                           Fortunately, someone else has that title
# OffOn                                                                   Yes
# SocialMedia                                                         Twitter
# Extraversion                                                         Online
# ScreenName                                                         Username
# SOVisit1st                                                             2017
# SOVisitFreq                                 A few times per month or weekly
# SOVisitTo                 Find answers to specific questions;Learn how t...
# SOFindAnswer                                             3-5 times per week
# SOTimeSaved                                  Stack Overflow was much faster
# SOHowMuchTime                                                 31-60 minutes
# SOAccount                                                                No
# SOPartFreq                                                              NaN
# SOJobs                    No, I didn't know that Stack Overflow had a jo...
# EntTeams                                No, and I don't know what those are
# SOComm                                                              Neutral
# WelcomeChange                       Just as welcome now as I felt last year
# SONewContent              Tech articles written by other developers;Indu...
# Age                                                                    14.0
# Gender                                                                  Man
# Trans                                                                    No
# Sexuality                                           Straight / Heterosexual
# Ethnicity                                                               NaN
# Dependents                                                               No
# SurveyLength                                          Appropriate in length
# SurveyEase                                       Neither easy nor difficult
# Name: 0, dtype: object

# %%
# assessing more than one row based on location
# we use loc[]
df.loc[[0,1]] #the two rows. 0 meaning index zero and 1 meaning index one.. which returns a datframe
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# 0            NaN  Taught yourself a new language, framework, or ...     NaN
# 1            NaN  Taken an online course in programming or softw...     NaN
#
#                                              DevType YearsCode Age1stCode  \
# 0                                                NaN         4         10
# 1  Developer, desktop or enterprise applications;...       NaN         17
#
#   YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant  \
# 0          NaN       NaN    NaN      NaN      NaN     NaN
# 1          NaN       NaN    NaN      NaN      NaN     NaN
#
#                            JobSeek          LastHireDate LastInt FizzBuzz  \
# 0                              NaN                   NaN     NaN      NaN
# 1  I am actively looking for a job  I've never had a job     NaN      NaN
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
#
#   CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan  \
# 0          NaN        NaN      NaN            NaN          NaN      NaN
# 1          NaN        NaN      NaN            NaN          NaN      NaN
#
#   WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests  \
# 0           NaN        NaN     NaN    NaN     NaN         NaN       NaN
# 1           NaN        NaN     NaN    NaN     NaN         NaN       NaN
#
#   PurchaseHow PurchaseWhat               LanguageWorkedWith  \
# 0         NaN          NaN  HTML/CSS;Java;JavaScript;Python
# 1         NaN          NaN              C++;HTML/CSS;Python
#
#                             LanguageDesireNextYear DatabaseWorkedWith  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite
# 1                      C++;HTML/CSS;JavaScript;SQL                NaN
#
#   DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith  \
# 0       Django;Flask           Flask;jQuery            Node.js
# 1             Django                 Django                NaN
#
#   MiscTechDesireNextYear                  DevEnviron    OpSys  \
# 0                Node.js  IntelliJ;Notepad++;PyCharm  Windows
# 1                    NaN                Atom;PyCharm  Windows
#
#                 Containers BlockchainOrg  \
# 0  I do not use containers           NaN
# 1  I do not use containers           NaN
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
#
#                                    ITperson OffOn SocialMedia Extraversion  \
# 0  Fortunately, someone else has that title   Yes     Twitter       Online
# 1                                       Yes   Yes   Instagram       Online
#
#   ScreenName SOVisit1st                      SOVisitFreq  \
# 0   Username       2017  A few times per month or weekly
# 1   Username       2017            Daily or almost daily
#
#                                            SOVisitTo        SOFindAnswer  \
# 0  Find answers to specific questions;Learn how t...  3-5 times per week
# 1  Find answers to specific questions;Learn how t...  3-5 times per week
#
#                       SOTimeSaved  SOHowMuchTime SOAccount  \
# 0  Stack Overflow was much faster  31-60 minutes        No
# 1  Stack Overflow was much faster  11-30 minutes       Yes
#
#                         SOPartFreq  \
# 0                              NaN
# 1  A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
#
#                               EntTeams         SOComm  \
# 0  No, and I don't know what those are        Neutral
# 1  No, and I don't know what those are  Yes, somewhat
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
# 1  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SurveyEase
# 0  Neither easy nor difficult
# 1  Neither easy nor difficult

# %%
# for iloc[], you have to specify the integer location for the column, but for loc[], you can just type the column name
# assessing more than one row, with a specfic column based on location
# we use loc[]
df.loc[[0,1], 'Employment'] #the two rows. 0 meaning index zero, 1 meaning index one and 5 meaning index five for columns
#which returns a series
# Out:
# 0    Not employed, and not looking for work
# 1        Not employed, but looking for work
# Name: Employment, dtype: object

# %%
# for iloc[], you have to specify the integer location for the column, but for loc[], you can just type the column name
# assessing more than one row, and more than one columns based on location
# we use loc[]
df.loc[[0,1], ['Employment','MainBranch']] #the two rows. 0 meaning index zero, 1 meaning index one and 5 meaning index five for columns
#which returns a dataframe
# Out:
#                                Employment  \
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
#
#                                MainBranch
# 0  I am a student who is learning to code
# 1  I am a student who is learning to code

# %%
# Data filtering
df['Hobbyist'] == 'Yes'
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
# we can assign it to a variable
hob = df['Hobbyist'] == 'Yes'
hob
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
# to get a dataframe instead
df[df['Hobbyist'] == 'Yes']
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88872       87739                                                NaN      Yes
# 88875       88182                                                NaN      Yes
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 2                                                  Never
# 4                             Once a month or more often
# 5                                                  Never
# 7                                Less than once per year
# ...                                                  ...
# 88872                            Less than once per year
# 88875                         Once a month or more often
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# 5      The quality of OSS and closed source software ...
# 7      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88872  OSS is, on average, of HIGHER quality than pro...
# 88875  OSS is, on average, of HIGHER quality than pro...
# 88877  The quality of OSS and closed source software ...
# 88878  The quality of OSS and closed source software ...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                    Employment         Country         Student  \
# 0      Not employed, and not looking for work  United Kingdom              No
# 2                          Employed full-time        Thailand              No
# 4                          Employed full-time         Ukraine              No
# 5                          Employed full-time          Canada              No
# 7          Not employed, but looking for work           India             NaN
# ...                                       ...             ...             ...
# 88872                      Employed part-time  Czech Republic  Yes, full-time
# 88875                      Employed part-time        Pakistan             NaN
# 88877      Not employed, but looking for work   United States              No
# 88878  Not employed, and not looking for work          Canada              No
# 88882  Not employed, and not looking for work           Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88872        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88875  Secondary school (e.g. American high school, G...
# 88877  Some college/university study without earning ...
# 88878                          Primary/elementary school
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 2                          Web development or web design
# 4      Computer science, computer engineering, or sof...
# 5                              Mathematics or statistics
# 7      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88872  Computer science, computer engineering, or sof...
# 88875                                                NaN
# 88877  Computer science, computer engineering, or sof...
# 88878                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 2      Taught yourself a new language, framework, or ...
# 4      Taken an online course in programming or softw...
# 5      Taken an online course in programming or softw...
# 7      Taught yourself a new language, framework, or ...
# ...                                                  ...
# 88872  Taught yourself a new language, framework, or ...
# 88875  Taken an online course in programming or softw...
# 88877  Taught yourself a new language, framework, or ...
# 88878  Taught yourself a new language, framework, or ...
# 88882  Taken an online course in programming or softw...
#
#                         OrgSize  \
# 0                           NaN
# 2          100 to 499 employees
# 4      10,000 or more employees
# 5                           NaN
# 7                           NaN
# ...                         ...
# 88872      500 to 999 employees
# 88875        10 to 19 employees
# 88877                       NaN
# 88878                       NaN
# 88882                       NaN
#
#                                                  DevType YearsCode  \
# 0                                                    NaN         4
# 2      Designer;Developer, back-end;Developer, front-...         3
# 4      Academic researcher;Developer, desktop or ente...        16
# 5      Data or business analyst;Data scientist or mac...        13
# 7         Developer, back-end;Engineer, site reliability         8
# ...                                                  ...       ...
# 88872  Academic researcher;Designer;Developer, game o...         9
# 88875                                Academic researcher         1
# 88877  Developer, back-end;Developer, desktop or ente...        38
# 88878                                                NaN       NaN
# 88882                                                NaN         8
#
#                  Age1stCode      YearsCodePro           CareerSat  \
# 0                        10               NaN                 NaN
# 2                        22                 1  Slightly satisfied
# 4                        14                 9   Very dissatisfied
# 5                        15                 3      Very satisfied
# 7                        16               NaN                 NaN
# ...                     ...               ...                 ...
# 88872                    16                 3                 NaN
# 88875  Younger than 5 years  Less than 1 year                 NaN
# 88877                    10                38                 NaN
# 88878                   NaN               NaN                 NaN
# 88882                    11                 3                 NaN
#
#                       JobSat              MgrIdiot  MgrMoney   MgrWant  \
# 0                        NaN                   NaN       NaN       NaN
# 2         Slightly satisfied  Not at all confident  Not sure  Not sure
# 4      Slightly dissatisfied    Somewhat confident       Yes        No
# 5         Slightly satisfied        Very confident        No       Yes
# 7                        NaN                   NaN       NaN       NaN
# ...                      ...                   ...       ...       ...
# 88872                    NaN    Somewhat confident        No  Not sure
# 88875                    NaN        Very confident  Not sure       Yes
# 88877                    NaN                   NaN       NaN       NaN
# 88878                    NaN                   NaN       NaN       NaN
# 88882                    NaN                   NaN       NaN       NaN
#
#                                                  JobSeek  \
# 0                                                    NaN
# 2      I’m not actively looking, but I am open to new...
# 4           I am not interested in new job opportunities
# 5           I am not interested in new job opportunities
# 7                                                    NaN
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                LastHireDate  \
# 0                       NaN
# 2             1-2 years ago
# 4      Less than a year ago
# 5             1-2 years ago
# 7                       NaN
# ...                     ...
# 88872                   NaN
# 88875                   NaN
# 88877                   NaN
# 88878                   NaN
# 88882                   NaN
#
#                                                  LastInt FizzBuzz  \
# 0                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# 5      Write any code;Complete a take-home project;In...       No
# 7                                                    NaN      NaN
# ...                                                  ...      ...
# 88872                                                NaN      NaN
# 88875                                                NaN      NaN
# 88877                                                NaN      NaN
# 88878                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               JobFactors  \
# 0                                                    NaN
# 2      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# 5      Financial performance or funding status of the...
# 7                                                    NaN
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                                             ResumeUpdate CurrencySymbol  \
# 0                                                    NaN            NaN
# 2                       I was preparing for a job search            THB
# 4                       I was preparing for a job search            UAH
# 5      I heard about a job opportunity (from a recrui...            CAD
# 7                                                    NaN            NaN
# ...                                                  ...            ...
# 88872                                                NaN            NaN
# 88875                                                NaN            NaN
# 88877                                                NaN            NaN
# 88878                                                NaN            NaN
# 88882                                                NaN            NaN
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                    NaN        NaN      NaN            NaN          NaN
# 2              Thai baht    23000.0  Monthly         8820.0         40.0
# 4      Ukrainian hryvnia        NaN      NaN            NaN         55.0
# 5        Canadian dollar    40000.0  Monthly       366420.0         15.0
# 7                    NaN        NaN      NaN            NaN          NaN
# ...                  ...        ...      ...            ...          ...
# 88872                NaN        NaN      NaN            NaN          NaN
# 88875                NaN        NaN      NaN            NaN          NaN
# 88877                NaN        NaN      NaN            NaN          NaN
# 88878                NaN        NaN      NaN            NaN          NaN
# 88882                NaN        NaN      NaN            NaN          NaN
#
#                                                 WorkPlan  \
# 0                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# 5      There's no schedule or spec; I work on what se...
# 7                                                    NaN
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                                            WorkChallenge  \
# 0                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 4      Being tasked with non-development work;Inadequ...
# 5                                                    NaN
# 7                                                    NaN
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                              WorkRemote WorkLoc                  ImpSyn  \
# 0                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 4                 A few days each month  Office  A little above average
# 5                 A few days each month    Home  A little above average
# 7                                   NaN     NaN                     NaN
# ...                                 ...     ...                     ...
# 88872                               NaN     NaN                     NaN
# 88875                               NaN     NaN                     NaN
# 88877                               NaN     NaN                     NaN
# 88878                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        CodeRev  CodeRevHrs  \
# 0                                          NaN         NaN
# 2                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# 5                                           No         NaN
# 7                                          NaN         NaN
# ...                                        ...         ...
# 88872                                      NaN         NaN
# 88875                                      NaN         NaN
# 88877                                      NaN         NaN
# 88878                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                                                UnitTests PurchaseHow  \
# 0                                                    NaN         NaN
# 2                              No, but I think we should    Not sure
# 4                          Yes, it's part of our process    Not sure
# 5      Yes, it's not part of our process but the deve...    Not sure
# 7                                                    NaN         NaN
# ...                                                  ...         ...
# 88872                                                NaN         NaN
# 88875                                                NaN         NaN
# 88877                                                NaN         NaN
# 88878                                                NaN         NaN
# 88882                                                NaN         NaN
#
#                         PurchaseWhat  \
# 0                                NaN
# 2      I have little or no influence
# 4      I have little or no influence
# 5      I have little or no influence
# 7                                NaN
# ...                              ...
# 88872                            NaN
# 88875                            NaN
# 88877                            NaN
# 88878                            NaN
# 88882                            NaN
#
#                                       LanguageWorkedWith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 2                                               HTML/CSS
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 5                                             Java;R;SQL
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...                                                  ...
# 88872           C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88875                           HTML/CSS;Java;JavaScript
# 88877  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   LanguageDesireNextYear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                                        Elixir;HTML/CSS
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 5                                       Python;Scala;SQL
# 7      Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# ...                                                  ...
# 88872                            C++;HTML/CSS;PHP;Python
# 88875                                                NaN
# 88877  Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                       DatabaseWorkedWith  \
# 0                                                 SQLite
# 2                                             PostgreSQL
# 4       Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 5                                     MongoDB;PostgreSQL
# 7      Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# ...                                                  ...
# 88872                                              MySQL
# 88875                                                NaN
# 88877                                                NaN
# 88878                                    Firebase;SQLite
# 88882        DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   DatabaseDesireNextYear  \
# 0                                                  MySQL
# 2                                             PostgreSQL
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 5                                             PostgreSQL
# 7      Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# ...                                                  ...
# 88872                                              MySQL
# 88875                                                NaN
# 88877                                                NaN
# 88878                              Firebase;MySQL;SQLite
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                                 PlatformWorkedWith  \
# 0                                    MacOS;Windows
# 2                                              NaN
# 4                Android;Linux;MacOS;Slack;Windows
# 5      Android;Google Cloud Platform;Linux;Windows
# 7              AWS;Docker;Heroku;Linux;MacOS;Slack
# ...                                            ...
# 88872                      Android;Linux;WordPress
# 88875                        Google Cloud Platform
# 88877                                        Linux
# 88878                                        Linux
# 88882                    iOS;Linux;MacOS;WordPress
#
#                                   PlatformDesireNextYear  \
# 0                                Android;Arduino;Windows
# 2                                                    NaN
# 4                  Android;Docker;Kubernetes;Linux;Slack
# 5            Android;Google Cloud Platform;Linux;Windows
# 7      Android;Arduino;AWS;Docker;Google Cloud Platfo...
# ...                                                  ...
# 88872                                      Android;Linux
# 88875                                                NaN
# 88877                                 Linux;Raspberry Pi
# 88878                        Google Cloud Platform;Linux
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 WebFrameWorkedWith  \
# 0                                     Django;Flask
# 2                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# 5                                              NaN
# 7                    Express;Flask;React.js;Spring
# ...                                            ...
# 88872                                       jQuery
# 88875                                    Other(s):
# 88877                                     React.js
# 88878                                       jQuery
# 88882                       Django;jQuery;React.js
#
#                      WebFrameDesireNextYear      MiscTechWorkedWith  \
# 0                              Flask;jQuery                 Node.js
# 2                                 Other(s):                     NaN
# 4              Flask;jQuery;React.js;Spring         Cordova;Node.js
# 5                                       NaN                  Hadoop
# 7      Django;Express;Flask;React.js;Vue.js   Hadoop;Node.js;Pandas
# ...                                     ...                     ...
# 88872                                jQuery              TensorFlow
# 88875                                   NaN               Other(s):
# 88877                                Vue.js                 Node.js
# 88878                         jQuery;Vue.js                 Node.js
# 88882                                Django  Unity 3D;Unreal Engine
#
#                                   MiscTechDesireNextYear  \
# 0                                                Node.js
# 2                                                    NaN
# 4               Apache Spark;Hadoop;Node.js;React Native
# 5                      Hadoop;Pandas;TensorFlow;Unity 3D
# 7      Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                            Ansible
# 88878                React Native;Unity 3D;Unreal Engine
# 88882                                                NaN
#
#                                               DevEnviron        OpSys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# 5      Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 7      Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# ...                                                  ...          ...
# 88872                                                Vim  Linux-based
# 88875                                     Android Studio      Windows
# 88877                                                Vim  Linux-based
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                               Containers BlockchainOrg  \
# 0                                I do not use containers           NaN
# 2                                I do not use containers           NaN
# 4                 Outside of work, for personal projects    Not at all
# 5                                I do not use containers    Not at all
# 7      Development;Testing;Production;Outside of work...           NaN
# ...                                                  ...           ...
# 88872                            I do not use containers           NaN
# 88875                                        Development           NaN
# 88877                            I do not use containers           NaN
# 88878                            I do not use containers           NaN
# 88882                                         Production           NaN
#
#                                             BlockchainIs BetterLife  \
# 0                                                    NaN        Yes
# 2                                                    NaN        Yes
# 4                                                    NaN        Yes
# 5                                                    NaN         No
# 7      Useful across many domains and could change ma...        Yes
# ...                                                  ...        ...
# 88872                                      A passing fad         No
# 88875  Useful across many domains and could change ma...        Yes
# 88877                  An irresponsible use of resources         No
# 88878  Useful across many domains and could change ma...        Yes
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        ITperson  OffOn  \
# 0      Fortunately, someone else has that title    Yes
# 2                                           Yes    Yes
# 4                                      Also Yes    Yes
# 5                                           Yes     No
# 7                                          SIGH    Yes
# ...                                         ...    ...
# 88872                                       Yes    Yes
# 88875                                  Also Yes  What?
# 88877                                       NaN    Yes
# 88878                                       Yes  What?
# 88882                                  Also Yes    Yes
#
#                     SocialMedia              Extraversion ScreenName  \
# 0                       Twitter                    Online   Username
# 2                        Reddit  In real life (in person)   Username
# 4                      Facebook  In real life (in person)   Username
# 5                       YouTube  In real life (in person)      Login
# 7                       YouTube  In real life (in person)     Handle
# ...                         ...                       ...        ...
# 88872                   YouTube  In real life (in person)      Login
# 88875                   Twitter                   Neither   Username
# 88877  I don't use social media  In real life (in person)   Username
# 88878                   YouTube                       NaN   Username
# 88882                  WhatsApp  In real life (in person)        NaN
#
#              SOVisit1st                                        SOVisitFreq  \
# 0                  2017                    A few times per month or weekly
# 2                  2011                               A few times per week
# 4      I don't remember                             Multiple times per day
# 5                  2011                    A few times per month or weekly
# 7                  2012                               A few times per week
# ...                 ...                                                ...
# 88872              2009                    A few times per month or weekly
# 88875               NaN  I have never visited Stack Overflow (before to...
# 88877  I don't remember                    A few times per month or weekly
# 88878  I don't remember                               A few times per week
# 88882              2012                              Daily or almost daily
#
#                                                SOVisitTo  \
# 0      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 4                     Find answers to specific questions
# 5                     Find answers to specific questions
# 7      Find answers to specific questions;Learn how t...
# ...                                                  ...
# 88872                 Find answers to specific questions
# 88875  Get a sense of belonging to the developer comm...
# 88877                 Find answers to specific questions
# 88878  Find answers to specific questions;Learn how t...
# 88882  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer                             SOTimeSaved  \
# 0               3-5 times per week          Stack Overflow was much faster
# 2              6-10 times per week                They were about the same
# 4      More than 10 times per week          Stack Overflow was much faster
# 5          Less than once per week      Stack Overflow was slightly faster
# 7          Less than once per week      Stack Overflow was slightly faster
# ...                            ...                                     ...
# 88872           1-2 times per week          Stack Overflow was much faster
# 88875      Less than once per week  The other resource was slightly faster
# 88877           1-2 times per week                They were about the same
# 88878           3-5 times per week      Stack Overflow was slightly faster
# 88882          6-10 times per week          Stack Overflow was much faster
#
#        SOHowMuchTime SOAccount  \
# 0      31-60 minutes        No
# 2                NaN       Yes
# 4                NaN       Yes
# 5        60+ minutes       Yes
# 7      11-30 minutes       Yes
# ...              ...       ...
# 88872  31-60 minutes       Yes
# 88875    60+ minutes       NaN
# 88877            NaN       Yes
# 88878  11-30 minutes       Yes
# 88882  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 0                                                    NaN
# 2                    Less than once per month or monthly
# 4                        A few times per month or weekly
# 5      I have never participated in Q&A on Stack Over...
# 7                    Less than once per month or monthly
# ...                                                  ...
# 88872                    A few times per month or weekly
# 88875                                                NaN
# 88877  I have never participated in Q&A on Stack Over...
# 88878  I have never participated in Q&A on Stack Over...
# 88882                    A few times per month or weekly
#
#                                                   SOJobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 2                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# 5      No, I knew that Stack Overflow had a job board...
# 7                                                    Yes
# ...                                                  ...
# 88872  No, I knew that Stack Overflow had a job board...
# 88875  No, I didn't know that Stack Overflow had a jo...
# 88877                                                Yes
# 88878  No, I knew that Stack Overflow had a job board...
# 88882                                                Yes
#
#                                                 EntTeams           SOComm  \
# 0                    No, and I don't know what those are          Neutral
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# 5                    No, and I don't know what those are   No, not really
# 7                    No, and I don't know what those are  Yes, definitely
# ...                                                  ...              ...
# 88872                No, and I don't know what those are          Neutral
# 88875                No, and I don't know what those are          Neutral
# 88877                No, and I don't know what those are   No, not really
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                            WelcomeChange  \
# 0                Just as welcome now as I felt last year
# 2                Just as welcome now as I felt last year
# 4                Just as welcome now as I felt last year
# 5                Just as welcome now as I felt last year
# 7                  A lot more welcome now than last year
# ...                                                  ...
# 88872            Just as welcome now as I felt last year
# 88875  Not applicable - I did not use Stack Overflow ...
# 88877            Just as welcome now as I felt last year
# 88878                                                NaN
# 88882           Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# 5      Tech articles written by other developers;Indu...  28.0    Man    No
# 7      Tech articles written by other developers;Indu...  24.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88872                                                NaN  25.0    NaN    No
# 88875       Courses on technologies you're interested in   NaN    Man    No
# 88877                                                NaN   NaN    Man    No
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 2      Straight / Heterosexual
# 4      Straight / Heterosexual
# 5      Straight / Heterosexual
# 7      Straight / Heterosexual
# ...                        ...
# 88872  Straight / Heterosexual
# 88875  Straight / Heterosexual
# 88877  Straight / Heterosexual
# 88878                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 2                                                    NaN        Yes
# 4               White or of European descent;Multiracial         No
# 5                                             East Asian         No
# 7                                                    NaN        NaN
# ...                                                  ...        ...
# 88872                       White or of European descent         No
# 88875                                                NaN        Yes
# 88877                                                NaN         No
# 88878                                                NaN         No
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 4      Appropriate in length                        Easy
# 5                   Too long  Neither easy nor difficult
# 7      Appropriate in length  Neither easy nor difficult
# ...                      ...                         ...
# 88872  Appropriate in length                        Easy
# 88875              Too short  Neither easy nor difficult
# 88877              Too short  Neither easy nor difficult
# 88878  Appropriate in length                        Easy
# 88882  Appropriate in length                        Easy
#
# [71257 rows x 85 columns]

# %%
# you can also add a variable to it
hob_1 = df[df['Hobbyist'] == 'Yes']
hob_1
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88872       87739                                                NaN      Yes
# 88875       88182                                                NaN      Yes
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 2                                                  Never
# 4                             Once a month or more often
# 5                                                  Never
# 7                                Less than once per year
# ...                                                  ...
# 88872                            Less than once per year
# 88875                         Once a month or more often
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# 5      The quality of OSS and closed source software ...
# 7      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88872  OSS is, on average, of HIGHER quality than pro...
# 88875  OSS is, on average, of HIGHER quality than pro...
# 88877  The quality of OSS and closed source software ...
# 88878  The quality of OSS and closed source software ...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                    Employment         Country         Student  \
# 0      Not employed, and not looking for work  United Kingdom              No
# 2                          Employed full-time        Thailand              No
# 4                          Employed full-time         Ukraine              No
# 5                          Employed full-time          Canada              No
# 7          Not employed, but looking for work           India             NaN
# ...                                       ...             ...             ...
# 88872                      Employed part-time  Czech Republic  Yes, full-time
# 88875                      Employed part-time        Pakistan             NaN
# 88877      Not employed, but looking for work   United States              No
# 88878  Not employed, and not looking for work          Canada              No
# 88882  Not employed, and not looking for work           Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88872        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88875  Secondary school (e.g. American high school, G...
# 88877  Some college/university study without earning ...
# 88878                          Primary/elementary school
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 2                          Web development or web design
# 4      Computer science, computer engineering, or sof...
# 5                              Mathematics or statistics
# 7      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88872  Computer science, computer engineering, or sof...
# 88875                                                NaN
# 88877  Computer science, computer engineering, or sof...
# 88878                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 2      Taught yourself a new language, framework, or ...
# 4      Taken an online course in programming or softw...
# 5      Taken an online course in programming or softw...
# 7      Taught yourself a new language, framework, or ...
# ...                                                  ...
# 88872  Taught yourself a new language, framework, or ...
# 88875  Taken an online course in programming or softw...
# 88877  Taught yourself a new language, framework, or ...
# 88878  Taught yourself a new language, framework, or ...
# 88882  Taken an online course in programming or softw...
#
#                         OrgSize  \
# 0                           NaN
# 2          100 to 499 employees
# 4      10,000 or more employees
# 5                           NaN
# 7                           NaN
# ...                         ...
# 88872      500 to 999 employees
# 88875        10 to 19 employees
# 88877                       NaN
# 88878                       NaN
# 88882                       NaN
#
#                                                  DevType YearsCode  \
# 0                                                    NaN         4
# 2      Designer;Developer, back-end;Developer, front-...         3
# 4      Academic researcher;Developer, desktop or ente...        16
# 5      Data or business analyst;Data scientist or mac...        13
# 7         Developer, back-end;Engineer, site reliability         8
# ...                                                  ...       ...
# 88872  Academic researcher;Designer;Developer, game o...         9
# 88875                                Academic researcher         1
# 88877  Developer, back-end;Developer, desktop or ente...        38
# 88878                                                NaN       NaN
# 88882                                                NaN         8
#
#                  Age1stCode      YearsCodePro           CareerSat  \
# 0                        10               NaN                 NaN
# 2                        22                 1  Slightly satisfied
# 4                        14                 9   Very dissatisfied
# 5                        15                 3      Very satisfied
# 7                        16               NaN                 NaN
# ...                     ...               ...                 ...
# 88872                    16                 3                 NaN
# 88875  Younger than 5 years  Less than 1 year                 NaN
# 88877                    10                38                 NaN
# 88878                   NaN               NaN                 NaN
# 88882                    11                 3                 NaN
#
#                       JobSat              MgrIdiot  MgrMoney   MgrWant  \
# 0                        NaN                   NaN       NaN       NaN
# 2         Slightly satisfied  Not at all confident  Not sure  Not sure
# 4      Slightly dissatisfied    Somewhat confident       Yes        No
# 5         Slightly satisfied        Very confident        No       Yes
# 7                        NaN                   NaN       NaN       NaN
# ...                      ...                   ...       ...       ...
# 88872                    NaN    Somewhat confident        No  Not sure
# 88875                    NaN        Very confident  Not sure       Yes
# 88877                    NaN                   NaN       NaN       NaN
# 88878                    NaN                   NaN       NaN       NaN
# 88882                    NaN                   NaN       NaN       NaN
#
#                                                  JobSeek  \
# 0                                                    NaN
# 2      I’m not actively looking, but I am open to new...
# 4           I am not interested in new job opportunities
# 5           I am not interested in new job opportunities
# 7                                                    NaN
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                LastHireDate  \
# 0                       NaN
# 2             1-2 years ago
# 4      Less than a year ago
# 5             1-2 years ago
# 7                       NaN
# ...                     ...
# 88872                   NaN
# 88875                   NaN
# 88877                   NaN
# 88878                   NaN
# 88882                   NaN
#
#                                                  LastInt FizzBuzz  \
# 0                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# 5      Write any code;Complete a take-home project;In...       No
# 7                                                    NaN      NaN
# ...                                                  ...      ...
# 88872                                                NaN      NaN
# 88875                                                NaN      NaN
# 88877                                                NaN      NaN
# 88878                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               JobFactors  \
# 0                                                    NaN
# 2      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# 5      Financial performance or funding status of the...
# 7                                                    NaN
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                                             ResumeUpdate CurrencySymbol  \
# 0                                                    NaN            NaN
# 2                       I was preparing for a job search            THB
# 4                       I was preparing for a job search            UAH
# 5      I heard about a job opportunity (from a recrui...            CAD
# 7                                                    NaN            NaN
# ...                                                  ...            ...
# 88872                                                NaN            NaN
# 88875                                                NaN            NaN
# 88877                                                NaN            NaN
# 88878                                                NaN            NaN
# 88882                                                NaN            NaN
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                    NaN        NaN      NaN            NaN          NaN
# 2              Thai baht    23000.0  Monthly         8820.0         40.0
# 4      Ukrainian hryvnia        NaN      NaN            NaN         55.0
# 5        Canadian dollar    40000.0  Monthly       366420.0         15.0
# 7                    NaN        NaN      NaN            NaN          NaN
# ...                  ...        ...      ...            ...          ...
# 88872                NaN        NaN      NaN            NaN          NaN
# 88875                NaN        NaN      NaN            NaN          NaN
# 88877                NaN        NaN      NaN            NaN          NaN
# 88878                NaN        NaN      NaN            NaN          NaN
# 88882                NaN        NaN      NaN            NaN          NaN
#
#                                                 WorkPlan  \
# 0                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# 5      There's no schedule or spec; I work on what se...
# 7                                                    NaN
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                                            WorkChallenge  \
# 0                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 4      Being tasked with non-development work;Inadequ...
# 5                                                    NaN
# 7                                                    NaN
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                                NaN
# 88878                                                NaN
# 88882                                                NaN
#
#                              WorkRemote WorkLoc                  ImpSyn  \
# 0                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 4                 A few days each month  Office  A little above average
# 5                 A few days each month    Home  A little above average
# 7                                   NaN     NaN                     NaN
# ...                                 ...     ...                     ...
# 88872                               NaN     NaN                     NaN
# 88875                               NaN     NaN                     NaN
# 88877                               NaN     NaN                     NaN
# 88878                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        CodeRev  CodeRevHrs  \
# 0                                          NaN         NaN
# 2                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# 5                                           No         NaN
# 7                                          NaN         NaN
# ...                                        ...         ...
# 88872                                      NaN         NaN
# 88875                                      NaN         NaN
# 88877                                      NaN         NaN
# 88878                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                                                UnitTests PurchaseHow  \
# 0                                                    NaN         NaN
# 2                              No, but I think we should    Not sure
# 4                          Yes, it's part of our process    Not sure
# 5      Yes, it's not part of our process but the deve...    Not sure
# 7                                                    NaN         NaN
# ...                                                  ...         ...
# 88872                                                NaN         NaN
# 88875                                                NaN         NaN
# 88877                                                NaN         NaN
# 88878                                                NaN         NaN
# 88882                                                NaN         NaN
#
#                         PurchaseWhat  \
# 0                                NaN
# 2      I have little or no influence
# 4      I have little or no influence
# 5      I have little or no influence
# 7                                NaN
# ...                              ...
# 88872                            NaN
# 88875                            NaN
# 88877                            NaN
# 88878                            NaN
# 88882                            NaN
#
#                                       LanguageWorkedWith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 2                                               HTML/CSS
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 5                                             Java;R;SQL
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...                                                  ...
# 88872           C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88875                           HTML/CSS;Java;JavaScript
# 88877  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   LanguageDesireNextYear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                                        Elixir;HTML/CSS
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 5                                       Python;Scala;SQL
# 7      Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# ...                                                  ...
# 88872                            C++;HTML/CSS;PHP;Python
# 88875                                                NaN
# 88877  Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                       DatabaseWorkedWith  \
# 0                                                 SQLite
# 2                                             PostgreSQL
# 4       Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 5                                     MongoDB;PostgreSQL
# 7      Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# ...                                                  ...
# 88872                                              MySQL
# 88875                                                NaN
# 88877                                                NaN
# 88878                                    Firebase;SQLite
# 88882        DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   DatabaseDesireNextYear  \
# 0                                                  MySQL
# 2                                             PostgreSQL
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 5                                             PostgreSQL
# 7      Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# ...                                                  ...
# 88872                                              MySQL
# 88875                                                NaN
# 88877                                                NaN
# 88878                              Firebase;MySQL;SQLite
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                                 PlatformWorkedWith  \
# 0                                    MacOS;Windows
# 2                                              NaN
# 4                Android;Linux;MacOS;Slack;Windows
# 5      Android;Google Cloud Platform;Linux;Windows
# 7              AWS;Docker;Heroku;Linux;MacOS;Slack
# ...                                            ...
# 88872                      Android;Linux;WordPress
# 88875                        Google Cloud Platform
# 88877                                        Linux
# 88878                                        Linux
# 88882                    iOS;Linux;MacOS;WordPress
#
#                                   PlatformDesireNextYear  \
# 0                                Android;Arduino;Windows
# 2                                                    NaN
# 4                  Android;Docker;Kubernetes;Linux;Slack
# 5            Android;Google Cloud Platform;Linux;Windows
# 7      Android;Arduino;AWS;Docker;Google Cloud Platfo...
# ...                                                  ...
# 88872                                      Android;Linux
# 88875                                                NaN
# 88877                                 Linux;Raspberry Pi
# 88878                        Google Cloud Platform;Linux
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 WebFrameWorkedWith  \
# 0                                     Django;Flask
# 2                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# 5                                              NaN
# 7                    Express;Flask;React.js;Spring
# ...                                            ...
# 88872                                       jQuery
# 88875                                    Other(s):
# 88877                                     React.js
# 88878                                       jQuery
# 88882                       Django;jQuery;React.js
#
#                      WebFrameDesireNextYear      MiscTechWorkedWith  \
# 0                              Flask;jQuery                 Node.js
# 2                                 Other(s):                     NaN
# 4              Flask;jQuery;React.js;Spring         Cordova;Node.js
# 5                                       NaN                  Hadoop
# 7      Django;Express;Flask;React.js;Vue.js   Hadoop;Node.js;Pandas
# ...                                     ...                     ...
# 88872                                jQuery              TensorFlow
# 88875                                   NaN               Other(s):
# 88877                                Vue.js                 Node.js
# 88878                         jQuery;Vue.js                 Node.js
# 88882                                Django  Unity 3D;Unreal Engine
#
#                                   MiscTechDesireNextYear  \
# 0                                                Node.js
# 2                                                    NaN
# 4               Apache Spark;Hadoop;Node.js;React Native
# 5                      Hadoop;Pandas;TensorFlow;Unity 3D
# 7      Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# 88877                                            Ansible
# 88878                React Native;Unity 3D;Unreal Engine
# 88882                                                NaN
#
#                                               DevEnviron        OpSys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# 5      Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 7      Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# ...                                                  ...          ...
# 88872                                                Vim  Linux-based
# 88875                                     Android Studio      Windows
# 88877                                                Vim  Linux-based
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                               Containers BlockchainOrg  \
# 0                                I do not use containers           NaN
# 2                                I do not use containers           NaN
# 4                 Outside of work, for personal projects    Not at all
# 5                                I do not use containers    Not at all
# 7      Development;Testing;Production;Outside of work...           NaN
# ...                                                  ...           ...
# 88872                            I do not use containers           NaN
# 88875                                        Development           NaN
# 88877                            I do not use containers           NaN
# 88878                            I do not use containers           NaN
# 88882                                         Production           NaN
#
#                                             BlockchainIs BetterLife  \
# 0                                                    NaN        Yes
# 2                                                    NaN        Yes
# 4                                                    NaN        Yes
# 5                                                    NaN         No
# 7      Useful across many domains and could change ma...        Yes
# ...                                                  ...        ...
# 88872                                      A passing fad         No
# 88875  Useful across many domains and could change ma...        Yes
# 88877                  An irresponsible use of resources         No
# 88878  Useful across many domains and could change ma...        Yes
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        ITperson  OffOn  \
# 0      Fortunately, someone else has that title    Yes
# 2                                           Yes    Yes
# 4                                      Also Yes    Yes
# 5                                           Yes     No
# 7                                          SIGH    Yes
# ...                                         ...    ...
# 88872                                       Yes    Yes
# 88875                                  Also Yes  What?
# 88877                                       NaN    Yes
# 88878                                       Yes  What?
# 88882                                  Also Yes    Yes
#
#                     SocialMedia              Extraversion ScreenName  \
# 0                       Twitter                    Online   Username
# 2                        Reddit  In real life (in person)   Username
# 4                      Facebook  In real life (in person)   Username
# 5                       YouTube  In real life (in person)      Login
# 7                       YouTube  In real life (in person)     Handle
# ...                         ...                       ...        ...
# 88872                   YouTube  In real life (in person)      Login
# 88875                   Twitter                   Neither   Username
# 88877  I don't use social media  In real life (in person)   Username
# 88878                   YouTube                       NaN   Username
# 88882                  WhatsApp  In real life (in person)        NaN
#
#              SOVisit1st                                        SOVisitFreq  \
# 0                  2017                    A few times per month or weekly
# 2                  2011                               A few times per week
# 4      I don't remember                             Multiple times per day
# 5                  2011                    A few times per month or weekly
# 7                  2012                               A few times per week
# ...                 ...                                                ...
# 88872              2009                    A few times per month or weekly
# 88875               NaN  I have never visited Stack Overflow (before to...
# 88877  I don't remember                    A few times per month or weekly
# 88878  I don't remember                               A few times per week
# 88882              2012                              Daily or almost daily
#
#                                                SOVisitTo  \
# 0      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 4                     Find answers to specific questions
# 5                     Find answers to specific questions
# 7      Find answers to specific questions;Learn how t...
# ...                                                  ...
# 88872                 Find answers to specific questions
# 88875  Get a sense of belonging to the developer comm...
# 88877                 Find answers to specific questions
# 88878  Find answers to specific questions;Learn how t...
# 88882  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer                             SOTimeSaved  \
# 0               3-5 times per week          Stack Overflow was much faster
# 2              6-10 times per week                They were about the same
# 4      More than 10 times per week          Stack Overflow was much faster
# 5          Less than once per week      Stack Overflow was slightly faster
# 7          Less than once per week      Stack Overflow was slightly faster
# ...                            ...                                     ...
# 88872           1-2 times per week          Stack Overflow was much faster
# 88875      Less than once per week  The other resource was slightly faster
# 88877           1-2 times per week                They were about the same
# 88878           3-5 times per week      Stack Overflow was slightly faster
# 88882          6-10 times per week          Stack Overflow was much faster
#
#        SOHowMuchTime SOAccount  \
# 0      31-60 minutes        No
# 2                NaN       Yes
# 4                NaN       Yes
# 5        60+ minutes       Yes
# 7      11-30 minutes       Yes
# ...              ...       ...
# 88872  31-60 minutes       Yes
# 88875    60+ minutes       NaN
# 88877            NaN       Yes
# 88878  11-30 minutes       Yes
# 88882  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 0                                                    NaN
# 2                    Less than once per month or monthly
# 4                        A few times per month or weekly
# 5      I have never participated in Q&A on Stack Over...
# 7                    Less than once per month or monthly
# ...                                                  ...
# 88872                    A few times per month or weekly
# 88875                                                NaN
# 88877  I have never participated in Q&A on Stack Over...
# 88878  I have never participated in Q&A on Stack Over...
# 88882                    A few times per month or weekly
#
#                                                   SOJobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 2                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# 5      No, I knew that Stack Overflow had a job board...
# 7                                                    Yes
# ...                                                  ...
# 88872  No, I knew that Stack Overflow had a job board...
# 88875  No, I didn't know that Stack Overflow had a jo...
# 88877                                                Yes
# 88878  No, I knew that Stack Overflow had a job board...
# 88882                                                Yes
#
#                                                 EntTeams           SOComm  \
# 0                    No, and I don't know what those are          Neutral
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# 5                    No, and I don't know what those are   No, not really
# 7                    No, and I don't know what those are  Yes, definitely
# ...                                                  ...              ...
# 88872                No, and I don't know what those are          Neutral
# 88875                No, and I don't know what those are          Neutral
# 88877                No, and I don't know what those are   No, not really
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                            WelcomeChange  \
# 0                Just as welcome now as I felt last year
# 2                Just as welcome now as I felt last year
# 4                Just as welcome now as I felt last year
# 5                Just as welcome now as I felt last year
# 7                  A lot more welcome now than last year
# ...                                                  ...
# 88872            Just as welcome now as I felt last year
# 88875  Not applicable - I did not use Stack Overflow ...
# 88877            Just as welcome now as I felt last year
# 88878                                                NaN
# 88882           Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# 5      Tech articles written by other developers;Indu...  28.0    Man    No
# 7      Tech articles written by other developers;Indu...  24.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88872                                                NaN  25.0    NaN    No
# 88875       Courses on technologies you're interested in   NaN    Man    No
# 88877                                                NaN   NaN    Man    No
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 2      Straight / Heterosexual
# 4      Straight / Heterosexual
# 5      Straight / Heterosexual
# 7      Straight / Heterosexual
# ...                        ...
# 88872  Straight / Heterosexual
# 88875  Straight / Heterosexual
# 88877  Straight / Heterosexual
# 88878                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 2                                                    NaN        Yes
# 4               White or of European descent;Multiracial         No
# 5                                             East Asian         No
# 7                                                    NaN        NaN
# ...                                                  ...        ...
# 88872                       White or of European descent         No
# 88875                                                NaN        Yes
# 88877                                                NaN         No
# 88878                                                NaN         No
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 4      Appropriate in length                        Easy
# 5                   Too long  Neither easy nor difficult
# 7      Appropriate in length  Neither easy nor difficult
# ...                      ...                         ...
# 88872  Appropriate in length                        Easy
# 88875              Too short  Neither easy nor difficult
# 88877              Too short  Neither easy nor difficult
# 88878  Appropriate in length                        Easy
# 88882  Appropriate in length                        Easy
#
# [71257 rows x 85 columns]

# %%
high_salary = df[df['ConvertedComp'] > 70000]
high_salary
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 8               9                     I am a developer by profession      Yes
# 12             13                     I am a developer by profession      Yes
# 15             16                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88323       88876                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
# 88326       88879                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 5                                                  Never
# 8                             Once a month or more often
# 12     Less than once a month but more than once per ...
# 15                                                 Never
# 21                               Less than once per year
# ...                                                  ...
# 88323                                              Never
# 88324                            Less than once per year
# 88325                            Less than once per year
# 88326                                              Never
# 88329                                              Never
#
#                                               OpenSource          Employment  \
# 5      The quality of OSS and closed source software ...  Employed full-time
# 8      The quality of OSS and closed source software ...  Employed full-time
# 12     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 15     The quality of OSS and closed source software ...  Employed full-time
# 21     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...                                                  ...                 ...
# 88323  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 88324  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 88325  The quality of OSS and closed source software ...  Employed full-time
# 88326  The quality of OSS and closed source software ...  Employed full-time
# 88329  OSS is, on average, of LOWER quality than prop...  Employed full-time
#
#               Country         Student  \
# 5              Canada              No
# 8         New Zealand              No
# 12      United States              No
# 15     United Kingdom              No
# 21      United States              No
# ...               ...             ...
# 88323   United States              No
# 88324   United States              No
# 88325   United States              No
# 88326         Finland              No
# 88329     Netherlands  Yes, full-time
#
#                                                  EdLevel  \
# 5               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8      Some college/university study without earning ...
# 12           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 21     Some college/university study without earning ...
# ...                                                  ...
# 88323           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88324           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88325           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88326        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88329        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                           UndergradMajor  \
# 5                              Mathematics or statistics
# 8      Computer science, computer engineering, or sof...
# 12     Computer science, computer engineering, or sof...
# 15                                                   NaN
# 21                                                   NaN
# ...                                                  ...
# 88323  Computer science, computer engineering, or sof...
# 88324  Computer science, computer engineering, or sof...
# 88325  Computer science, computer engineering, or sof...
# 88326  Computer science, computer engineering, or sof...
# 88329  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 5      Taken an online course in programming or softw...
# 8      Taken an online course in programming or softw...
# 12     Taken an online course in programming or softw...
# 15     Taken an online course in programming or softw...
# 21     Taken an online course in programming or softw...
# ...                                                  ...
# 88323  Received on-the-job training in software devel...
# 88324  Taken an online course in programming or softw...
# 88325  Taken an online course in programming or softw...
# 88326  Taught yourself a new language, framework, or ...
# 88329  Participated in online coding competitions (e....
#
#                         OrgSize  \
# 5                           NaN
# 8            10 to 19 employees
# 12           10 to 19 employees
# 15         100 to 499 employees
# 21     10,000 or more employees
# ...                         ...
# 88323  10,000 or more employees
# 88324      500 to 999 employees
# 88325        20 to 99 employees
# 88326        20 to 99 employees
# 88329      100 to 499 employees
#
#                                                  DevType YearsCode Age1stCode  \
# 5      Data or business analyst;Data scientist or mac...        13         15
# 8      Database administrator;Developer, back-end;Dev...        12         11
# 12     Data or business analyst;Database administrato...        17         11
# 15                                 Developer, full-stack        10         17
# 21     Data or business analyst;Designer;Developer, b...        35         12
# ...                                                  ...       ...        ...
# 88323    Developer, back-end;Developer, game or graphics         8         15
# 88324  Data scientist or machine learning specialist;...        31         18
# 88325  Developer, back-end;Developer, front-end;Devel...        12         14
# 88326  Developer, desktop or enterprise applications;...        17         16
# 88329  Academic researcher;Database administrator;Dev...        10         15
#
#       YearsCodePro              CareerSat                              JobSat  \
# 5                3         Very satisfied                  Slightly satisfied
# 8                4     Slightly satisfied                  Slightly satisfied
# 12               8         Very satisfied                      Very satisfied
# 15               3         Very satisfied                  Slightly satisfied
# 21              18     Slightly satisfied                   Very dissatisfied
# ...            ...                    ...                                 ...
# 88323            2         Very satisfied                  Slightly satisfied
# 88324           28         Very satisfied                      Very satisfied
# 88325            3         Very satisfied                      Very satisfied
# 88326            7     Slightly satisfied  Neither satisfied nor dissatisfied
# 88329            8  Slightly dissatisfied                   Very dissatisfied
#
#                    MgrIdiot  MgrMoney                 MgrWant  \
# 5            Very confident        No                     Yes
# 8        Somewhat confident        No                Not sure
# 12                      NaN       NaN                     NaN
# 15       Somewhat confident        No                      No
# 21       Somewhat confident        No                      No
# ...                     ...       ...                     ...
# 88323    Somewhat confident       Yes                Not sure
# 88324        Very confident       Yes                     Yes
# 88325        Very confident       Yes                     Yes
# 88326  Not at all confident  Not sure  I am already a manager
# 88329  Not at all confident       Yes                     Yes
#
#                                                  JobSeek  \
# 5           I am not interested in new job opportunities
# 8      I’m not actively looking, but I am open to new...
# 12          I am not interested in new job opportunities
# 15     I’m not actively looking, but I am open to new...
# 21     I’m not actively looking, but I am open to new...
# ...                                                  ...
# 88323  I’m not actively looking, but I am open to new...
# 88324  I’m not actively looking, but I am open to new...
# 88325       I am not interested in new job opportunities
# 88326  I’m not actively looking, but I am open to new...
# 88329  I’m not actively looking, but I am open to new...
#
#                 LastHireDate  \
# 5              1-2 years ago
# 8       Less than a year ago
# 12             3-4 years ago
# 15             3-4 years ago
# 21     More than 4 years ago
# ...                      ...
# 88323          1-2 years ago
# 88324  More than 4 years ago
# 88325   Less than a year ago
# 88326  More than 4 years ago
# 88329   Less than a year ago
#
#                                                  LastInt FizzBuzz  \
# 5      Write any code;Complete a take-home project;In...       No
# 8      Write any code;Interview with people in peer r...      Yes
# 12     Complete a take-home project;Interview with pe...      Yes
# 15     Interview with people in senior / management r...      Yes
# 21     Interview with people in senior / management r...       No
# ...                                                  ...      ...
# 88323         Write code by hand (e.g., on a whiteboard)       No
# 88324  Interview with people in senior / management r...      Yes
# 88325  Write any code;Write code by hand (e.g., on a ...       No
# 88326  Complete a take-home project;Interview with pe...       No
# 88329  Write any code;Complete a take-home project;In...       No
#
#                                               JobFactors  \
# 5      Financial performance or funding status of the...
# 8      Financial performance or funding status of the...
# 12     Languages, frameworks, and other technologies ...
# 15     Languages, frameworks, and other technologies ...
# 21     Industry that I'd be working in;Financial perf...
# ...                                                  ...
# 88323  Office environment or company culture;Remote w...
# 88324  Industry that I'd be working in;Languages, fra...
# 88325  Languages, frameworks, and other technologies ...
# 88326  Languages, frameworks, and other technologies ...
# 88329  Office environment or company culture;Remote w...
#
#                                             ResumeUpdate CurrencySymbol  \
# 5      I heard about a job opportunity (from a recrui...            CAD
# 8                       I was preparing for a job search            NZD
# 12                      I was preparing for a job search            USD
# 15     I heard about a job opportunity (from a recrui...            GBP
# 21     I had a negative experience or interaction at ...            USD
# ...                                                  ...            ...
# 88323   My job status changed (promotion, new job, etc.)            USD
# 88324  I heard about a job opportunity (from a recrui...            USD
# 88325                   I was preparing for a job search            USD
# 88326  I had a negative experience or interaction at ...            EUR
# 88329  I had a negative experience or interaction at ...            EUR
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 5           Canadian dollar    40000.0  Monthly       366420.0        15.00
# 8        New Zealand dollar   138000.0   Yearly        95179.0        32.00
# 12     United States dollar    90000.0   Yearly        90000.0        40.00
# 15           Pound sterling    29000.0  Monthly       455352.0        40.00
# 21     United States dollar   103000.0   Yearly       103000.0        40.00
# ...                     ...        ...      ...            ...          ...
# 88323  United States dollar   180000.0   Yearly       180000.0        40.00
# 88324  United States dollar   239000.0   Weekly      2000000.0        45.00
# 88325  United States dollar   130000.0   Yearly       130000.0        40.00
# 88326         European Euro     6000.0  Monthly        82488.0        37.75
# 88329         European Euro    42768.0  Monthly       588012.0        40.00
#
#                                                 WorkPlan  \
# 5      There's no schedule or spec; I work on what se...
# 8      There is a schedule and/or spec (made by me or...
# 12     There is a schedule and/or spec (made by me or...
# 15     There is a schedule and/or spec (made by me or...
# 21     There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88323  There is a schedule and/or spec (made by me or...
# 88324  There is a schedule and/or spec (made by me or...
# 88325  There is a schedule and/or spec (made by me or...
# 88326  There is a schedule and/or spec (made by me or...
# 88329  There is a schedule and/or spec (made by me or...
#
#                                            WorkChallenge  \
# 5                                                    NaN
# 8      Being tasked with non-development work;Inadequ...
# 12     Meetings;Non-work commitments (parenting, scho...
# 15     Being tasked with non-development work;Distrac...
# 21     Being tasked with non-development work;Meeting...
# ...                                                  ...
# 88323  Distracting work environment;Meetings;Time spe...
# 88324        Meetings;Not enough people for the workload
# 88325  Non-work commitments (parenting, school work, ...
# 88326  Being tasked with non-development work;Distrac...
# 88329  Distracting work environment;Lack of support f...
#
#                                               WorkRemote WorkLoc  \
# 5                                  A few days each month    Home
# 8                       Less than once per month / Never  Office
# 12     All or almost all the time (I'm full-time remote)    Home
# 15                                 A few days each month    Home
# 21     Less than half the time, but at least one day ...    Home
# ...                                                  ...     ...
# 88323  Less than half the time, but at least one day ...  Office
# 88324                   Less than once per month / Never  Office
# 88325                              A few days each month  Office
# 88326                   Less than once per month / Never    Home
# 88329                   Less than once per month / Never    Home
#
#                        ImpSyn                                  CodeRev  \
# 5      A little above average                                       No
# 8      A little above average  Yes, because I see value in code review
# 12     A little above average  Yes, because I see value in code review
# 15                    Average                                       No
# 21                    Average                                       No
# ...                       ...                                      ...
# 88323                 Average  Yes, because I see value in code review
# 88324       Far above average  Yes, because I see value in code review
# 88325       Far above average  Yes, because I see value in code review
# 88326       Far above average  Yes, because I see value in code review
# 88329       Far above average  Yes, because I see value in code review
#
#        CodeRevHrs                                          UnitTests  \
# 5             NaN  Yes, it's not part of our process but the deve...
# 8            12.0  Yes, it's not part of our process but the deve...
# 12            5.0                          No, but I think we should
# 15            NaN                          No, but I think we should
# 21            NaN                          No, but I think we should
# ...           ...                                                ...
# 88323         3.0                      Yes, it's part of our process
# 88324         5.0                          No, but I think we should
# 88325         3.0                          No, and I'm glad we don't
# 88326        10.0                      Yes, it's part of our process
# 88329         5.0                      Yes, it's part of our process
#
#                                              PurchaseHow  \
# 5                                               Not sure
# 8                                               Not sure
# 12     Developers and management have nearly equal in...
# 15     Developers and management have nearly equal in...
# 21     The CTO, CIO, or other management purchase new...
# ...                                                  ...
# 88323                                           Not sure
# 88324  Developers and management have nearly equal in...
# 88325  Developers and management have nearly equal in...
# 88326  Developers and management have nearly equal in...
# 88329                                           Not sure
#
#                            PurchaseWhat  \
# 5         I have little or no influence
# 8                 I have some influence
# 12     I have a great deal of influence
# 15                I have some influence
# 21        I have little or no influence
# ...                                 ...
# 88323     I have little or no influence
# 88324             I have some influence
# 88325             I have some influence
# 88326     I have little or no influence
# 88329     I have little or no influence
#
#                                       LanguageWorkedWith  \
# 5                                             Java;R;SQL
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                                                  ...
# 88323  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325               HTML/CSS;JavaScript;Scala;TypeScript
# 88326                   Bash/Shell/PowerShell;C++;Python
# 88329             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#                                   LanguageDesireNextYear  \
# 5                                       Python;Scala;SQL
# 8      Bash/Shell/PowerShell;C;HTML/CSS;JavaScript;Ru...
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 15     C#;HTML/CSS;JavaScript;TypeScript;WebAssembly;...
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                                                  ...
# 88323                               C#;Java;Kotlin;Scala
# 88324  Bash/Shell/PowerShell;Clojure;HTML/CSS;Java;Ja...
# 88325                   JavaScript;Rust;Scala;TypeScript
# 88326                                                C++
# 88329                             C#;Java;JavaScript;PHP
#
#                        DatabaseWorkedWith  \
# 5                      MongoDB;PostgreSQL
# 8              DynamoDB;PostgreSQL;SQLite
# 12      Couchbase;DynamoDB;Firebase;MySQL
# 15     MongoDB;Microsoft SQL Server;MySQL
# 21       Elasticsearch;MySQL;Oracle;Redis
# ...                                   ...
# 88323                      DynamoDB;MySQL
# 88324                              Oracle
# 88325                          PostgreSQL
# 88326                                 NaN
# 88329                  MariaDB;PostgreSQL
#
#                                   DatabaseDesireNextYear  \
# 5                                             PostgreSQL
# 8                                PostgreSQL;Redis;SQLite
# 12                                  Firebase;MySQL;Redis
# 15     Elasticsearch;MongoDB;Microsoft SQL Server;SQLite
# 21                      Elasticsearch;MySQL;Oracle;Redis
# ...                                                  ...
# 88323                                           DynamoDB
# 88324                                             Oracle
# 88325                                         PostgreSQL
# 88326                                                NaN
# 88329                                 MariaDB;PostgreSQL
#
#                                       PlatformWorkedWith  \
# 5            Android;Google Cloud Platform;Linux;Windows
# 8                    AWS;Docker;Heroku;Linux;MacOS;Slack
# 12     Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# 15                                                   NaN
# 21                     Docker;Linux;Raspberry Pi;Windows
# ...                                                  ...
# 88323                            AWS;Linux;MacOS;Windows
# 88324  Docker;iOS;Kubernetes;Linux;Slack;Windows;Othe...
# 88325                                              Slack
# 88326                              Android;Linux;Windows
# 88329       Android;Arduino;Linux;Raspberry Pi;WordPress
#
#                                   PlatformDesireNextYear  \
# 5            Android;Google Cloud Platform;Linux;Windows
# 8          AWS;Docker;Heroku;Linux;MacOS;Slack;Other(s):
# 12     Android;AWS;Docker;IBM Cloud or Watson;Linux;S...
# 15             AWS;Google Cloud Platform;Microsoft Azure
# 21                     Docker;Linux;Raspberry Pi;Windows
# ...                                                  ...
# 88323                Android;AWS;iOS;Linux;MacOS;Windows
# 88324                                          Other(s):
# 88325                                              Slack
# 88326                                      Linux;Windows
# 88329       Android;Arduino;Linux;Raspberry Pi;WordPress
#
#                                      WebFrameWorkedWith  \
# 5                                                   NaN
# 8                       Express;Ruby on Rails;Other(s):
# 12     Angular/Angular.js;ASP.NET;Express;jQuery;Vue.js
# 15                    Angular/Angular.js;ASP.NET;jQuery
# 21                     Angular/Angular.js;Ruby on Rails
# ...                                                 ...
# 88323                                               NaN
# 88324                                         Other(s):
# 88325                                React.js;Other(s):
# 88326                                               NaN
# 88329                                   jQuery;React.js
#
#                     WebFrameDesireNextYear  \
# 5                                      NaN
# 8          Express;Ruby on Rails;Other(s):
# 12                          Express;Vue.js
# 15     Angular/Angular.js;ASP.NET;React.js
# 21        Angular/Angular.js;Ruby on Rails
# ...                                    ...
# 88323                                  NaN
# 88324                            Other(s):
# 88325                   React.js;Other(s):
# 88326                                  NaN
# 88329                      jQuery;React.js
#
#                            MiscTechWorkedWith  \
# 5                                      Hadoop
# 8                            Node.js;Unity 3D
# 12                            Node.js;Xamarin
# 15                     .NET;.NET Core;Node.js
# 21                                    Node.js
# ...                                       ...
# 88323  Apache Spark;Hadoop;.NET Core;Unity 3D
# 88324                            Apache Spark
# 88325                                 Node.js
# 88326                                     NaN
# 88329                                Unity 3D
#
#                                   MiscTechDesireNextYear  \
# 5                      Hadoop;Pandas;TensorFlow;Unity 3D
# 8                                                Node.js
# 12                                    Node.js;TensorFlow
# 15                        .NET Core;Node.js;React Native
# 21                                               Node.js
# ...                                                  ...
# 88323  Apache Spark;CryEngine;Hadoop;.NET;.NET Core;T...
# 88324                                       Apache Spark
# 88325                                            Node.js
# 88326                  TensorFlow;Unity 3D;Unreal Engine
# 88329                                           Unity 3D
#
#                                               DevEnviron        OpSys  \
# 5      Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 8                                                    Vim        MacOS
# 12            Vim;Visual Studio;Visual Studio Code;Xcode      Windows
# 15                      Visual Studio;Visual Studio Code      Windows
# 21         Sublime Text;Visual Studio;Visual Studio Code      Windows
# ...                                                  ...          ...
# 88323  IntelliJ;Notepad++;PyCharm;Sublime Text;Vim;Vi...        MacOS
# 88324  Atom;Emacs;IntelliJ;IPython / Jupyter;PyCharm;...      Windows
# 88325           IntelliJ;Sublime Text;Visual Studio Code        MacOS
# 88326         Android Studio;Notepad++;Vim;Visual Studio      Windows
# 88329  Android Studio;IntelliJ;Notepad++;Vim;Visual S...  Linux-based
#
#                                    Containers  \
# 5                     I do not use containers
# 8              Development;Testing;Production
# 12             Development;Testing;Production
# 15                    I do not use containers
# 21     Outside of work, for personal projects
# ...                                       ...
# 88323                 I do not use containers
# 88324          Development;Testing;Production
# 88325                              Production
# 88326                 I do not use containers
# 88329                 I do not use containers
#
#                                     BlockchainOrg  \
# 5                                      Not at all
# 8                                      Not at all
# 12                                     Not at all
# 15                                     Not at all
# 21                                     Not at all
# ...                                           ...
# 88323                                         NaN
# 88324  Implementing cryptocurrency-based products
# 88325                                  Not at all
# 88326                                  Not at all
# 88329                                  Not at all
#
#                                             BlockchainIs BetterLife ITperson  \
# 5                                                    NaN         No      Yes
# 8                      An irresponsible use of resources         No     SIGH
# 12     Useful for decentralized currency (i.e., Bitcoin)        Yes      Yes
# 15                                         A passing fad         No     SIGH
# 21                                                   NaN        Yes      Yes
# ...                                                  ...        ...      ...
# 88323                                      A passing fad        Yes     SIGH
# 88324                  An irresponsible use of resources        Yes      Yes
# 88325  Useful for decentralized currency (i.e., Bitcoin)        Yes      Yes
# 88326                                      A passing fad        Yes      NaN
# 88329                                      A passing fad        Yes      Yes
#
#       OffOn SocialMedia              Extraversion   ScreenName  \
# 5        No     YouTube  In real life (in person)        Login
# 8       Yes     Twitter  In real life (in person)     Username
# 12      Yes     Twitter  In real life (in person)     Username
# 15       No     YouTube                    Online     Username
# 21      Yes   Instagram                    Online     Username
# ...     ...         ...                       ...          ...
# 88323   Yes      Reddit                   Neither       UserID
# 88324    No    Facebook                    Online  Screen Name
# 88325   Yes     Twitter                    Online     Username
# 88326   NaN     YouTube                   Neither     Username
# 88329   Yes   Instagram                   Neither     Username
#
#              SOVisit1st                      SOVisitFreq  \
# 5                  2011  A few times per month or weekly
# 8                  2013            Daily or almost daily
# 12                 2011           Multiple times per day
# 15                 2010           Multiple times per day
# 21     I don't remember            Daily or almost daily
# ...                 ...                              ...
# 88323              2011  A few times per month or weekly
# 88324               NaN  A few times per month or weekly
# 88325              2010           Multiple times per day
# 88326  I don't remember  A few times per month or weekly
# 88329              2009             A few times per week
#
#                                                SOVisitTo  \
# 5                     Find answers to specific questions
# 8      Find answers to specific questions;Contribute ...
# 12                    Find answers to specific questions
# 15     Find answers to specific questions;Learn how t...
# 21                    Find answers to specific questions
# ...                                                  ...
# 88323                 Find answers to specific questions
# 88324                 Find answers to specific questions
# 88325  Find answers to specific questions;Learn how t...
# 88326                 Find answers to specific questions
# 88329                 Find answers to specific questions
#
#                       SOFindAnswer                         SOTimeSaved  \
# 5          Less than once per week  Stack Overflow was slightly faster
# 8               3-5 times per week            They were about the same
# 12     More than 10 times per week      Stack Overflow was much faster
# 15         Less than once per week      Stack Overflow was much faster
# 21              3-5 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88323           1-2 times per week      Stack Overflow was much faster
# 88324      Less than once per week      Stack Overflow was much faster
# 88325           3-5 times per week      Stack Overflow was much faster
# 88326      Less than once per week  Stack Overflow was slightly faster
# 88329           3-5 times per week  Stack Overflow was slightly faster
#
#        SOHowMuchTime SOAccount  \
# 5        60+ minutes       Yes
# 8                NaN       Yes
# 12     11-30 minutes       Yes
# 15     11-30 minutes       Yes
# 21      0-10 minutes       Yes
# ...              ...       ...
# 88323    60+ minutes       Yes
# 88324  11-30 minutes       Yes
# 88325   0-10 minutes       Yes
# 88326    60+ minutes        No
# 88329  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 5      I have never participated in Q&A on Stack Over...
# 8                    Less than once per month or monthly
# 12                   Less than once per month or monthly
# 15                   Less than once per month or monthly
# 21                                  A few times per week
# ...                                                  ...
# 88323                Less than once per month or monthly
# 88324  I have never participated in Q&A on Stack Over...
# 88325                               A few times per week
# 88326                                                NaN
# 88329                Less than once per month or monthly
#
#                                                   SOJobs  \
# 5      No, I knew that Stack Overflow had a job board...
# 8      No, I knew that Stack Overflow had a job board...
# 12                                                   Yes
# 15                                                   Yes
# 21                                                   Yes
# ...                                                  ...
# 88323  No, I didn't know that Stack Overflow had a jo...
# 88324  No, I knew that Stack Overflow had a job board...
# 88325                                                Yes
# 88326  No, I didn't know that Stack Overflow had a jo...
# 88329  No, I knew that Stack Overflow had a job board...
#
#                                                 EntTeams          SOComm  \
# 5                    No, and I don't know what those are  No, not really
# 8                    No, and I don't know what those are   Yes, somewhat
# 12     No, I've heard of them, but I am not part of a...         Neutral
# 15     No, I've heard of them, but I am not part of a...   Yes, somewhat
# 21                   No, and I don't know what those are   Yes, somewhat
# ...                                                  ...             ...
# 88323                No, and I don't know what those are   Yes, somewhat
# 88324                No, and I don't know what those are   Yes, somewhat
# 88325  No, I've heard of them, but I am not part of a...   Yes, somewhat
# 88326                No, and I don't know what those are  No, not at all
# 88329                No, and I don't know what those are  No, not really
#
#                                            WelcomeChange  \
# 5                Just as welcome now as I felt last year
# 8                Just as welcome now as I felt last year
# 12              Somewhat more welcome now than last year
# 15               Just as welcome now as I felt last year
# 21               Just as welcome now as I felt last year
# ...                                                  ...
# 88323              A lot less welcome now than last year
# 88324           Somewhat more welcome now than last year
# 88325            Just as welcome now as I felt last year
# 88326  Not applicable - I did not use Stack Overflow ...
# 88329            Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 5      Tech articles written by other developers;Indu...  28.0    Man    No
# 8                                                    NaN  23.0    Man    No
# 12     Tech articles written by other developers;Cour...  28.0    Man    No
# 15     Tech articles written by other developers;Indu...  26.0    Man    No
# 21     Tech articles written by other developers;Indu...  47.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88323                                                NaN  23.0    Man    No
# 88324  Tech articles written by other developers;Cour...  48.0    Man    No
# 88325  Tech articles written by other developers;Indu...  26.0    Man    No
# 88326                                                NaN  34.0    Man    No
# 88329                                                NaN   NaN    Man    No
#
#                      Sexuality                     Ethnicity Dependents  \
# 5      Straight / Heterosexual                    East Asian         No
# 8                     Bisexual  White or of European descent         No
# 12     Straight / Heterosexual  White or of European descent        Yes
# 15     Straight / Heterosexual  White or of European descent         No
# 21     Straight / Heterosexual  White or of European descent        Yes
# ...                        ...                           ...        ...
# 88323  Straight / Heterosexual  White or of European descent         No
# 88324  Straight / Heterosexual                   South Asian        Yes
# 88325  Straight / Heterosexual                   South Asian         No
# 88326  Straight / Heterosexual  White or of European descent         No
# 88329  Straight / Heterosexual  White or of European descent        Yes
#
#                 SurveyLength                  SurveyEase
# 5                   Too long  Neither easy nor difficult
# 8      Appropriate in length  Neither easy nor difficult
# 12     Appropriate in length                        Easy
# 15     Appropriate in length  Neither easy nor difficult
# 21     Appropriate in length                        Easy
# ...                      ...                         ...
# 88323  Appropriate in length                        Easy
# 88324               Too long  Neither easy nor difficult
# 88325  Appropriate in length                        Easy
# 88326  Appropriate in length                        Easy
# 88329               Too long                        Easy
#
# [22289 rows x 85 columns]

# %%
high_salary_1 = df['ConvertedComp'] > 70000

# %%
df.loc[high_salary_1]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 8               9                     I am a developer by profession      Yes
# 12             13                     I am a developer by profession      Yes
# 15             16                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88323       88876                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
# 88326       88879                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 5                                                  Never
# 8                             Once a month or more often
# 12     Less than once a month but more than once per ...
# 15                                                 Never
# 21                               Less than once per year
# ...                                                  ...
# 88323                                              Never
# 88324                            Less than once per year
# 88325                            Less than once per year
# 88326                                              Never
# 88329                                              Never
#
#                                               OpenSource          Employment  \
# 5      The quality of OSS and closed source software ...  Employed full-time
# 8      The quality of OSS and closed source software ...  Employed full-time
# 12     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 15     The quality of OSS and closed source software ...  Employed full-time
# 21     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...                                                  ...                 ...
# 88323  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 88324  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 88325  The quality of OSS and closed source software ...  Employed full-time
# 88326  The quality of OSS and closed source software ...  Employed full-time
# 88329  OSS is, on average, of LOWER quality than prop...  Employed full-time
#
#               Country         Student  \
# 5              Canada              No
# 8         New Zealand              No
# 12      United States              No
# 15     United Kingdom              No
# 21      United States              No
# ...               ...             ...
# 88323   United States              No
# 88324   United States              No
# 88325   United States              No
# 88326         Finland              No
# 88329     Netherlands  Yes, full-time
#
#                                                  EdLevel  \
# 5               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8      Some college/university study without earning ...
# 12           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 15           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 21     Some college/university study without earning ...
# ...                                                  ...
# 88323           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88324           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88325           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88326        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88329        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                           UndergradMajor  \
# 5                              Mathematics or statistics
# 8      Computer science, computer engineering, or sof...
# 12     Computer science, computer engineering, or sof...
# 15                                                   NaN
# 21                                                   NaN
# ...                                                  ...
# 88323  Computer science, computer engineering, or sof...
# 88324  Computer science, computer engineering, or sof...
# 88325  Computer science, computer engineering, or sof...
# 88326  Computer science, computer engineering, or sof...
# 88329  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 5      Taken an online course in programming or softw...
# 8      Taken an online course in programming or softw...
# 12     Taken an online course in programming or softw...
# 15     Taken an online course in programming or softw...
# 21     Taken an online course in programming or softw...
# ...                                                  ...
# 88323  Received on-the-job training in software devel...
# 88324  Taken an online course in programming or softw...
# 88325  Taken an online course in programming or softw...
# 88326  Taught yourself a new language, framework, or ...
# 88329  Participated in online coding competitions (e....
#
#                         OrgSize  \
# 5                           NaN
# 8            10 to 19 employees
# 12           10 to 19 employees
# 15         100 to 499 employees
# 21     10,000 or more employees
# ...                         ...
# 88323  10,000 or more employees
# 88324      500 to 999 employees
# 88325        20 to 99 employees
# 88326        20 to 99 employees
# 88329      100 to 499 employees
#
#                                                  DevType YearsCode Age1stCode  \
# 5      Data or business analyst;Data scientist or mac...        13         15
# 8      Database administrator;Developer, back-end;Dev...        12         11
# 12     Data or business analyst;Database administrato...        17         11
# 15                                 Developer, full-stack        10         17
# 21     Data or business analyst;Designer;Developer, b...        35         12
# ...                                                  ...       ...        ...
# 88323    Developer, back-end;Developer, game or graphics         8         15
# 88324  Data scientist or machine learning specialist;...        31         18
# 88325  Developer, back-end;Developer, front-end;Devel...        12         14
# 88326  Developer, desktop or enterprise applications;...        17         16
# 88329  Academic researcher;Database administrator;Dev...        10         15
#
#       YearsCodePro              CareerSat                              JobSat  \
# 5                3         Very satisfied                  Slightly satisfied
# 8                4     Slightly satisfied                  Slightly satisfied
# 12               8         Very satisfied                      Very satisfied
# 15               3         Very satisfied                  Slightly satisfied
# 21              18     Slightly satisfied                   Very dissatisfied
# ...            ...                    ...                                 ...
# 88323            2         Very satisfied                  Slightly satisfied
# 88324           28         Very satisfied                      Very satisfied
# 88325            3         Very satisfied                      Very satisfied
# 88326            7     Slightly satisfied  Neither satisfied nor dissatisfied
# 88329            8  Slightly dissatisfied                   Very dissatisfied
#
#                    MgrIdiot  MgrMoney                 MgrWant  \
# 5            Very confident        No                     Yes
# 8        Somewhat confident        No                Not sure
# 12                      NaN       NaN                     NaN
# 15       Somewhat confident        No                      No
# 21       Somewhat confident        No                      No
# ...                     ...       ...                     ...
# 88323    Somewhat confident       Yes                Not sure
# 88324        Very confident       Yes                     Yes
# 88325        Very confident       Yes                     Yes
# 88326  Not at all confident  Not sure  I am already a manager
# 88329  Not at all confident       Yes                     Yes
#
#                                                  JobSeek  \
# 5           I am not interested in new job opportunities
# 8      I’m not actively looking, but I am open to new...
# 12          I am not interested in new job opportunities
# 15     I’m not actively looking, but I am open to new...
# 21     I’m not actively looking, but I am open to new...
# ...                                                  ...
# 88323  I’m not actively looking, but I am open to new...
# 88324  I’m not actively looking, but I am open to new...
# 88325       I am not interested in new job opportunities
# 88326  I’m not actively looking, but I am open to new...
# 88329  I’m not actively looking, but I am open to new...
#
#                 LastHireDate  \
# 5              1-2 years ago
# 8       Less than a year ago
# 12             3-4 years ago
# 15             3-4 years ago
# 21     More than 4 years ago
# ...                      ...
# 88323          1-2 years ago
# 88324  More than 4 years ago
# 88325   Less than a year ago
# 88326  More than 4 years ago
# 88329   Less than a year ago
#
#                                                  LastInt FizzBuzz  \
# 5      Write any code;Complete a take-home project;In...       No
# 8      Write any code;Interview with people in peer r...      Yes
# 12     Complete a take-home project;Interview with pe...      Yes
# 15     Interview with people in senior / management r...      Yes
# 21     Interview with people in senior / management r...       No
# ...                                                  ...      ...
# 88323         Write code by hand (e.g., on a whiteboard)       No
# 88324  Interview with people in senior / management r...      Yes
# 88325  Write any code;Write code by hand (e.g., on a ...       No
# 88326  Complete a take-home project;Interview with pe...       No
# 88329  Write any code;Complete a take-home project;In...       No
#
#                                               JobFactors  \
# 5      Financial performance or funding status of the...
# 8      Financial performance or funding status of the...
# 12     Languages, frameworks, and other technologies ...
# 15     Languages, frameworks, and other technologies ...
# 21     Industry that I'd be working in;Financial perf...
# ...                                                  ...
# 88323  Office environment or company culture;Remote w...
# 88324  Industry that I'd be working in;Languages, fra...
# 88325  Languages, frameworks, and other technologies ...
# 88326  Languages, frameworks, and other technologies ...
# 88329  Office environment or company culture;Remote w...
#
#                                             ResumeUpdate CurrencySymbol  \
# 5      I heard about a job opportunity (from a recrui...            CAD
# 8                       I was preparing for a job search            NZD
# 12                      I was preparing for a job search            USD
# 15     I heard about a job opportunity (from a recrui...            GBP
# 21     I had a negative experience or interaction at ...            USD
# ...                                                  ...            ...
# 88323   My job status changed (promotion, new job, etc.)            USD
# 88324  I heard about a job opportunity (from a recrui...            USD
# 88325                   I was preparing for a job search            USD
# 88326  I had a negative experience or interaction at ...            EUR
# 88329  I had a negative experience or interaction at ...            EUR
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 5           Canadian dollar    40000.0  Monthly       366420.0        15.00
# 8        New Zealand dollar   138000.0   Yearly        95179.0        32.00
# 12     United States dollar    90000.0   Yearly        90000.0        40.00
# 15           Pound sterling    29000.0  Monthly       455352.0        40.00
# 21     United States dollar   103000.0   Yearly       103000.0        40.00
# ...                     ...        ...      ...            ...          ...
# 88323  United States dollar   180000.0   Yearly       180000.0        40.00
# 88324  United States dollar   239000.0   Weekly      2000000.0        45.00
# 88325  United States dollar   130000.0   Yearly       130000.0        40.00
# 88326         European Euro     6000.0  Monthly        82488.0        37.75
# 88329         European Euro    42768.0  Monthly       588012.0        40.00
#
#                                                 WorkPlan  \
# 5      There's no schedule or spec; I work on what se...
# 8      There is a schedule and/or spec (made by me or...
# 12     There is a schedule and/or spec (made by me or...
# 15     There is a schedule and/or spec (made by me or...
# 21     There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88323  There is a schedule and/or spec (made by me or...
# 88324  There is a schedule and/or spec (made by me or...
# 88325  There is a schedule and/or spec (made by me or...
# 88326  There is a schedule and/or spec (made by me or...
# 88329  There is a schedule and/or spec (made by me or...
#
#                                            WorkChallenge  \
# 5                                                    NaN
# 8      Being tasked with non-development work;Inadequ...
# 12     Meetings;Non-work commitments (parenting, scho...
# 15     Being tasked with non-development work;Distrac...
# 21     Being tasked with non-development work;Meeting...
# ...                                                  ...
# 88323  Distracting work environment;Meetings;Time spe...
# 88324        Meetings;Not enough people for the workload
# 88325  Non-work commitments (parenting, school work, ...
# 88326  Being tasked with non-development work;Distrac...
# 88329  Distracting work environment;Lack of support f...
#
#                                               WorkRemote WorkLoc  \
# 5                                  A few days each month    Home
# 8                       Less than once per month / Never  Office
# 12     All or almost all the time (I'm full-time remote)    Home
# 15                                 A few days each month    Home
# 21     Less than half the time, but at least one day ...    Home
# ...                                                  ...     ...
# 88323  Less than half the time, but at least one day ...  Office
# 88324                   Less than once per month / Never  Office
# 88325                              A few days each month  Office
# 88326                   Less than once per month / Never    Home
# 88329                   Less than once per month / Never    Home
#
#                        ImpSyn                                  CodeRev  \
# 5      A little above average                                       No
# 8      A little above average  Yes, because I see value in code review
# 12     A little above average  Yes, because I see value in code review
# 15                    Average                                       No
# 21                    Average                                       No
# ...                       ...                                      ...
# 88323                 Average  Yes, because I see value in code review
# 88324       Far above average  Yes, because I see value in code review
# 88325       Far above average  Yes, because I see value in code review
# 88326       Far above average  Yes, because I see value in code review
# 88329       Far above average  Yes, because I see value in code review
#
#        CodeRevHrs                                          UnitTests  \
# 5             NaN  Yes, it's not part of our process but the deve...
# 8            12.0  Yes, it's not part of our process but the deve...
# 12            5.0                          No, but I think we should
# 15            NaN                          No, but I think we should
# 21            NaN                          No, but I think we should
# ...           ...                                                ...
# 88323         3.0                      Yes, it's part of our process
# 88324         5.0                          No, but I think we should
# 88325         3.0                          No, and I'm glad we don't
# 88326        10.0                      Yes, it's part of our process
# 88329         5.0                      Yes, it's part of our process
#
#                                              PurchaseHow  \
# 5                                               Not sure
# 8                                               Not sure
# 12     Developers and management have nearly equal in...
# 15     Developers and management have nearly equal in...
# 21     The CTO, CIO, or other management purchase new...
# ...                                                  ...
# 88323                                           Not sure
# 88324  Developers and management have nearly equal in...
# 88325  Developers and management have nearly equal in...
# 88326  Developers and management have nearly equal in...
# 88329                                           Not sure
#
#                            PurchaseWhat  \
# 5         I have little or no influence
# 8                 I have some influence
# 12     I have a great deal of influence
# 15                I have some influence
# 21        I have little or no influence
# ...                                 ...
# 88323     I have little or no influence
# 88324             I have some influence
# 88325             I have some influence
# 88326     I have little or no influence
# 88329     I have little or no influence
#
#                                       LanguageWorkedWith  \
# 5                                             Java;R;SQL
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                                                  ...
# 88323  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325               HTML/CSS;JavaScript;Scala;TypeScript
# 88326                   Bash/Shell/PowerShell;C++;Python
# 88329             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#                                   LanguageDesireNextYear  \
# 5                                       Python;Scala;SQL
# 8      Bash/Shell/PowerShell;C;HTML/CSS;JavaScript;Ru...
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 15     C#;HTML/CSS;JavaScript;TypeScript;WebAssembly;...
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                                                  ...
# 88323                               C#;Java;Kotlin;Scala
# 88324  Bash/Shell/PowerShell;Clojure;HTML/CSS;Java;Ja...
# 88325                   JavaScript;Rust;Scala;TypeScript
# 88326                                                C++
# 88329                             C#;Java;JavaScript;PHP
#
#                        DatabaseWorkedWith  \
# 5                      MongoDB;PostgreSQL
# 8              DynamoDB;PostgreSQL;SQLite
# 12      Couchbase;DynamoDB;Firebase;MySQL
# 15     MongoDB;Microsoft SQL Server;MySQL
# 21       Elasticsearch;MySQL;Oracle;Redis
# ...                                   ...
# 88323                      DynamoDB;MySQL
# 88324                              Oracle
# 88325                          PostgreSQL
# 88326                                 NaN
# 88329                  MariaDB;PostgreSQL
#
#                                   DatabaseDesireNextYear  \
# 5                                             PostgreSQL
# 8                                PostgreSQL;Redis;SQLite
# 12                                  Firebase;MySQL;Redis
# 15     Elasticsearch;MongoDB;Microsoft SQL Server;SQLite
# 21                      Elasticsearch;MySQL;Oracle;Redis
# ...                                                  ...
# 88323                                           DynamoDB
# 88324                                             Oracle
# 88325                                         PostgreSQL
# 88326                                                NaN
# 88329                                 MariaDB;PostgreSQL
#
#                                       PlatformWorkedWith  \
# 5            Android;Google Cloud Platform;Linux;Windows
# 8                    AWS;Docker;Heroku;Linux;MacOS;Slack
# 12     Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# 15                                                   NaN
# 21                     Docker;Linux;Raspberry Pi;Windows
# ...                                                  ...
# 88323                            AWS;Linux;MacOS;Windows
# 88324  Docker;iOS;Kubernetes;Linux;Slack;Windows;Othe...
# 88325                                              Slack
# 88326                              Android;Linux;Windows
# 88329       Android;Arduino;Linux;Raspberry Pi;WordPress
#
#                                   PlatformDesireNextYear  \
# 5            Android;Google Cloud Platform;Linux;Windows
# 8          AWS;Docker;Heroku;Linux;MacOS;Slack;Other(s):
# 12     Android;AWS;Docker;IBM Cloud or Watson;Linux;S...
# 15             AWS;Google Cloud Platform;Microsoft Azure
# 21                     Docker;Linux;Raspberry Pi;Windows
# ...                                                  ...
# 88323                Android;AWS;iOS;Linux;MacOS;Windows
# 88324                                          Other(s):
# 88325                                              Slack
# 88326                                      Linux;Windows
# 88329       Android;Arduino;Linux;Raspberry Pi;WordPress
#
#                                      WebFrameWorkedWith  \
# 5                                                   NaN
# 8                       Express;Ruby on Rails;Other(s):
# 12     Angular/Angular.js;ASP.NET;Express;jQuery;Vue.js
# 15                    Angular/Angular.js;ASP.NET;jQuery
# 21                     Angular/Angular.js;Ruby on Rails
# ...                                                 ...
# 88323                                               NaN
# 88324                                         Other(s):
# 88325                                React.js;Other(s):
# 88326                                               NaN
# 88329                                   jQuery;React.js
#
#                     WebFrameDesireNextYear  \
# 5                                      NaN
# 8          Express;Ruby on Rails;Other(s):
# 12                          Express;Vue.js
# 15     Angular/Angular.js;ASP.NET;React.js
# 21        Angular/Angular.js;Ruby on Rails
# ...                                    ...
# 88323                                  NaN
# 88324                            Other(s):
# 88325                   React.js;Other(s):
# 88326                                  NaN
# 88329                      jQuery;React.js
#
#                            MiscTechWorkedWith  \
# 5                                      Hadoop
# 8                            Node.js;Unity 3D
# 12                            Node.js;Xamarin
# 15                     .NET;.NET Core;Node.js
# 21                                    Node.js
# ...                                       ...
# 88323  Apache Spark;Hadoop;.NET Core;Unity 3D
# 88324                            Apache Spark
# 88325                                 Node.js
# 88326                                     NaN
# 88329                                Unity 3D
#
#                                   MiscTechDesireNextYear  \
# 5                      Hadoop;Pandas;TensorFlow;Unity 3D
# 8                                                Node.js
# 12                                    Node.js;TensorFlow
# 15                        .NET Core;Node.js;React Native
# 21                                               Node.js
# ...                                                  ...
# 88323  Apache Spark;CryEngine;Hadoop;.NET;.NET Core;T...
# 88324                                       Apache Spark
# 88325                                            Node.js
# 88326                  TensorFlow;Unity 3D;Unreal Engine
# 88329                                           Unity 3D
#
#                                               DevEnviron        OpSys  \
# 5      Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 8                                                    Vim        MacOS
# 12            Vim;Visual Studio;Visual Studio Code;Xcode      Windows
# 15                      Visual Studio;Visual Studio Code      Windows
# 21         Sublime Text;Visual Studio;Visual Studio Code      Windows
# ...                                                  ...          ...
# 88323  IntelliJ;Notepad++;PyCharm;Sublime Text;Vim;Vi...        MacOS
# 88324  Atom;Emacs;IntelliJ;IPython / Jupyter;PyCharm;...      Windows
# 88325           IntelliJ;Sublime Text;Visual Studio Code        MacOS
# 88326         Android Studio;Notepad++;Vim;Visual Studio      Windows
# 88329  Android Studio;IntelliJ;Notepad++;Vim;Visual S...  Linux-based
#
#                                    Containers  \
# 5                     I do not use containers
# 8              Development;Testing;Production
# 12             Development;Testing;Production
# 15                    I do not use containers
# 21     Outside of work, for personal projects
# ...                                       ...
# 88323                 I do not use containers
# 88324          Development;Testing;Production
# 88325                              Production
# 88326                 I do not use containers
# 88329                 I do not use containers
#
#                                     BlockchainOrg  \
# 5                                      Not at all
# 8                                      Not at all
# 12                                     Not at all
# 15                                     Not at all
# 21                                     Not at all
# ...                                           ...
# 88323                                         NaN
# 88324  Implementing cryptocurrency-based products
# 88325                                  Not at all
# 88326                                  Not at all
# 88329                                  Not at all
#
#                                             BlockchainIs BetterLife ITperson  \
# 5                                                    NaN         No      Yes
# 8                      An irresponsible use of resources         No     SIGH
# 12     Useful for decentralized currency (i.e., Bitcoin)        Yes      Yes
# 15                                         A passing fad         No     SIGH
# 21                                                   NaN        Yes      Yes
# ...                                                  ...        ...      ...
# 88323                                      A passing fad        Yes     SIGH
# 88324                  An irresponsible use of resources        Yes      Yes
# 88325  Useful for decentralized currency (i.e., Bitcoin)        Yes      Yes
# 88326                                      A passing fad        Yes      NaN
# 88329                                      A passing fad        Yes      Yes
#
#       OffOn SocialMedia              Extraversion   ScreenName  \
# 5        No     YouTube  In real life (in person)        Login
# 8       Yes     Twitter  In real life (in person)     Username
# 12      Yes     Twitter  In real life (in person)     Username
# 15       No     YouTube                    Online     Username
# 21      Yes   Instagram                    Online     Username
# ...     ...         ...                       ...          ...
# 88323   Yes      Reddit                   Neither       UserID
# 88324    No    Facebook                    Online  Screen Name
# 88325   Yes     Twitter                    Online     Username
# 88326   NaN     YouTube                   Neither     Username
# 88329   Yes   Instagram                   Neither     Username
#
#              SOVisit1st                      SOVisitFreq  \
# 5                  2011  A few times per month or weekly
# 8                  2013            Daily or almost daily
# 12                 2011           Multiple times per day
# 15                 2010           Multiple times per day
# 21     I don't remember            Daily or almost daily
# ...                 ...                              ...
# 88323              2011  A few times per month or weekly
# 88324               NaN  A few times per month or weekly
# 88325              2010           Multiple times per day
# 88326  I don't remember  A few times per month or weekly
# 88329              2009             A few times per week
#
#                                                SOVisitTo  \
# 5                     Find answers to specific questions
# 8      Find answers to specific questions;Contribute ...
# 12                    Find answers to specific questions
# 15     Find answers to specific questions;Learn how t...
# 21                    Find answers to specific questions
# ...                                                  ...
# 88323                 Find answers to specific questions
# 88324                 Find answers to specific questions
# 88325  Find answers to specific questions;Learn how t...
# 88326                 Find answers to specific questions
# 88329                 Find answers to specific questions
#
#                       SOFindAnswer                         SOTimeSaved  \
# 5          Less than once per week  Stack Overflow was slightly faster
# 8               3-5 times per week            They were about the same
# 12     More than 10 times per week      Stack Overflow was much faster
# 15         Less than once per week      Stack Overflow was much faster
# 21              3-5 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88323           1-2 times per week      Stack Overflow was much faster
# 88324      Less than once per week      Stack Overflow was much faster
# 88325           3-5 times per week      Stack Overflow was much faster
# 88326      Less than once per week  Stack Overflow was slightly faster
# 88329           3-5 times per week  Stack Overflow was slightly faster
#
#        SOHowMuchTime SOAccount  \
# 5        60+ minutes       Yes
# 8                NaN       Yes
# 12     11-30 minutes       Yes
# 15     11-30 minutes       Yes
# 21      0-10 minutes       Yes
# ...              ...       ...
# 88323    60+ minutes       Yes
# 88324  11-30 minutes       Yes
# 88325   0-10 minutes       Yes
# 88326    60+ minutes        No
# 88329  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 5      I have never participated in Q&A on Stack Over...
# 8                    Less than once per month or monthly
# 12                   Less than once per month or monthly
# 15                   Less than once per month or monthly
# 21                                  A few times per week
# ...                                                  ...
# 88323                Less than once per month or monthly
# 88324  I have never participated in Q&A on Stack Over...
# 88325                               A few times per week
# 88326                                                NaN
# 88329                Less than once per month or monthly
#
#                                                   SOJobs  \
# 5      No, I knew that Stack Overflow had a job board...
# 8      No, I knew that Stack Overflow had a job board...
# 12                                                   Yes
# 15                                                   Yes
# 21                                                   Yes
# ...                                                  ...
# 88323  No, I didn't know that Stack Overflow had a jo...
# 88324  No, I knew that Stack Overflow had a job board...
# 88325                                                Yes
# 88326  No, I didn't know that Stack Overflow had a jo...
# 88329  No, I knew that Stack Overflow had a job board...
#
#                                                 EntTeams          SOComm  \
# 5                    No, and I don't know what those are  No, not really
# 8                    No, and I don't know what those are   Yes, somewhat
# 12     No, I've heard of them, but I am not part of a...         Neutral
# 15     No, I've heard of them, but I am not part of a...   Yes, somewhat
# 21                   No, and I don't know what those are   Yes, somewhat
# ...                                                  ...             ...
# 88323                No, and I don't know what those are   Yes, somewhat
# 88324                No, and I don't know what those are   Yes, somewhat
# 88325  No, I've heard of them, but I am not part of a...   Yes, somewhat
# 88326                No, and I don't know what those are  No, not at all
# 88329                No, and I don't know what those are  No, not really
#
#                                            WelcomeChange  \
# 5                Just as welcome now as I felt last year
# 8                Just as welcome now as I felt last year
# 12              Somewhat more welcome now than last year
# 15               Just as welcome now as I felt last year
# 21               Just as welcome now as I felt last year
# ...                                                  ...
# 88323              A lot less welcome now than last year
# 88324           Somewhat more welcome now than last year
# 88325            Just as welcome now as I felt last year
# 88326  Not applicable - I did not use Stack Overflow ...
# 88329            Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 5      Tech articles written by other developers;Indu...  28.0    Man    No
# 8                                                    NaN  23.0    Man    No
# 12     Tech articles written by other developers;Cour...  28.0    Man    No
# 15     Tech articles written by other developers;Indu...  26.0    Man    No
# 21     Tech articles written by other developers;Indu...  47.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88323                                                NaN  23.0    Man    No
# 88324  Tech articles written by other developers;Cour...  48.0    Man    No
# 88325  Tech articles written by other developers;Indu...  26.0    Man    No
# 88326                                                NaN  34.0    Man    No
# 88329                                                NaN   NaN    Man    No
#
#                      Sexuality                     Ethnicity Dependents  \
# 5      Straight / Heterosexual                    East Asian         No
# 8                     Bisexual  White or of European descent         No
# 12     Straight / Heterosexual  White or of European descent        Yes
# 15     Straight / Heterosexual  White or of European descent         No
# 21     Straight / Heterosexual  White or of European descent        Yes
# ...                        ...                           ...        ...
# 88323  Straight / Heterosexual  White or of European descent         No
# 88324  Straight / Heterosexual                   South Asian        Yes
# 88325  Straight / Heterosexual                   South Asian         No
# 88326  Straight / Heterosexual  White or of European descent         No
# 88329  Straight / Heterosexual  White or of European descent        Yes
#
#                 SurveyLength                  SurveyEase
# 5                   Too long  Neither easy nor difficult
# 8      Appropriate in length  Neither easy nor difficult
# 12     Appropriate in length                        Easy
# 15     Appropriate in length  Neither easy nor difficult
# 21     Appropriate in length                        Easy
# ...                      ...                         ...
# 88323  Appropriate in length                        Easy
# 88324               Too long  Neither easy nor difficult
# 88325  Appropriate in length                        Easy
# 88326  Appropriate in length                        Easy
# 88329               Too long                        Easy
#
# [22289 rows x 85 columns]

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df.loc[high_salary_1, ['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# 15          455352.0
# 21          103000.0
# ...              ...
# 88323       180000.0
# 88324      2000000.0
# 88325       130000.0
# 88326        82488.0
# 88329       588012.0
#
# [22289 rows x 3 columns]

# %%
# more filtering
countries = ['United States', 'Finland', 'United Kingdom', 'Canada']
high_salary_1 = df[df['Country'].isin(countries)]
high_salary_1
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 3               4                     I am a developer by profession       No
# 5               6  I am not primarily a developer, but I write co...      Yes
# 11             12             I am a student who is learning to code       No
# 12             13                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88855       85182                                                NaN       No
# 88859       85642                                                NaN       No
# 88863       85961                                                NaN      Yes
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 3                                                  Never
# 5                                                  Never
# 11                                                 Never
# 12     Less than once a month but more than once per ...
# ...                                                  ...
# 88855  Less than once a month but more than once per ...
# 88859                            Less than once per year
# 88863                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 5      The quality of OSS and closed source software ...
# 11     OSS is, on average, of HIGHER quality than pro...
# 12     OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88855  The quality of OSS and closed source software ...
# 88859  OSS is, on average, of LOWER quality than prop...
# 88863  The quality of OSS and closed source software ...
# 88877  The quality of OSS and closed source software ...
# 88878  The quality of OSS and closed source software ...
#
#                                               Employment         Country  \
# 0                 Not employed, and not looking for work  United Kingdom
# 3                                     Employed full-time   United States
# 5                                     Employed full-time          Canada
# 11                                    Employed part-time          Canada
# 12                                    Employed full-time   United States
# ...                                                  ...             ...
# 88855                                                NaN          Canada
# 88859  Independent contractor, freelancer, or self-em...   United States
# 88863                                                NaN  United Kingdom
# 88877                 Not employed, but looking for work   United States
# 88878             Not employed, and not looking for work          Canada
#
#               Student                                            EdLevel  \
# 0                  No                          Primary/elementary school
# 3                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11     Yes, full-time  Some college/university study without earning ...
# 12                 No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...               ...                                                ...
# 88855             NaN                                                NaN
# 88859              No                                   Associate degree
# 88863              No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 88877              No  Some college/university study without earning ...
# 88878              No                          Primary/elementary school
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 3      Computer science, computer engineering, or sof...
# 5                              Mathematics or statistics
# 11                             Mathematics or statistics
# 12     Computer science, computer engineering, or sof...
# ...                                                  ...
# 88855                                                NaN
# 88859  Information systems, information technology, o...
# 88863  Computer science, computer engineering, or sof...
# 88877  Computer science, computer engineering, or sof...
# 88878                                                NaN
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 5      Taken an online course in programming or softw...
# 11     Taken an online course in programming or softw...
# 12     Taken an online course in programming or softw...
# ...                                                  ...
# 88855                                                NaN
# 88859  Taken an online course in programming or softw...
# 88863  Taught yourself a new language, framework, or ...
# 88877  Taught yourself a new language, framework, or ...
# 88878  Taught yourself a new language, framework, or ...
#
#                                                  OrgSize  \
# 0                                                    NaN
# 3                                   100 to 499 employees
# 5                                                    NaN
# 11                                                   NaN
# 12                                    10 to 19 employees
# ...                                                  ...
# 88855                                                NaN
# 88859  Just me - I am a freelancer, sole proprietor, ...
# 88863                                                NaN
# 88877                                                NaN
# 88878                                                NaN
#
#                                                  DevType YearsCode Age1stCode  \
# 0                                                    NaN         4         10
# 3                                  Developer, full-stack         3         16
# 5      Data or business analyst;Data scientist or mac...        13         15
# 11     Data or business analyst;Data scientist or mac...         5         16
# 12     Data or business analyst;Database administrato...        17         11
# ...                                                  ...       ...        ...
# 88855                                                NaN       NaN        NaN
# 88859           Designer;Marketing or sales professional        20          7
# 88863                                                NaN        24         10
# 88877  Developer, back-end;Developer, desktop or ente...        38         10
# 88878                                                NaN       NaN        NaN
#
#            YearsCodePro       CareerSat              JobSat        MgrIdiot  \
# 0                   NaN             NaN                 NaN             NaN
# 3      Less than 1 year  Very satisfied  Slightly satisfied  Very confident
# 5                     3  Very satisfied  Slightly satisfied  Very confident
# 11                  NaN             NaN                 NaN             NaN
# 12                    8  Very satisfied      Very satisfied             NaN
# ...                 ...             ...                 ...             ...
# 88855               NaN             NaN                 NaN             NaN
# 88859  Less than 1 year             NaN                 NaN             NaN
# 88863               NaN             NaN                 NaN             NaN
# 88877                38             NaN                 NaN             NaN
# 88878               NaN             NaN                 NaN             NaN
#
#       MgrMoney   MgrWant                                       JobSeek  \
# 0          NaN       NaN                                           NaN
# 3           No  Not sure  I am not interested in new job opportunities
# 5           No       Yes  I am not interested in new job opportunities
# 11         NaN       NaN  I am not interested in new job opportunities
# 12         NaN       NaN  I am not interested in new job opportunities
# ...        ...       ...                                           ...
# 88855      NaN       NaN                                           NaN
# 88859      NaN       NaN                                           NaN
# 88863      NaN       NaN                                           NaN
# 88877      NaN       NaN                                           NaN
# 88878      NaN       NaN                                           NaN
#
#                LastHireDate  \
# 0                       NaN
# 3      Less than a year ago
# 5             1-2 years ago
# 11     Less than a year ago
# 12            3-4 years ago
# ...                     ...
# 88855                   NaN
# 88859                   NaN
# 88863                   NaN
# 88877                   NaN
# 88878                   NaN
#
#                                                  LastInt FizzBuzz  \
# 0                                                    NaN      NaN
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 5      Write any code;Complete a take-home project;In...       No
# 11                                                   NaN      NaN
# 12     Complete a take-home project;Interview with pe...      Yes
# ...                                                  ...      ...
# 88855                                                NaN      NaN
# 88859                                                NaN      NaN
# 88863                                                NaN      NaN
# 88877                                                NaN      NaN
# 88878                                                NaN      NaN
#
#                                               JobFactors  \
# 0                                                    NaN
# 3      Languages, frameworks, and other technologies ...
# 5      Financial performance or funding status of the...
# 11     Financial performance or funding status of the...
# 12     Languages, frameworks, and other technologies ...
# ...                                                  ...
# 88855                                                NaN
# 88859                                                NaN
# 88863                                                NaN
# 88877                                                NaN
# 88878                                                NaN
#
#                                             ResumeUpdate CurrencySymbol  \
# 0                                                    NaN            NaN
# 3                       I was preparing for a job search            USD
# 5      I heard about a job opportunity (from a recrui...            CAD
# 11      My job status changed (promotion, new job, etc.)            NaN
# 12                      I was preparing for a job search            USD
# ...                                                  ...            ...
# 88855                                                NaN            NaN
# 88859                                                NaN            NaN
# 88863                                                NaN            NaN
# 88877                                                NaN            NaN
# 88878                                                NaN            NaN
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 5           Canadian dollar    40000.0  Monthly       366420.0         15.0
# 11                      NaN        NaN      NaN            NaN          NaN
# 12     United States dollar    90000.0   Yearly        90000.0         40.0
# ...                     ...        ...      ...            ...          ...
# 88855                   NaN        NaN      NaN            NaN          NaN
# 88859                   NaN        NaN      NaN            NaN          NaN
# 88863                   NaN        NaN      NaN            NaN          NaN
# 88877                   NaN        NaN      NaN            NaN          NaN
# 88878                   NaN        NaN      NaN            NaN          NaN
#
#                                                 WorkPlan  \
# 0                                                    NaN
# 3      There's no schedule or spec; I work on what se...
# 5      There's no schedule or spec; I work on what se...
# 11                                                   NaN
# 12     There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88855                                                NaN
# 88859                                                NaN
# 88863                                                NaN
# 88877                                                NaN
# 88878                                                NaN
#
#                                            WorkChallenge  \
# 0                                                    NaN
# 3                                                    NaN
# 5                                                    NaN
# 11                                                   NaN
# 12     Meetings;Non-work commitments (parenting, scho...
# ...                                                  ...
# 88855                                                NaN
# 88859                                                NaN
# 88863                                                NaN
# 88877                                                NaN
# 88878                                                NaN
#
#                                               WorkRemote WorkLoc  \
# 0                                                    NaN     NaN
# 3                       Less than once per month / Never    Home
# 5                                  A few days each month    Home
# 11                                                   NaN     NaN
# 12     All or almost all the time (I'm full-time remote)    Home
# ...                                                  ...     ...
# 88855                                                NaN     NaN
# 88859                                                NaN     NaN
# 88863                                                NaN     NaN
# 88877                                                NaN     NaN
# 88878                                                NaN     NaN
#
#                        ImpSyn                                  CodeRev  \
# 0                         NaN                                      NaN
# 3      A little below average                                       No
# 5      A little above average                                       No
# 11                        NaN                                      NaN
# 12     A little above average  Yes, because I see value in code review
# ...                       ...                                      ...
# 88855                     NaN                                      NaN
# 88859                     NaN                                      NaN
# 88863                     NaN                                      NaN
# 88877                     NaN                                      NaN
# 88878                     NaN                                      NaN
#
#        CodeRevHrs                                          UnitTests  \
# 0             NaN                                                NaN
# 3             NaN                          No, but I think we should
# 5             NaN  Yes, it's not part of our process but the deve...
# 11            NaN                                                NaN
# 12            5.0                          No, but I think we should
# ...           ...                                                ...
# 88855         NaN                                                NaN
# 88859         NaN                                                NaN
# 88863         NaN                                                NaN
# 88877         NaN                                                NaN
# 88878         NaN                                                NaN
#
#                                              PurchaseHow  \
# 0                                                    NaN
# 3      Developers typically have the most influence o...
# 5                                               Not sure
# 11                                                   NaN
# 12     Developers and management have nearly equal in...
# ...                                                  ...
# 88855                                                NaN
# 88859                                                NaN
# 88863                                                NaN
# 88877                                                NaN
# 88878                                                NaN
#
#                            PurchaseWhat  \
# 0                                   NaN
# 3         I have little or no influence
# 5         I have little or no influence
# 11                                  NaN
# 12     I have a great deal of influence
# ...                                 ...
# 88855                               NaN
# 88859                               NaN
# 88863                               NaN
# 88877                               NaN
# 88878                               NaN
#
#                                       LanguageWorkedWith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 3                                    C;C++;C#;Python;SQL
# 5                                             Java;R;SQL
# 11      Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# ...                                                  ...
# 88855                                               Dart
# 88859                                        Go;HTML/CSS
# 88863                                    C;C++;Other(s):
# 88877  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88878                      HTML/CSS;JavaScript;Other(s):
#
#                                   LanguageDesireNextYear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 3                                    C;C#;JavaScript;SQL
# 5                                       Python;Scala;SQL
# 11       Bash/Shell/PowerShell;C++;Go;Python;R;Scala;SQL
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# ...                                                  ...
# 88855                              Objective-C;Other(s):
# 88859                                                NaN
# 88863                           Assembly;C;C++;Other(s):
# 88877  Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
#
#                       DatabaseWorkedWith  \
# 0                                 SQLite
# 3                           MySQL;SQLite
# 5                     MongoDB;PostgreSQL
# 11               MySQL;PostgreSQL;SQLite
# 12     Couchbase;DynamoDB;Firebase;MySQL
# ...                                  ...
# 88855                                NaN
# 88859                                NaN
# 88863                                NaN
# 88877                                NaN
# 88878                    Firebase;SQLite
#
#                        DatabaseDesireNextYear  \
# 0                                       MySQL
# 3                                MySQL;SQLite
# 5                                  PostgreSQL
# 11     Elasticsearch;MongoDB;MySQL;PostgreSQL
# 12                       Firebase;MySQL;Redis
# ...                                       ...
# 88855                                     NaN
# 88859                                     NaN
# 88863                                     NaN
# 88877                                     NaN
# 88878                   Firebase;MySQL;SQLite
#
#                                       PlatformWorkedWith  \
# 0                                          MacOS;Windows
# 3                                          Linux;Windows
# 5            Android;Google Cloud Platform;Linux;Windows
# 11     AWS;Docker;Google Cloud Platform;Linux;MacOS;S...
# 12     Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# ...                                                  ...
# 88855  AWS;IBM Cloud or Watson;Raspberry Pi;Slack;Wor...
# 88859                                                NaN
# 88863     Android;Arduino;Raspberry Pi;Windows;Other(s):
# 88877                                              Linux
# 88878                                              Linux
#
#                                   PlatformDesireNextYear  \
# 0                                Android;Arduino;Windows
# 3                                          Linux;Windows
# 5            Android;Google Cloud Platform;Linux;Windows
# 11                                 AWS;Linux;MacOS;Slack
# 12     Android;AWS;Docker;IBM Cloud or Watson;Linux;S...
# ...                                                  ...
# 88855  Arduino;AWS;Docker;Microsoft Azure;Slack;Windo...
# 88859                                                NaN
# 88863     Android;Arduino;Raspberry Pi;Windows;Other(s):
# 88877                                 Linux;Raspberry Pi
# 88878                        Google Cloud Platform;Linux
#
#                                      WebFrameWorkedWith  \
# 0                                          Django;Flask
# 3                                                   NaN
# 5                                                   NaN
# 11                                                  NaN
# 12     Angular/Angular.js;ASP.NET;Express;jQuery;Vue.js
# ...                                                 ...
# 88855         Angular/Angular.js;Express;Laravel;Spring
# 88859                                               NaN
# 88863                                         Other(s):
# 88877                                          React.js
# 88878                                            jQuery
#
#                 WebFrameDesireNextYear                     MiscTechWorkedWith  \
# 0                         Flask;jQuery                                Node.js
# 3                                  NaN                                   .NET
# 5                                  NaN                                 Hadoop
# 11                                 NaN  Ansible;Chef;Hadoop;Pandas;TensorFlow
# 12                      Express;Vue.js                        Node.js;Xamarin
# ...                                ...                                    ...
# 88855  Angular/Angular.js;Flask;Vue.js           Hadoop;Node.js;Torch/PyTorch
# 88859                              NaN                                    NaN
# 88863                        Other(s):                              Other(s):
# 88877                           Vue.js                                Node.js
# 88878                    jQuery;Vue.js                                Node.js
#
#                                   MiscTechDesireNextYear  \
# 0                                                Node.js
# 3                                                   .NET
# 5                      Hadoop;Pandas;TensorFlow;Unity 3D
# 11     Ansible;Apache Spark;Chef;Hadoop;Pandas;Tensor...
# 12                                    Node.js;TensorFlow
# ...                                                  ...
# 88855                                    .NET;TensorFlow
# 88859                                                NaN
# 88863                                          Other(s):
# 88877                                            Ansible
# 88878                React Native;Unity 3D;Unreal Engine
#
#                                               DevEnviron        OpSys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5      Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 11     IPython / Jupyter;PyCharm;RStudio;Sublime Text...        MacOS
# 12            Vim;Visual Studio;Visual Studio Code;Xcode      Windows
# ...                                                  ...          ...
# 88855                                     Android Studio        MacOS
# 88859                                 Visual Studio Code      Windows
# 88863  Android Studio;Atom;Notepad++;Visual Studio;Vi...      Windows
# 88877                                                Vim  Linux-based
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
#
#                            Containers BlockchainOrg  \
# 0             I do not use containers           NaN
# 3             I do not use containers    Not at all
# 5             I do not use containers    Not at all
# 11                 Testing;Production           NaN
# 12     Development;Testing;Production    Not at all
# ...                               ...           ...
# 88855                      Production           NaN
# 88859         I do not use containers           NaN
# 88863         I do not use containers           NaN
# 88877         I do not use containers           NaN
# 88878         I do not use containers           NaN
#
#                                             BlockchainIs BetterLife  \
# 0                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                    NaN         No
# 11                                                   NaN        Yes
# 12     Useful for decentralized currency (i.e., Bitcoin)        Yes
# ...                                                  ...        ...
# 88855  Useful for immutable record keeping outside of...        Yes
# 88859  Useful for immutable record keeping outside of...         No
# 88863                                                NaN        Yes
# 88877                  An irresponsible use of resources         No
# 88878  Useful across many domains and could change ma...        Yes
#
#                                        ITperson  OffOn  \
# 0      Fortunately, someone else has that title    Yes
# 3                                          SIGH    Yes
# 5                                           Yes     No
# 11                                          Yes    Yes
# 12                                          Yes    Yes
# ...                                         ...    ...
# 88855                                  Also Yes     No
# 88859                                      SIGH    Yes
# 88863                                       Yes    Yes
# 88877                                       NaN    Yes
# 88878                                       Yes  What?
#
#                     SocialMedia              Extraversion ScreenName  \
# 0                       Twitter                    Online   Username
# 3                        Reddit  In real life (in person)   Username
# 5                       YouTube  In real life (in person)      Login
# 11                       Reddit  In real life (in person)   Username
# 12                      Twitter  In real life (in person)   Username
# ...                         ...                       ...        ...
# 88855                  Snapchat  In real life (in person)        NaN
# 88859                       NaN  In real life (in person)     Handle
# 88863                   YouTube                   Neither     UserID
# 88877  I don't use social media  In real life (in person)   Username
# 88878                   YouTube                       NaN   Username
#
#              SOVisit1st                                        SOVisitFreq  \
# 0                  2017                    A few times per month or weekly
# 3                  2014                              Daily or almost daily
# 5                  2011                    A few times per month or weekly
# 11                 2014                    A few times per month or weekly
# 12                 2011                             Multiple times per day
# ...                 ...                                                ...
# 88855               NaN  I have never visited Stack Overflow (before to...
# 88859              2008                Less than once per month or monthly
# 88863              2010                    A few times per month or weekly
# 88877  I don't remember                    A few times per month or weekly
# 88878  I don't remember                               A few times per week
#
#                                                SOVisitTo  \
# 0      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 5                     Find answers to specific questions
# 11     Find answers to specific questions;Learn how t...
# 12                    Find answers to specific questions
# ...                                                  ...
# 88855                              Pass the time / relax
# 88859                 Find answers to specific questions
# 88863  Find answers to specific questions;Learn how t...
# 88877                 Find answers to specific questions
# 88878  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer                             SOTimeSaved  \
# 0               3-5 times per week          Stack Overflow was much faster
# 3               1-2 times per week          Stack Overflow was much faster
# 5          Less than once per week      Stack Overflow was slightly faster
# 11              1-2 times per week  The other resource was slightly faster
# 12     More than 10 times per week          Stack Overflow was much faster
# ...                            ...                                     ...
# 88855      Less than once per week          Stack Overflow was much faster
# 88859      Less than once per week      Stack Overflow was slightly faster
# 88863      Less than once per week                They were about the same
# 88877           1-2 times per week                They were about the same
# 88878           3-5 times per week      Stack Overflow was slightly faster
#
#        SOHowMuchTime                  SOAccount  \
# 0      31-60 minutes                         No
# 3      31-60 minutes                        Yes
# 5        60+ minutes                        Yes
# 11     11-30 minutes  Not sure / can't remember
# 12     11-30 minutes                        Yes
# ...              ...                        ...
# 88855  31-60 minutes                        NaN
# 88859    60+ minutes                        Yes
# 88863            NaN                        Yes
# 88877            NaN                        Yes
# 88878  11-30 minutes                        Yes
#
#                                               SOPartFreq  \
# 0                                                    NaN
# 3                    Less than once per month or monthly
# 5      I have never participated in Q&A on Stack Over...
# 11                                                   NaN
# 12                   Less than once per month or monthly
# ...                                                  ...
# 88855                                                NaN
# 88859  I have never participated in Q&A on Stack Over...
# 88863                    A few times per month or weekly
# 88877  I have never participated in Q&A on Stack Over...
# 88878  I have never participated in Q&A on Stack Over...
#
#                                                   SOJobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 3                                                    Yes
# 5      No, I knew that Stack Overflow had a job board...
# 11     No, I knew that Stack Overflow had a job board...
# 12                                                   Yes
# ...                                                  ...
# 88855  No, I didn't know that Stack Overflow had a jo...
# 88859  No, I knew that Stack Overflow had a job board...
# 88863  No, I knew that Stack Overflow had a job board...
# 88877                                                Yes
# 88878  No, I knew that Stack Overflow had a job board...
#
#                                                 EntTeams          SOComm  \
# 0                    No, and I don't know what those are         Neutral
# 3                    No, and I don't know what those are  No, not really
# 5                    No, and I don't know what those are  No, not really
# 11                                                   Yes   Yes, somewhat
# 12     No, I've heard of them, but I am not part of a...         Neutral
# ...                                                  ...             ...
# 88855                                                Yes  No, not really
# 88859                No, and I don't know what those are  No, not at all
# 88863                No, and I don't know what those are         Neutral
# 88877                No, and I don't know what those are  No, not really
# 88878  No, I've heard of them, but I am not part of a...  No, not at all
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 5       Just as welcome now as I felt last year
# 11      Just as welcome now as I felt last year
# 12     Somewhat more welcome now than last year
# ...                                         ...
# 88855     A lot less welcome now than last year
# 88859   Just as welcome now as I felt last year
# 88863  Somewhat less welcome now than last year
# 88877   Just as welcome now as I felt last year
# 88878                                       NaN
#
#                                             SONewContent   Age  \
# 0      Tech articles written by other developers;Indu...  14.0
# 3      Tech articles written by other developers;Indu...  22.0
# 5      Tech articles written by other developers;Indu...  28.0
# 11          Courses on technologies you're interested in  21.0
# 12     Tech articles written by other developers;Cour...  28.0
# ...                                                  ...   ...
# 88855                                                NaN   NaN
# 88859  Tech articles written by other developers;Indu...  34.0
# 88863                                                NaN  45.0
# 88877                                                NaN   NaN
# 88878  Tech articles written by other developers;Tech...   NaN
#
#                                                   Gender Trans  \
# 0                                                    Man    No
# 3                                                    Man    No
# 5                                                    Man    No
# 11                                                 Woman    No
# 12                                                   Man    No
# ...                                                  ...   ...
# 88855                                              Woman    No
# 88859  Non-binary, genderqueer, or gender non-conforming   NaN
# 88863                                                Man    No
# 88877                                                Man    No
# 88878                                                Man    No
#
#                      Sexuality                     Ethnicity Dependents  \
# 0      Straight / Heterosexual                           NaN         No
# 3      Straight / Heterosexual  White or of European descent         No
# 5      Straight / Heterosexual                    East Asian         No
# 11     Straight / Heterosexual   Black or of African descent         No
# 12     Straight / Heterosexual  White or of European descent        Yes
# ...                        ...                           ...        ...
# 88855  Straight / Heterosexual                           NaN         No
# 88859  Bisexual;Gay or Lesbian  White or of European descent         No
# 88863           Gay or Lesbian  White or of European descent         No
# 88877  Straight / Heterosexual                           NaN         No
# 88878                      NaN                           NaN         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 5                   Too long  Neither easy nor difficult
# 11     Appropriate in length                        Easy
# 12     Appropriate in length                        Easy
# ...                      ...                         ...
# 88855               Too long                        Easy
# 88859  Appropriate in length                        Easy
# 88863  Appropriate in length                   Difficult
# 88877              Too short  Neither easy nor difficult
# 88878  Appropriate in length                        Easy
#
# [30627 rows x 85 columns]

# %%
# OR
countries = ['United States', 'Finland', 'United Kingdom', 'Canada']
high_salary_1 = df['Country'].isin(countries)
df.loc[high_salary_1, 'Country']
# Out:
# 0        United Kingdom
# 3         United States
# 5                Canada
# 11               Canada
# 12        United States
#               ...
# 88855            Canada
# 88859     United States
# 88863    United Kingdom
# 88877     United States
# 88878            Canada
# Name: Country, Length: 30627, dtype: object

# %%
# this colume has different inputs in a cell, seperated with a comma. so we want results that contains a particular result
# e.g 'Python'
df[df['LanguageWorkedWith'].str.contains('Python', na=False)]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 1               2  I am a student who is learning to code       No
# 3               4          I am a developer by profession       No
# 4               5          I am a developer by profession      Yes
# 7               8             I code primarily as a hobby      Yes
# ...           ...                                     ...      ...
# 88854       84539                                     NaN      Yes
# 88860       85738                                     NaN      Yes
# 88865       86566                                     NaN      Yes
# 88872       87739                                     NaN      Yes
# 88876       88212                                     NaN       No
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 3                                                  Never
# 4                             Once a month or more often
# 7                                Less than once per year
# ...                                                  ...
# 88854  Less than once a month but more than once per ...
# 88860                                              Never
# 88865  Less than once a month but more than once per ...
# 88872                            Less than once per year
# 88876                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# 7      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88854  The quality of OSS and closed source software ...
# 88860  The quality of OSS and closed source software ...
# 88865  OSS is, on average, of HIGHER quality than pro...
# 88872  OSS is, on average, of HIGHER quality than pro...
# 88876  OSS is, on average, of HIGHER quality than pro...
#
#                                    Employment                 Country  \
# 0      Not employed, and not looking for work          United Kingdom
# 1          Not employed, but looking for work  Bosnia and Herzegovina
# 3                          Employed full-time           United States
# 4                          Employed full-time                 Ukraine
# 7          Not employed, but looking for work                   India
# ...                                       ...                     ...
# 88854                      Employed full-time          United Kingdom
# 88860  Not employed, and not looking for work                  Brazil
# 88865                                 Retired             Switzerland
# 88872                      Employed part-time          Czech Republic
# 88876                      Employed full-time                   Spain
#
#               Student                                            EdLevel  \
# 0                  No                          Primary/elementary school
# 1      Yes, full-time  Secondary school (e.g. American high school, G...
# 3                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7                 NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...               ...                                                ...
# 88854  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88860  Yes, full-time  Secondary school (e.g. American high school, G...
# 88865              No  Some college/university study without earning ...
# 88872  Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88876              No  Secondary school (e.g. American high school, G...
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 1                                                    NaN
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# 7      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88854  Computer science, computer engineering, or sof...
# 88860                                                NaN
# 88865  A humanities discipline (ex. literature, histo...
# 88872  Computer science, computer engineering, or sof...
# 88876                                                NaN
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# 7      Taught yourself a new language, framework, or ...
# ...                                                  ...
# 88854  Taken an online course in programming or softw...
# 88860  Taught yourself a new language, framework, or ...
# 88865  Taken a part-time in-person course in programm...
# 88872  Taught yourself a new language, framework, or ...
# 88876  Taught yourself a new language, framework, or ...
#
#                         OrgSize  \
# 0                           NaN
# 1                           NaN
# 3          100 to 499 employees
# 4      10,000 or more employees
# 7                           NaN
# ...                         ...
# 88854  1,000 to 4,999 employees
# 88860                       NaN
# 88865                       NaN
# 88872      500 to 999 employees
# 88876        10 to 19 employees
#
#                                                  DevType           YearsCode  \
# 0                                                    NaN                   4
# 1      Developer, desktop or enterprise applications;...                 NaN
# 3                                  Developer, full-stack                   3
# 4      Academic researcher;Developer, desktop or ente...                  16
# 7         Developer, back-end;Engineer, site reliability                   8
# ...                                                  ...                 ...
# 88854  Academic researcher;Data scientist or machine ...                   8
# 88860                                                NaN                  10
# 88865                                                NaN  More than 50 years
# 88872  Academic researcher;Designer;Developer, game o...                   9
# 88876  Designer;Developer, front-end;Developer, full-...                  18
#
#       Age1stCode      YearsCodePro          CareerSat                 JobSat  \
# 0             10               NaN                NaN                    NaN
# 1             17               NaN                NaN                    NaN
# 3             16  Less than 1 year     Very satisfied     Slightly satisfied
# 4             14                 9  Very dissatisfied  Slightly dissatisfied
# 7             16               NaN                NaN                    NaN
# ...          ...               ...                ...                    ...
# 88854         16                 6                NaN                    NaN
# 88860          5                 3                NaN                    NaN
# 88865         17                22                NaN                    NaN
# 88872         16                 3                NaN                    NaN
# 88876          7                15                NaN                    NaN
#
#                  MgrIdiot MgrMoney                 MgrWant  \
# 0                     NaN      NaN                     NaN
# 1                     NaN      NaN                     NaN
# 3          Very confident       No                Not sure
# 4      Somewhat confident      Yes                      No
# 7                     NaN      NaN                     NaN
# ...                   ...      ...                     ...
# 88854  Somewhat confident       No                Not sure
# 88860                 NaN      NaN                     NaN
# 88865                 NaN      NaN                     NaN
# 88872  Somewhat confident       No                Not sure
# 88876  Somewhat confident      Yes  I am already a manager
#
#                                             JobSeek          LastHireDate  \
# 0                                               NaN                   NaN
# 1                   I am actively looking for a job  I've never had a job
# 3      I am not interested in new job opportunities  Less than a year ago
# 4      I am not interested in new job opportunities  Less than a year ago
# 7                                               NaN                   NaN
# ...                                             ...                   ...
# 88854                                           NaN                   NaN
# 88860                                           NaN                   NaN
# 88865                                           NaN                   NaN
# 88872                                           NaN                   NaN
# 88876                                           NaN                   NaN
#
#                                                  LastInt FizzBuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# 7                                                    NaN      NaN
# ...                                                  ...      ...
# 88854                                                NaN      NaN
# 88860                                                NaN      NaN
# 88865                                                NaN      NaN
# 88872                                                NaN      NaN
# 88876                                                NaN      NaN
#
#                                               JobFactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# 7                                                    NaN
# ...                                                  ...
# 88854                                                NaN
# 88860                                                NaN
# 88865                                                NaN
# 88872                                                NaN
# 88876                                                NaN
#
#                                             ResumeUpdate CurrencySymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# 7                                                    NaN            NaN
# ...                                                  ...            ...
# 88854                                                NaN            NaN
# 88860                                                NaN            NaN
# 88865                                                NaN            NaN
# 88872                                                NaN            NaN
# 88876                                                NaN            NaN
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# 7                       NaN        NaN      NaN            NaN          NaN
# ...                     ...        ...      ...            ...          ...
# 88854                   NaN        NaN      NaN            NaN          NaN
# 88860                   NaN        NaN      NaN            NaN          NaN
# 88865                   NaN        NaN      NaN            NaN          NaN
# 88872                   NaN        NaN      NaN            NaN          NaN
# 88876                   NaN        NaN      NaN            NaN          NaN
#
#                                                 WorkPlan  \
# 0                                                    NaN
# 1                                                    NaN
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# 7                                                    NaN
# ...                                                  ...
# 88854                                                NaN
# 88860                                                NaN
# 88865                                                NaN
# 88872                                                NaN
# 88876                                                NaN
#
#                                            WorkChallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# 7                                                    NaN
# ...                                                  ...
# 88854                                                NaN
# 88860                                                NaN
# 88865                                                NaN
# 88872                                                NaN
# 88876                                                NaN
#
#                              WorkRemote WorkLoc                  ImpSyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# 7                                   NaN     NaN                     NaN
# ...                                 ...     ...                     ...
# 88854                               NaN     NaN                     NaN
# 88860                               NaN     NaN                     NaN
# 88865                               NaN     NaN                     NaN
# 88872                               NaN     NaN                     NaN
# 88876                               NaN     NaN                     NaN
#
#                                        CodeRev  CodeRevHrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# 7                                          NaN         NaN
# ...                                        ...         ...
# 88854                                      NaN         NaN
# 88860                                      NaN         NaN
# 88865                                      NaN         NaN
# 88872                                      NaN         NaN
# 88876                                      NaN         NaN
#
#                            UnitTests  \
# 0                                NaN
# 1                                NaN
# 3          No, but I think we should
# 4      Yes, it's part of our process
# 7                                NaN
# ...                              ...
# 88854                            NaN
# 88860                            NaN
# 88865                            NaN
# 88872                            NaN
# 88876                            NaN
#
#                                              PurchaseHow  \
# 0                                                    NaN
# 1                                                    NaN
# 3      Developers typically have the most influence o...
# 4                                               Not sure
# 7                                                    NaN
# ...                                                  ...
# 88854                                                NaN
# 88860                                                NaN
# 88865                                                NaN
# 88872                                                NaN
# 88876                                                NaN
#
#                         PurchaseWhat  \
# 0                                NaN
# 1                                NaN
# 3      I have little or no influence
# 4      I have little or no influence
# 7                                NaN
# ...                              ...
# 88854                            NaN
# 88860                            NaN
# 88865                            NaN
# 88872                            NaN
# 88876                            NaN
#
#                                       LanguageWorkedWith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...                                                  ...
# 88854  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860    Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865    Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872           C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                         HTML/CSS;JavaScript;Python
#
#                                   LanguageDesireNextYear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 7      Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# ...                                                  ...
# 88854  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 88860       Assembly;Bash/Shell/PowerShell;C++;Other(s):
# 88865  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 88872                            C++;HTML/CSS;PHP;Python
# 88876                                         JavaScript
#
#                                       DatabaseWorkedWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 3                                           MySQL;SQLite
# 4       Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 7      Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# ...                                                  ...
# 88854                                         PostgreSQL
# 88860                                                NaN
# 88865                                                NaN
# 88872                                              MySQL
# 88876                                   MySQL;PostgreSQL
#
#                                   DatabaseDesireNextYear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 7      Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# ...                                                  ...
# 88854                                                NaN
# 88860                                                NaN
# 88865                                                NaN
# 88872                                              MySQL
# 88876                                         PostgreSQL
#
#                         PlatformWorkedWith  \
# 0                            MacOS;Windows
# 1                                  Windows
# 3                            Linux;Windows
# 4        Android;Linux;MacOS;Slack;Windows
# 7      AWS;Docker;Heroku;Linux;MacOS;Slack
# ...                                    ...
# 88854   Android;Arduino;Linux;Raspberry Pi
# 88860                                Linux
# 88865                        Linux;Windows
# 88872              Android;Linux;WordPress
# 88876                                  NaN
#
#                                   PlatformDesireNextYear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# 7      Android;Arduino;AWS;Docker;Google Cloud Platfo...
# ...                                                  ...
# 88854                              Android;Arduino;Linux
# 88860                                              Linux
# 88865                                      Linux;Windows
# 88872                                      Android;Linux
# 88876                                            Arduino
#
#                                 WebFrameWorkedWith  \
# 0                                     Django;Flask
# 1                                           Django
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# 7                    Express;Flask;React.js;Spring
# ...                                            ...
# 88854                               Express;Vue.js
# 88860                                          NaN
# 88865                                          NaN
# 88872                                       jQuery
# 88876                              Django;React.js
#
#                      WebFrameDesireNextYear        MiscTechWorkedWith  \
# 0                              Flask;jQuery                   Node.js
# 1                                    Django                       NaN
# 3                                       NaN                      .NET
# 4              Flask;jQuery;React.js;Spring           Cordova;Node.js
# 7      Django;Express;Flask;React.js;Vue.js     Hadoop;Node.js;Pandas
# ...                                     ...                       ...
# 88854                        Express;Vue.js        Node.js;TensorFlow
# 88860                                   NaN  TensorFlow;Torch/PyTorch
# 88865                                   NaN                       NaN
# 88872                                jQuery                TensorFlow
# 88876                       Django;React.js                       NaN
#
#                                   MiscTechDesireNextYear  \
# 0                                                Node.js
# 1                                                    NaN
# 3                                                   .NET
# 4               Apache Spark;Hadoop;Node.js;React Native
# 7      Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# ...                                                  ...
# 88854                                 Node.js;TensorFlow
# 88860                                                NaN
# 88865                                                NaN
# 88872                                                NaN
# 88876                                                NaN
#
#                                               DevEnviron        OpSys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# 7      Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# ...                                                  ...          ...
# 88854                    Android Studio;Atom;Eclipse;Vim  Linux-based
# 88860                                                Vim  Linux-based
# 88865                                              Emacs      Windows
# 88872                                                Vim  Linux-based
# 88876                            Atom;Visual Studio Code        MacOS
#
#                                               Containers  \
# 0                                I do not use containers
# 1                                I do not use containers
# 3                                I do not use containers
# 4                 Outside of work, for personal projects
# 7      Development;Testing;Production;Outside of work...
# ...                                                  ...
# 88854                            I do not use containers
# 88860                            I do not use containers
# 88865                            I do not use containers
# 88872                            I do not use containers
# 88876                            I do not use containers
#
#                                  BlockchainOrg  \
# 0                                          NaN
# 1                                          NaN
# 3                                   Not at all
# 4                                   Not at all
# 7                                          NaN
# ...                                        ...
# 88854                                      NaN
# 88860                                      NaN
# 88865                                      NaN
# 88872                                      NaN
# 88876  Non-currency applications of blockchain
#
#                                             BlockchainIs BetterLife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# 7      Useful across many domains and could change ma...        Yes
# ...                                                  ...        ...
# 88854                                                NaN        Yes
# 88860  Useful across many domains and could change ma...         No
# 88865  Useful for immutable record keeping outside of...         No
# 88872                                      A passing fad         No
# 88876  Useful for immutable record keeping outside of...         No
#
#                                        ITperson OffOn SocialMedia  \
# 0      Fortunately, someone else has that title   Yes     Twitter
# 1                                           Yes   Yes   Instagram
# 3                                          SIGH   Yes      Reddit
# 4                                      Also Yes   Yes    Facebook
# 7                                          SIGH   Yes     YouTube
# ...                                         ...   ...         ...
# 88854                                      SIGH   Yes         NaN
# 88860                                      SIGH   Yes    WhatsApp
# 88865                                      SIGH   Yes     YouTube
# 88872                                       Yes   Yes     YouTube
# 88876                                      SIGH    No    WhatsApp
#
#                    Extraversion ScreenName        SOVisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# 7      In real life (in person)     Handle              2012
# ...                         ...        ...               ...
# 88854                    Online   Username              2011
# 88860  In real life (in person)   Username              2014
# 88865  In real life (in person)     Handle              2017
# 88872  In real life (in person)      Login              2009
# 88876  In real life (in person)   Username              2008
#
#                            SOVisitFreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 3                Daily or almost daily
# 4               Multiple times per day
# 7                 A few times per week
# ...                                ...
# 88854             A few times per week
# 88860           Multiple times per day
# 88865  A few times per month or weekly
# 88872  A few times per month or weekly
# 88876             A few times per week
#
#                                                SOVisitTo  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# 7      Find answers to specific questions;Learn how t...
# ...                                                  ...
# 88854  Find answers to specific questions;Learn how t...
# 88860                 Find answers to specific questions
# 88865  Find answers to specific questions;Contribute ...
# 88872                 Find answers to specific questions
# 88876                 Find answers to specific questions
#
#                       SOFindAnswer                         SOTimeSaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# 7          Less than once per week  Stack Overflow was slightly faster
# ...                            ...                                 ...
# 88854           1-2 times per week  Stack Overflow was slightly faster
# 88860  More than 10 times per week      Stack Overflow was much faster
# 88865      Less than once per week      Stack Overflow was much faster
# 88872           1-2 times per week      Stack Overflow was much faster
# 88876          6-10 times per week  Stack Overflow was slightly faster
#
#        SOHowMuchTime SOAccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# 7      11-30 minutes       Yes
# ...              ...       ...
# 88854   0-10 minutes       Yes
# 88860  31-60 minutes       Yes
# 88865    60+ minutes       Yes
# 88872  31-60 minutes       Yes
# 88876   0-10 minutes       Yes
#
#                                               SOPartFreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# 7                    Less than once per month or monthly
# ...                                                  ...
# 88854  I have never participated in Q&A on Stack Over...
# 88860                    A few times per month or weekly
# 88865                Less than once per month or monthly
# 88872                    A few times per month or weekly
# 88876  I have never participated in Q&A on Stack Over...
#
#                                                   SOJobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# 7                                                    Yes
# ...                                                  ...
# 88854  No, I knew that Stack Overflow had a job board...
# 88860  No, I knew that Stack Overflow had a job board...
# 88865  No, I didn't know that Stack Overflow had a jo...
# 88872  No, I knew that Stack Overflow had a job board...
# 88876  No, I didn't know that Stack Overflow had a jo...
#
#                                                 EntTeams           SOComm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# 7                    No, and I don't know what those are  Yes, definitely
# ...                                                  ...              ...
# 88854  No, I've heard of them, but I am not part of a...          Neutral
# 88860                No, and I don't know what those are    Yes, somewhat
# 88865                No, and I don't know what those are          Neutral
# 88872                No, and I don't know what those are          Neutral
# 88876                No, and I don't know what those are   No, not at all
#
#                                  WelcomeChange  \
# 0      Just as welcome now as I felt last year
# 1      Just as welcome now as I felt last year
# 3      Just as welcome now as I felt last year
# 4      Just as welcome now as I felt last year
# 7        A lot more welcome now than last year
# ...                                        ...
# 88854  Just as welcome now as I felt last year
# 88860  Just as welcome now as I felt last year
# 88865  Just as welcome now as I felt last year
# 88872  Just as welcome now as I felt last year
# 88876                                      NaN
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# 7      Tech articles written by other developers;Indu...  24.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88854       Courses on technologies you're interested in  23.0  Woman   Yes
# 88860  Industry news about technologies you're intere...  15.0    Man    No
# 88865  Tech articles written by other developers;Cour...  74.0    Man    No
# 88872                                                NaN  25.0    NaN    No
# 88876  Tech articles written by other developers;Indu...  40.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# 7      Straight / Heterosexual
# ...                        ...
# 88854                 Bisexual
# 88860  Straight / Heterosexual
# 88865                      NaN
# 88872  Straight / Heterosexual
# 88876  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# 7                                                    NaN        NaN
# ...                                                  ...        ...
# 88854                       White or of European descent         No
# 88860  Hispanic or Latino/Latina;White or of European...         No
# 88865                       White or of European descent         No
# 88872                       White or of European descent         No
# 88876                       White or of European descent         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# 7      Appropriate in length  Neither easy nor difficult
# ...                      ...                         ...
# 88854  Appropriate in length                        Easy
# 88860              Too short                        Easy
# 88865  Appropriate in length                        Easy
# 88872  Appropriate in length                        Easy
# 88876  Appropriate in length                        Easy
#
# [36443 rows x 85 columns]

# %%
# OR
python = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[python, 'LanguageWorkedWith']

# so basically, youll see that python is common in this list
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
# updating rows and columns
# updating columns
# making our column names to be all Capital letters
df.columns = [x.upper() for x in df.columns] #this is a list comprehension
df
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OPENSOURCER  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OPENSOURCE  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               EMPLOYMENT  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       COUNTRY         STUDENT  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EDLEVEL  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UNDERGRADMAJOR  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EDUOTHER  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         ORGSIZE  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  DEVTYPE YEARSCODE AGE1STCODE  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            YEARSCODEPRO           CAREERSAT                 JOBSAT  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    MGRIDIOT  MGRMONEY   MGRWANT  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  JOBSEEK  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                LASTHIREDATE  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  LASTINT FIZZBUZZ  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               JOBFACTORS  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             RESUMEUPDATE CURRENCYSYMBOL  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                CURRENCYDESC  COMPTOTAL COMPFREQ  CONVERTEDCOMP  WORKWEEKHRS  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 WORKPLAN  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            WORKCHALLENGE  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              WORKREMOTE WORKLOC                  IMPSYN  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        CODEREV  CODEREVHRS  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            UNITTESTS  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              PURCHASEHOW  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                               Not sure
# 3      Developers typically have the most influence o...
# 4                                               Not sure
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                         PURCHASEWHAT  \
# 0                                NaN
# 1                                NaN
# 2      I have little or no influence
# 3      I have little or no influence
# 4      I have little or no influence
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                       LANGUAGEWORKEDWITH  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   LANGUAGEDESIRENEXTYEAR  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      DATABASEWORKEDWITH  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   DATABASEDESIRENEXTYEAR  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       PLATFORMWORKEDWITH  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   PLATFORMDESIRENEXTYEAR  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 WEBFRAMEWORKEDWITH  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              WEBFRAMEDESIRENEXTYEAR      MISCTECHWORKEDWITH  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          MISCTECHDESIRENEXTYEAR  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               DEVENVIRON        OPSYS  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    CONTAINERS BLOCKCHAINORG  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             BLOCKCHAINIS BETTERLIFE  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        ITPERSON  OFFON SOCIALMEDIA  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    EXTRAVERSION SCREENNAME        SOVISIT1ST  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            SOVISITFREQ  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                SOVISITTO  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       SOFINDANSWER                         SOTIMESAVED  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        SOHOWMUCHTIME SOACCOUNT  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               SOPARTFREQ  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   SOJOBS  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 ENTTEAMS           SOCOMM  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   WELCOMECHANGE  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONEWCONTENT   AGE GENDER TRANS  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      SEXUALITY  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                ETHNICITY DEPENDENTS  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SURVEYLENGTH                  SURVEYEASE
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
# to normal
df.columns = [x.capitalize() for x in df.columns] #this is a list comprehension
df
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              Opensourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               Opensource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  Edlevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           Undergradmajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 Eduother  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         Orgsize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  Devtype Yearscode Age1stcode  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            Yearscodepro           Careersat                 Jobsat  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    Mgridiot  Mgrmoney   Mgrwant  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  Jobseek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                Lasthiredate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  Lastint Fizzbuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               Jobfactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             Resumeupdate Currencysymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 Workplan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            Workchallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              Workremote Workloc                  Impsyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        Coderev  Coderevhrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            Unittests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              Purchasehow  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                               Not sure
# 3      Developers typically have the most influence o...
# 4                                               Not sure
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                         Purchasewhat  \
# 0                                NaN
# 1                                NaN
# 2      I have little or no influence
# 3      I have little or no influence
# 4      I have little or no influence
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                       Languageworkedwith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   Languagedesirenextyear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      Databaseworkedwith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   Databasedesirenextyear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       Platformworkedwith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   Platformdesirenextyear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 Webframeworkedwith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              Webframedesirenextyear      Misctechworkedwith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          Misctechdesirenextyear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               Devenviron        Opsys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers Blockchainorg  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             Blockchainis Betterlife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        Itperson  Offon Socialmedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    Extraversion Screenname        Sovisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            Sovisitfreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                Sovisitto  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       Sofindanswer                         Sotimesaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        Sohowmuchtime Soaccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               Sopartfreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   Sojobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 Entteams           Socomm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   Welcomechange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             Sonewcontent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 Surveylength                  Surveyease
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
# replacing the spaces in our column names to underscore, or vice-vesar, or with anything
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              Opensourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               Opensource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  Edlevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           Undergradmajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 Eduother  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         Orgsize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  Devtype Yearscode Age1stcode  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            Yearscodepro           Careersat                 Jobsat  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    Mgridiot  Mgrmoney   Mgrwant  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  Jobseek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                Lasthiredate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  Lastint Fizzbuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               Jobfactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             Resumeupdate Currencysymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 Workplan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            Workchallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              Workremote Workloc                  Impsyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        Coderev  Coderevhrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            Unittests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              Purchasehow  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                               Not sure
# 3      Developers typically have the most influence o...
# 4                                               Not sure
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                         Purchasewhat  \
# 0                                NaN
# 1                                NaN
# 2      I have little or no influence
# 3      I have little or no influence
# 4      I have little or no influence
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                       Languageworkedwith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   Languagedesirenextyear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      Databaseworkedwith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   Databasedesirenextyear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       Platformworkedwith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   Platformdesirenextyear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 Webframeworkedwith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              Webframedesirenextyear      Misctechworkedwith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          Misctechdesirenextyear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               Devenviron        Opsys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers Blockchainorg  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             Blockchainis Betterlife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        Itperson  Offon Socialmedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    Extraversion Screenname        Sovisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            Sovisitfreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                Sovisitto  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       Sofindanswer                         Sotimesaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        Sohowmuchtime Soaccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               Sopartfreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   Sojobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 Entteams           Socomm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   Welcomechange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             Sonewcontent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 Surveylength                  Surveyease
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
df.columns
# Out:
# Index(['Respondent', 'Mainbranch', 'Hobbyist', 'Opensourcer', 'Opensource',
#        'Employment', 'Country', 'Student', 'Edlevel', 'Undergradmajor',
#        'Eduother', 'Orgsize', 'Devtype', 'Yearscode', 'Age1stcode',
#        'Yearscodepro', 'Careersat', 'Jobsat', 'Mgridiot', 'Mgrmoney',
#        'Mgrwant', 'Jobseek', 'Lasthiredate', 'Lastint', 'Fizzbuzz',
#        'Jobfactors', 'Resumeupdate', 'Currencysymbol', 'Currencydesc',
#        'Comptotal', 'Compfreq', 'Convertedcomp', 'Workweekhrs', 'Workplan',
#        'Workchallenge', 'Workremote', 'Workloc', 'Impsyn', 'Coderev',
#        'Coderevhrs', 'Unittests', 'Purchasehow', 'Purchasewhat',
#        'Languageworkedwith', 'Languagedesirenextyear', 'Databaseworkedwith',
#        'Databasedesirenextyear', 'Platformworkedwith',
#        'Platformdesirenextyear', 'Webframeworkedwith',
#        'Webframedesirenextyear', 'Misctechworkedwith',
#        'Misctechdesirenextyear', 'Devenviron', 'Opsys', 'Containers',
#        'Blockchainorg', 'Blockchainis', 'Betterlife', 'Itperson', 'Offon',
#        'Socialmedia', 'Extraversion', 'Screenname', 'Sovisit1st',
#        'Sovisitfreq', 'Sovisitto', 'Sofindanswer', 'Sotimesaved',
#        'Sohowmuchtime', 'Soaccount', 'Sopartfreq', 'Sojobs', 'Entteams',
#        'Socomm', 'Welcomechange', 'Sonewcontent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'Surveylength', 'Surveyease'],
#       dtype='object')

# %%
# to change some columns and not all
df.rename(columns={'RESPONDENT':'SERIAL_NO', 'MAINBRANCH': 'MAIN_BRANCH'}, inplace=True) #inplace make things permanent
df
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              Opensourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               Opensource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  Edlevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           Undergradmajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 Eduother  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         Orgsize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  Devtype Yearscode Age1stcode  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            Yearscodepro           Careersat                 Jobsat  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    Mgridiot  Mgrmoney   Mgrwant  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  Jobseek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                Lasthiredate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  Lastint Fizzbuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               Jobfactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             Resumeupdate Currencysymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 Workplan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            Workchallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              Workremote Workloc                  Impsyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        Coderev  Coderevhrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            Unittests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              Purchasehow  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                               Not sure
# 3      Developers typically have the most influence o...
# 4                                               Not sure
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                         Purchasewhat  \
# 0                                NaN
# 1                                NaN
# 2      I have little or no influence
# 3      I have little or no influence
# 4      I have little or no influence
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                       Languageworkedwith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   Languagedesirenextyear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      Databaseworkedwith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   Databasedesirenextyear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       Platformworkedwith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   Platformdesirenextyear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 Webframeworkedwith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              Webframedesirenextyear      Misctechworkedwith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          Misctechdesirenextyear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               Devenviron        Opsys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers Blockchainorg  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             Blockchainis Betterlife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        Itperson  Offon Socialmedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    Extraversion Screenname        Sovisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            Sovisitfreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                Sovisitto  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       Sofindanswer                         Sotimesaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        Sohowmuchtime Soaccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               Sopartfreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   Sojobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 Entteams           Socomm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   Welcomechange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             Sonewcontent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 Surveylength                  Surveyease
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
# Changin specific columns in a row
# Use this for a much smaller data
# df.loc[2] = [column1, column2, column3, ...]
#but we have a much larger data so we use the below
df.loc[2, 'MAIN_BRANCH'] = 'I am a student'
df
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              Opensourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               Opensource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  Edlevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           Undergradmajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 Eduother  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         Orgsize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  Devtype Yearscode Age1stcode  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            Yearscodepro           Careersat                 Jobsat  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    Mgridiot  Mgrmoney   Mgrwant  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  Jobseek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                Lasthiredate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  Lastint Fizzbuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               Jobfactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             Resumeupdate Currencysymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 Workplan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            Workchallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              Workremote Workloc                  Impsyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        Coderev  Coderevhrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            Unittests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              Purchasehow  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                               Not sure  ...
# 3      Developers typically have the most influence o...  ...
# 4                                               Not sure  ...
# ...                                                  ...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882                                                NaN  ...
#
#                                   Languagedesirenextyear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      Databaseworkedwith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   Databasedesirenextyear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       Platformworkedwith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   Platformdesirenextyear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 Webframeworkedwith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              Webframedesirenextyear      Misctechworkedwith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          Misctechdesirenextyear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               Devenviron        Opsys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers Blockchainorg  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             Blockchainis Betterlife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        Itperson  Offon Socialmedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    Extraversion Screenname        Sovisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            Sovisitfreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                Sovisitto  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       Sofindanswer                         Sotimesaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        Sohowmuchtime Soaccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               Sopartfreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   Sojobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 Entteams           Socomm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   Welcomechange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             Sonewcontent   Age Gender  Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man     No
# 1      Tech articles written by other developers;Indu...  19.0    Man     No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man     No
# 3      Tech articles written by other developers;Indu...  22.0    Man     No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man     No
# ...                                                  ...   ...    ...    ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man     No
# 88879                                                NaN   NaN    NaN    NaN
# 88880                                                NaN   NaN    NaN    NaN
# 88881                                                NaN   NaN    NaN    NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man     No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 Surveylength                  Surveyease     MAIN_BRANCH
# 0      Appropriate in length  Neither easy nor difficult             nan
# 1      Appropriate in length  Neither easy nor difficult             nan
# 2      Appropriate in length  Neither easy nor difficult  I am a student
# 3      Appropriate in length                        Easy             nan
# 4      Appropriate in length                        Easy             nan
# ...                      ...                         ...             ...
# 88878  Appropriate in length                        Easy             nan
# 88879                    NaN                         NaN             nan
# 88880                    NaN                         NaN             nan
# 88881                    NaN                         NaN             nan
# 88882  Appropriate in length                        Easy             nan
#
# [88883 rows x 86 columns]

# %%
# SORTING DATA
# Sorting with one column
#df.sort_values(by='HOBBYIST') #automatically it is in ascending order. so to make it in decending order
df.sort_values(by='Hobbyist', ascending=False)
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 55959       56315  I am not primarily a developer, but I write co...      Yes
# 55966       56322                     I am a developer by profession      Yes
# 55965       56321                     I am a developer by profession      Yes
# 55964       56320                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 63768       64177                     I am a developer by profession       No
# 20021       20133                     I am a developer by profession       No
# 20024       20136                     I am a developer by profession       No
# 20027       20139                     I am a developer by profession       No
# 64200       64612                     I am a developer by profession       No
#
#                       Opensourcer  \
# 0                           Never
# 55959  Once a month or more often
# 55966                       Never
# 55965                       Never
# 55964  Once a month or more often
# ...                           ...
# 63768                       Never
# 20021                       Never
# 20024                       Never
# 20027     Less than once per year
# 64200                       Never
#
#                                               Opensource  \
# 0      The quality of OSS and closed source software ...
# 55959  The quality of OSS and closed source software ...
# 55966  The quality of OSS and closed source software ...
# 55965  OSS is, on average, of HIGHER quality than pro...
# 55964  The quality of OSS and closed source software ...
# ...                                                  ...
# 63768  The quality of OSS and closed source software ...
# 20021  The quality of OSS and closed source software ...
# 20024  OSS is, on average, of LOWER quality than prop...
# 20027  The quality of OSS and closed source software ...
# 64200  The quality of OSS and closed source software ...
#
#                                    Employment         Country         Student  \
# 0      Not employed, and not looking for work  United Kingdom              No
# 55959                      Employed full-time     Switzerland  Yes, part-time
# 55966                      Employed part-time          Serbia              No
# 55965                      Employed full-time          Canada              No
# 55964                      Employed full-time         Ireland              No
# ...                                       ...             ...             ...
# 63768                      Employed full-time      Kyrgyzstan              No
# 20021                      Employed full-time       Argentina              No
# 20024                      Employed full-time           India              No
# 20027                      Employed full-time   United States              No
# 64200                      Employed full-time   United States              No
#
#                                                  Edlevel  \
# 0                              Primary/elementary school
# 55959                                                NaN
# 55966  Secondary school (e.g. American high school, G...
# 55965                                   Associate degree
# 55964           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 63768        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 20021           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 20024        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 20027        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 64200           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                           Undergradmajor  \
# 0                                                    NaN
# 55959  Computer science, computer engineering, or sof...
# 55966                                                NaN
# 55965  Fine arts or performing arts (ex. graphic desi...
# 55964                      Web development or web design
# ...                                                  ...
# 63768  Information systems, information technology, o...
# 20021  Computer science, computer engineering, or sof...
# 20024  Computer science, computer engineering, or sof...
# 20027  Computer science, computer engineering, or sof...
# 64200  A social science (ex. anthropology, psychology...
#
#                                                 Eduother  \
# 0      Taught yourself a new language, framework, or ...
# 55959  Taken an online course in programming or softw...
# 55966  Taken an online course in programming or softw...
# 55965  Taken an online course in programming or softw...
# 55964  Taught yourself a new language, framework, or ...
# ...                                                  ...
# 63768  Taken an online course in programming or softw...
# 20021  Completed an industry certification program (e...
# 20024  Taught yourself a new language, framework, or ...
# 20027  Taken an online course in programming or softw...
# 64200  Taken an online course in programming or softw...
#
#                         Orgsize  \
# 0                           NaN
# 55959        10 to 19 employees
# 55966        10 to 19 employees
# 55965        20 to 99 employees
# 55964      100 to 499 employees
# ...                         ...
# 63768      100 to 499 employees
# 20021        10 to 19 employees
# 20024        20 to 99 employees
# 20027  10,000 or more employees
# 64200      100 to 499 employees
#
#                                                  Devtype Yearscode Age1stcode  \
# 0                                                    NaN         4         10
# 55959  Database administrator;Engineer, site reliabil...         5         11
# 55966  Developer, back-end;Developer, desktop or ente...         4         15
# 55965  Developer, back-end;Developer, front-end;Devel...         9         14
# 55964         Developer, front-end;Developer, full-stack        10         10
# ...                                                  ...       ...        ...
# 63768             Developer, front-end;Developer, mobile         5          9
# 20021                                  Developer, mobile        12         19
# 20024       Data or business analyst;Developer, back-end        14         12
# 20027  Data or business analyst;Database administrato...        26          6
# 64200                               Developer, front-end         4         15
#
#            Yearscodepro              Careersat  \
# 0                   NaN                    NaN
# 55959                 3  Slightly dissatisfied
# 55966  Less than 1 year     Slightly satisfied
# 55965                 5         Very satisfied
# 55964                 6         Very satisfied
# ...                 ...                    ...
# 63768                 5         Very satisfied
# 20021                 8     Slightly satisfied
# 20024                 2     Slightly satisfied
# 20027                14         Very satisfied
# 64200                 2         Very satisfied
#
#                                    Jobsat            Mgridiot  Mgrmoney  \
# 0                                     NaN                 NaN       NaN
# 55959               Slightly dissatisfied      Very confident        No
# 55966                      Very satisfied      Very confident        No
# 55965                      Very satisfied      Very confident       Yes
# 55964                      Very satisfied      Very confident       Yes
# ...                                   ...                 ...       ...
# 63768                      Very satisfied      Very confident  Not sure
# 20021                  Slightly satisfied  Somewhat confident  Not sure
# 20024               Slightly dissatisfied  Somewhat confident  Not sure
# 20027                      Very satisfied  Somewhat confident        No
# 64200  Neither satisfied nor dissatisfied      Very confident       Yes
#
#         Mgrwant                                            Jobseek  \
# 0           NaN                                                NaN
# 55959        No  I’m not actively looking, but I am open to new...
# 55966  Not sure       I am not interested in new job opportunities
# 55965       Yes       I am not interested in new job opportunities
# 55964  Not sure       I am not interested in new job opportunities
# ...         ...                                                ...
# 63768  Not sure                    I am actively looking for a job
# 20021       Yes  I’m not actively looking, but I am open to new...
# 20024       Yes                    I am actively looking for a job
# 20027  Not sure       I am not interested in new job opportunities
# 64200  Not sure                    I am actively looking for a job
#
#                Lasthiredate  \
# 0                       NaN
# 55959         1-2 years ago
# 55966  Less than a year ago
# 55965         3-4 years ago
# 55964         3-4 years ago
# ...                     ...
# 63768         3-4 years ago
# 20021         3-4 years ago
# 20024         1-2 years ago
# 20027         3-4 years ago
# 64200         1-2 years ago
#
#                                                  Lastint Fizzbuzz  \
# 0                                                    NaN      NaN
# 55959  Interview with people in senior / management r...       No
# 55966                                                NaN       No
# 55965  Solve a brain-teaser style puzzle;Interview wi...       No
# 55964  Complete a take-home project;Interview with pe...       No
# ...                                                  ...      ...
# 63768  Write any code;Complete a take-home project;In...       No
# 20021                                     Write any code       No
# 20024  Write code by hand (e.g., on a whiteboard);Sol...      Yes
# 20027  Write any code;Write code by hand (e.g., on a ...       No
# 64200  Complete a take-home project;Interview with pe...       No
#
#                                               Jobfactors  \
# 0                                                    NaN
# 55959  Languages, frameworks, and other technologies ...
# 55966  Office environment or company culture;Remote w...
# 55965  Languages, frameworks, and other technologies ...
# 55964  Languages, frameworks, and other technologies ...
# ...                                                  ...
# 63768  Industry that I'd be working in;Languages, fra...
# 20021  Languages, frameworks, and other technologies ...
# 20024  Office environment or company culture;Remote w...
# 20027  Financial performance or funding status of the...
# 64200  Office environment or company culture;Opportun...
#
#                                             Resumeupdate Currencysymbol  \
# 0                                                    NaN            NaN
# 55959  Something else changed (education, award, medi...            CHF
# 55966   My job status changed (promotion, new job, etc.)            RSD
# 55965   My job status changed (promotion, new job, etc.)            CAD
# 55964                   I was preparing for a job search            EUR
# ...                                                  ...            ...
# 63768                   I was preparing for a job search            KGS
# 20021  I heard about a job opportunity (from a recrui...            ARS
# 20024  I had a negative experience or interaction at ...            INR
# 20027  Something else changed (education, award, medi...            USD
# 64200                   I was preparing for a job search            USD
#
#                Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 55959           Swiss franc    81250.0   Yearly        81626.0         41.0
# 55966         Serbian dinar        NaN  Monthly            NaN         40.0
# 55965       Canadian dollar    72500.0   Yearly        55345.0         50.0
# 55964         European Euro    58000.0   Yearly        66453.0         37.5
# ...                     ...        ...      ...            ...          ...
# 63768       Kyrgyzstani som   103500.0  Monthly        18084.0         60.0
# 20021        Argentine peso    44000.0  Monthly        14208.0         40.0
# 20024          Indian rupee    44000.0  Monthly         7392.0         50.0
# 20027  United States dollar   350000.0   Yearly       350000.0         45.0
# 64200  United States dollar    70000.0   Yearly        70000.0         40.0
#
#                                                 Workplan  \
# 0                                                    NaN
# 55959  There is a schedule and/or spec (made by me or...
# 55966  There is a schedule and/or spec (made by me or...
# 55965  There's no schedule or spec; I work on what se...
# 55964  There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 63768  There is a schedule and/or spec (made by me or...
# 20021  There is a schedule and/or spec (made by me or...
# 20024  There's no schedule or spec; I work on what se...
# 20027  There is a schedule and/or spec (made by me or...
# 64200  There is a schedule and/or spec (made by me or...
#
#                                            Workchallenge  \
# 0                                                    NaN
# 55959  Being tasked with non-development work;Distrac...
# 55966  Being tasked with non-development work;Inadequ...
# 55965  Not enough people for the workload;Time spent ...
# 55964  Non-work commitments (parenting, school work, ...
# ...                                                  ...
# 63768  Being tasked with non-development work;Distrac...
# 20021  Distracting work environment;Time spent commut...
# 20024  Distracting work environment;Not enough people...
# 20027  Being tasked with non-development work;Distrac...
# 64200  Meetings;Time spent commuting;Toxic work envir...
#
#                                   Workremote  \
# 0                                        NaN
# 55959       Less than once per month / Never
# 55966       Less than once per month / Never
# 55965       Less than once per month / Never
# 55964  More than half, but not all, the time
# ...                                      ...
# 63768                  A few days each month
# 20021       Less than once per month / Never
# 20024       Less than once per month / Never
# 20027                  A few days each month
# 64200                  A few days each month
#
#                                               Workloc                  Impsyn  \
# 0                                                 NaN                     NaN
# 55959  Other place, such as a coworking space or cafe  A little above average
# 55966                                            Home  A little below average
# 55965                                          Office  A little above average
# 55964                                            Home  A little above average
# ...                                               ...                     ...
# 63768                                          Office                 Average
# 20021                                          Office  A little above average
# 20024                                            Home                 Average
# 20027                                          Office  A little above average
# 64200                                          Office  A little above average
#
#                                        Coderev  Coderevhrs  \
# 0                                          NaN         NaN
# 55959                                       No         NaN
# 55966                                       No         NaN
# 55965                                       No         NaN
# 55964  Yes, because I see value in code review         2.0
# ...                                        ...         ...
# 63768  Yes, because I see value in code review         3.0
# 20021                                       No         NaN
# 20024  Yes, because I see value in code review        10.0
# 20027  Yes, because I see value in code review         6.0
# 64200                                       No         NaN
#
#                                                Unittests  \
# 0                                                    NaN
# 55959                          No, but I think we should
# 55966                      Yes, it's part of our process
# 55965                          No, but I think we should
# 55964  Yes, it's not part of our process but the deve...
# ...                                                  ...
# 63768                      Yes, it's part of our process
# 20021                      Yes, it's part of our process
# 20024                          No, but I think we should
# 20027                      Yes, it's part of our process
# 64200                          No, but I think we should
#
#                                              Purchasehow  ...  \
# 0                                                    NaN  ...
# 55959  Developers typically have the most influence o...  ...
# 55966  Developers typically have the most influence o...  ...
# 55965  Developers typically have the most influence o...  ...
# 55964  Developers typically have the most influence o...  ...
# ...                                                  ...  ...
# 63768  The CTO, CIO, or other management purchase new...  ...
# 20021                                           Not sure  ...
# 20024                                           Not sure  ...
# 20027                                           Not sure  ...
# 64200  The CTO, CIO, or other management purchase new...  ...
#
#                                   Languagedesirenextyear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 55959                  Bash/Shell/PowerShell;Python;Rust
# 55966                             C;C++;C#;SQL;Other(s):
# 55965                       C#;Java;SQL;Swift;TypeScript
# 55964       Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript
# ...                                                  ...
# 63768   HTML/CSS;JavaScript;Kotlin;Python;SQL;TypeScript
# 20021                                              Swift
# 20024  Bash/Shell/PowerShell;C;C++;Java;JavaScript;Py...
# 20027                                                 C#
# 64200                         HTML/CSS;JavaScript;Python
#
#                          Databaseworkedwith  \
# 0                                    SQLite
# 55959          MariaDB;Microsoft SQL Server
# 55966                  Microsoft SQL Server
# 55965                                   NaN
# 55964                      PostgreSQL;Redis
# ...                                     ...
# 63768                                   NaN
# 20021                                   NaN
# 20024  Firebase;MongoDB;MySQL;Oracle;SQLite
# 20027                                   NaN
# 64200                                 MySQL
#
#                       Databasedesirenextyear  \
# 0                                      MySQL
# 55959                                MariaDB
# 55966                   Microsoft SQL Server
# 55965          DynamoDB;Microsoft SQL Server
# 55964                                    NaN
# ...                                      ...
# 63768  MongoDB;MySQL;PostgreSQL;Redis;SQLite
# 20021                                    NaN
# 20024   Cassandra;Couchbase;Firebase;MongoDB
# 20027                                    NaN
# 64200                                  MySQL
#
#                                       Platformworkedwith  \
# 0                                          MacOS;Windows
# 55959                                      Linux;Windows
# 55966                                            Windows
# 55965                          Android;iOS;MacOS;Windows
# 55964  AWS;Docker;Heroku;Kubernetes;Linux;MacOS;Slack...
# ...                                                  ...
# 63768                  Android;Linux;MacOS;Slack;Windows
# 20021                                                iOS
# 20024     Android;Arduino;AWS;Linux;Raspberry Pi;Windows
# 20027                                              Linux
# 64200                           AWS;Docker;MacOS;Windows
#
#                                   Platformdesirenextyear  \
# 0                                Android;Arduino;Windows
# 55959                              Android;Linux;Windows
# 55966                                            Windows
# 55965                    Android;iOS;Linux;MacOS;Windows
# 55964  AWS;Docker;Kubernetes;Linux;MacOS;Raspberry Pi...
# ...                                                  ...
# 63768  Android;AWS;Docker;Google Cloud Platform;Herok...
# 20021                                            Android
# 20024             Arduino;AWS;Linux;Raspberry Pi;Windows
# 20027                                                NaN
# 64200                                   AWS;Docker;MacOS
#
#                           Webframeworkedwith  \
# 0                               Django;Flask
# 55959                         ASP.NET;Django
# 55966                                    NaN
# 55965                                    NaN
# 55964  Express;React.js;Ruby on Rails;Vue.js
# ...                                      ...
# 63768                               React.js
# 20021                                    NaN
# 20024                                    NaN
# 20027              Angular/Angular.js;Django
# 64200             Angular/Angular.js;Express
#
#                            Webframedesirenextyear Misctechworkedwith  \
# 0                                    Flask;jQuery            Node.js
# 55959                                Django;Flask            Ansible
# 55966                                         NaN               .NET
# 55965                                         NaN      .NET;Unity 3D
# 55964                              Express;Vue.js            Node.js
# ...                                           ...                ...
# 63768  Angular/Angular.js;Express;React.js;Vue.js       React Native
# 20021                                         NaN                NaN
# 20024                                         NaN            Node.js
# 20027                                         NaN                NaN
# 64200           Express;React.js;Vue.js;Other(s):            Node.js
#
#                  Misctechdesirenextyear  \
# 0                               Node.js
# 55959  Ansible;TensorFlow;Torch/PyTorch
# 55966                    .NET;Other(s):
# 55965                     .NET;Unity 3D
# 55964                           Node.js
# ...                                 ...
# 63768              Node.js;React Native
# 20021                      React Native
# 20024                           Node.js
# 20027                   .NET;TensorFlow
# 64200                           Node.js
#
#                                               Devenviron        Opsys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 55959                                          Emacs;Vim  Linux-based
# 55966                   Visual Studio;Visual Studio Code      Windows
# 55965    Android Studio;Sublime Text;Visual Studio;Xcode        MacOS
# 55964                                   Sublime Text;Vim        MacOS
# ...                                                  ...          ...
# 63768                              IntelliJ;Sublime Text  Linux-based
# 20021                                              Xcode        MacOS
# 20024  Atom;Coda;Eclipse;Notepad++;Sublime Text;Visua...      Windows
# 20027                                                Vim  Linux-based
# 64200                                 Visual Studio Code      Windows
#
#                                               Containers  \
# 0                                I do not use containers
# 55959                            I do not use containers
# 55966                            I do not use containers
# 55965                            I do not use containers
# 55964  Development;Testing;Production;Outside of work...
# ...                                                  ...
# 63768                     Development;Testing;Production
# 20021                            I do not use containers
# 20024                            I do not use containers
# 20027                            I do not use containers
# 64200                                        Development
#
#                                  Blockchainorg  \
# 0                                          NaN
# 55959                               Not at all
# 55966                                      NaN
# 55965                               Not at all
# 55964                               Not at all
# ...                                        ...
# 63768  Non-currency applications of blockchain
# 20021                               Not at all
# 20024                                      NaN
# 20027  Non-currency applications of blockchain
# 64200                               Not at all
#
#                                             Blockchainis Betterlife  \
# 0                                                    NaN        Yes
# 55959  Useful across many domains and could change ma...        Yes
# 55966                                                NaN        Yes
# 55965                                      A passing fad        Yes
# 55964                                      A passing fad        Yes
# ...                                                  ...        ...
# 63768                                                NaN        Yes
# 20021  Useful for decentralized currency (i.e., Bitcoin)        Yes
# 20024                                                NaN         No
# 20027  Useful for immutable record keeping outside of...         No
# 64200                  An irresponsible use of resources         No
#
#                                        Itperson  Offon Socialmedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 55959                                  Also Yes    Yes      Reddit
# 55966                                       Yes    Yes     Twitter
# 55965                                      SIGH    Yes     YouTube
# 55964                                      SIGH  What?     YouTube
# ...                                         ...    ...         ...
# 63768                                      SIGH    Yes   Instagram
# 20021                                       Yes  What?    WhatsApp
# 20024                                       Yes    Yes    WhatsApp
# 20027                                       Yes    Yes      Reddit
# 64200                                       Yes    Yes     Twitter
#
#                    Extraversion Screenname        Sovisit1st  \
# 0                        Online   Username              2017
# 55959  In real life (in person)   Username              2013
# 55966  In real life (in person)   Username              2015
# 55965                    Online   Username              2011
# 55964                    Online   Username  I don't remember
# ...                         ...        ...               ...
# 63768                    Online   Username              2011
# 20021  In real life (in person)   Username              2009
# 20024                    Online   Username              2014
# 20027                    Online   Username              2008
# 64200                    Online   Username              2016
#
#                            Sovisitfreq  \
# 0      A few times per month or weekly
# 55959             A few times per week
# 55966             A few times per week
# 55965  A few times per month or weekly
# 55964  A few times per month or weekly
# ...                                ...
# 63768            Daily or almost daily
# 20021            Daily or almost daily
# 20024            Daily or almost daily
# 20027             A few times per week
# 64200             A few times per week
#
#                                                Sovisitto  \
# 0      Find answers to specific questions;Learn how t...
# 55959  Find answers to specific questions;Learn how t...
# 55966  Find answers to specific questions;Learn how t...
# 55965                 Find answers to specific questions
# 55964                 Find answers to specific questions
# ...                                                  ...
# 63768                 Find answers to specific questions
# 20021                 Find answers to specific questions
# 20024  Find answers to specific questions;Learn how t...
# 20027  Find answers to specific questions;Pass the ti...
# 64200                 Find answers to specific questions
#
#                   Sofindanswer                         Sotimesaved  \
# 0           3-5 times per week      Stack Overflow was much faster
# 55959       1-2 times per week  Stack Overflow was slightly faster
# 55966       3-5 times per week      Stack Overflow was much faster
# 55965       1-2 times per week  Stack Overflow was slightly faster
# 55964       1-2 times per week  Stack Overflow was slightly faster
# ...                        ...                                 ...
# 63768  Less than once per week      Stack Overflow was much faster
# 20021      6-10 times per week      Stack Overflow was much faster
# 20024       1-2 times per week  Stack Overflow was slightly faster
# 20027       3-5 times per week      Stack Overflow was much faster
# 64200       3-5 times per week      Stack Overflow was much faster
#
#        Sohowmuchtime Soaccount  \
# 0      31-60 minutes        No
# 55959  11-30 minutes       Yes
# 55966  11-30 minutes       Yes
# 55965  11-30 minutes       Yes
# 55964   0-10 minutes       Yes
# ...              ...       ...
# 63768  11-30 minutes       Yes
# 20021  31-60 minutes       Yes
# 20024    60+ minutes       Yes
# 20027   0-10 minutes       Yes
# 64200  11-30 minutes        No
#
#                                               Sopartfreq  \
# 0                                                    NaN
# 55959                    A few times per month or weekly
# 55966                               A few times per week
# 55965                Less than once per month or monthly
# 55964                Less than once per month or monthly
# ...                                                  ...
# 63768  I have never participated in Q&A on Stack Over...
# 20021                               A few times per week
# 20024                Less than once per month or monthly
# 20027                Less than once per month or monthly
# 64200                                                NaN
#
#                                                   Sojobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 55959  No, I knew that Stack Overflow had a job board...
# 55966  No, I knew that Stack Overflow had a job board...
# 55965  No, I knew that Stack Overflow had a job board...
# 55964  No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 63768                                                Yes
# 20021  No, I knew that Stack Overflow had a job board...
# 20024  No, I knew that Stack Overflow had a job board...
# 20027                                                Yes
# 64200  No, I knew that Stack Overflow had a job board...
#
#                                                 Entteams           Socomm  \
# 0                    No, and I don't know what those are          Neutral
# 55959                No, and I don't know what those are   No, not really
# 55966                No, and I don't know what those are  Yes, definitely
# 55965                No, and I don't know what those are   No, not really
# 55964  No, I've heard of them, but I am not part of a...   No, not at all
# ...                                                  ...              ...
# 63768                No, and I don't know what those are   No, not really
# 20021  No, I've heard of them, but I am not part of a...    Yes, somewhat
# 20024                No, and I don't know what those are          Neutral
# 20027  No, I've heard of them, but I am not part of a...    Yes, somewhat
# 64200  No, I've heard of them, but I am not part of a...          Neutral
#
#                                   Welcomechange  \
# 0       Just as welcome now as I felt last year
# 55959   Just as welcome now as I felt last year
# 55966     A lot more welcome now than last year
# 55965   Just as welcome now as I felt last year
# 55964   Just as welcome now as I felt last year
# ...                                         ...
# 63768   Just as welcome now as I felt last year
# 20021  Somewhat more welcome now than last year
# 20024     A lot more welcome now than last year
# 20027   Just as welcome now as I felt last year
# 64200  Somewhat less welcome now than last year
#
#                                             Sonewcontent   Age Gender  Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man     No
# 55959  Tech articles written by other developers;Tech...  29.0    Man     No
# 55966  Tech articles written by other developers;Indu...  19.0    NaN    NaN
# 55965       Courses on technologies you're interested in  24.0    Man     No
# 55964                                                NaN  28.0    Man     No
# ...                                                  ...   ...    ...    ...
# 63768  Tech articles written by other developers;Indu...  26.0    Man     No
# 20021  Tech articles written by other developers;Cour...  31.0    Man     No
# 20024  Tech articles written by other developers;Cour...  25.0    Man     No
# 20027                Tech meetups or events in your area  34.0    Man     No
# 64200  Tech articles written by other developers;Indu...  28.0    Man     No
#
#                      Sexuality                     Ethnicity Dependents  \
# 0      Straight / Heterosexual                           NaN         No
# 55959  Straight / Heterosexual  White or of European descent         No
# 55966  Straight / Heterosexual  White or of European descent         No
# 55965           Gay or Lesbian  White or of European descent         No
# 55964  Straight / Heterosexual  White or of European descent         No
# ...                        ...                           ...        ...
# 63768  Straight / Heterosexual                    East Asian         No
# 20021  Straight / Heterosexual     Hispanic or Latino/Latina        Yes
# 20024  Straight / Heterosexual                   South Asian        Yes
# 20027  Straight / Heterosexual  White or of European descent        Yes
# 64200  Straight / Heterosexual   Black or of African descent         No
#
#                 Surveylength                  Surveyease MAIN_BRANCH
# 0      Appropriate in length  Neither easy nor difficult         nan
# 55959  Appropriate in length  Neither easy nor difficult         nan
# 55966  Appropriate in length                        Easy         nan
# 55965               Too long                        Easy         nan
# 55964  Appropriate in length                        Easy         nan
# ...                      ...                         ...         ...
# 63768  Appropriate in length                        Easy         nan
# 20021               Too long                        Easy         nan
# 20024               Too long  Neither easy nor difficult         nan
# 20027              Too short                        Easy         nan
# 64200  Appropriate in length                        Easy         nan
#
# [88883 rows x 86 columns]

# %%
# sorting with multiple columns
df.sort_values(by=['Hobbyist','Student'], ascending=False)
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 26             27  I used to be a developer by profession, but no...      Yes
# 86             87                     I am a developer by profession      Yes
# 114           115                     I am a developer by profession      Yes
# 149           151                     I am a developer by profession      Yes
# 184           186             I am a student who is learning to code      Yes
# ...           ...                                                ...      ...
# 88873       88062                                                NaN       No
# 88874       88076                                                NaN       No
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
#                    Opensourcer  \
# 26     Less than once per year
# 86                       Never
# 114                      Never
# 149    Less than once per year
# 184    Less than once per year
# ...                        ...
# 88873                    Never
# 88874                    Never
# 88879                    Never
# 88880                    Never
# 88881                    Never
#
#                                               Opensource  \
# 26     OSS is, on average, of HIGHER quality than pro...
# 86     OSS is, on average, of HIGHER quality than pro...
# 114    OSS is, on average, of HIGHER quality than pro...
# 149    OSS is, on average, of LOWER quality than prop...
# 184    The quality of OSS and closed source software ...
# ...                                                  ...
# 88873  OSS is, on average, of LOWER quality than prop...
# 88874  OSS is, on average, of HIGHER quality than pro...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment        Country  \
# 26                    Not employed, but looking for work       Colombia
# 86                                    Employed full-time         Brazil
# 114                                   Employed full-time         Sweden
# 149                                   Employed full-time        Romania
# 184    Independent contractor, freelancer, or self-em...  United States
# ...                                                  ...            ...
# 88873                                                NaN            NaN
# 88874                                 Employed full-time            NaN
# 88879                                                NaN            NaN
# 88880                                 Employed full-time            NaN
# 88881  Independent contractor, freelancer, or self-em...            NaN
#
#               Student                                            Edlevel  \
# 26     Yes, part-time  Some college/university study without earning ...
# 86     Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 114    Yes, part-time                                   Associate degree
# 149    Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 184    Yes, part-time                 Professional degree (JD, MD, etc.)
# ...               ...                                                ...
# 88873             NaN                                                NaN
# 88874             NaN                                                NaN
# 88879             NaN                                                NaN
# 88880             NaN                                                NaN
# 88881             NaN                                                NaN
#
#                                           Undergradmajor  \
# 26     Information systems, information technology, o...
# 86     Computer science, computer engineering, or sof...
# 114    Information systems, information technology, o...
# 149    Computer science, computer engineering, or sof...
# 184    Computer science, computer engineering, or sof...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                                 Eduother  \
# 26     Taken an online course in programming or softw...
# 86     Taken an online course in programming or softw...
# 114                                                  NaN
# 149    Received on-the-job training in software devel...
# 184    Taken an online course in programming or softw...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                         Orgsize  \
# 26                          NaN
# 86     10,000 or more employees
# 114        100 to 499 employees
# 149    5,000 to 9,999 employees
# 184                         NaN
# ...                         ...
# 88873                       NaN
# 88874                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
#
#                                                  Devtype Yearscode Age1stcode  \
# 26     Developer, back-end;Developer, front-end;Devel...         7         15
# 86              Developer, back-end;Developer, front-end        20         15
# 114                                Developer, full-stack         6         13
# 149    Developer, back-end;Developer, desktop or ente...        16         10
# 184                         Developer, front-end;Student         3         13
# ...                                                  ...       ...        ...
# 88873                                                NaN       NaN        NaN
# 88874                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
#
#            Yearscodepro           Careersat              Jobsat  \
# 26                    2                 NaN                 NaN
# 86                    8  Slightly satisfied  Slightly satisfied
# 114    Less than 1 year      Very satisfied      Very satisfied
# 149                  13  Slightly satisfied  Slightly satisfied
# 184                 NaN                 NaN                 NaN
# ...                 ...                 ...                 ...
# 88873               NaN                 NaN                 NaN
# 88874               NaN                 NaN                 NaN
# 88879               NaN                 NaN                 NaN
# 88880               NaN                 NaN                 NaN
# 88881               NaN                 NaN                 NaN
#
#                  Mgridiot Mgrmoney   Mgrwant  \
# 26                    NaN      NaN       NaN
# 86     Somewhat confident      Yes  Not sure
# 114    Somewhat confident      Yes       Yes
# 149    Somewhat confident       No  Not sure
# 184                   NaN      NaN       NaN
# ...                   ...      ...       ...
# 88873                 NaN      NaN       NaN
# 88874                 NaN      NaN       NaN
# 88879                 NaN      NaN       NaN
# 88880                 NaN      NaN       NaN
# 88881                 NaN      NaN       NaN
#
#                                                  Jobseek  \
# 26                                                   NaN
# 86     I’m not actively looking, but I am open to new...
# 114    I’m not actively looking, but I am open to new...
# 149    I’m not actively looking, but I am open to new...
# 184                      I am actively looking for a job
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                 Lasthiredate  \
# 26                       NaN
# 86     More than 4 years ago
# 114     Less than a year ago
# 149     Less than a year ago
# 184            1-2 years ago
# ...                      ...
# 88873                    NaN
# 88874                    NaN
# 88879                    NaN
# 88880                    NaN
# 88881                    NaN
#
#                                                  Lastint Fizzbuzz  \
# 26                                                   NaN      NaN
# 86                   Interview with people in peer roles       No
# 114    Write any code;Complete a take-home project;In...       No
# 149    Write any code;Solve a brain-teaser style puzz...       No
# 184                                                  NaN      NaN
# ...                                                  ...      ...
# 88873                                                NaN      NaN
# 88874                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
#
#                                               Jobfactors  \
# 26                                                   NaN
# 86     Remote work options;Opportunities for professi...
# 114    Office environment or company culture;Opportun...
# 149    Specific department or team I'd be working on;...
# 184    Languages, frameworks, and other technologies ...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                             Resumeupdate Currencysymbol  \
# 26                                                   NaN            NaN
# 86     I heard about a job opportunity (from a recrui...            BRL
# 114                     I was preparing for a job search            SEK
# 149                     I was preparing for a job search            EUR
# 184     My job status changed (promotion, new job, etc.)            NaN
# ...                                                  ...            ...
# 88873                                                NaN            NaN
# 88874                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
#
#          Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 26                NaN        NaN      NaN            NaN          NaN
# 86     Brazilian real    11000.0  Monthly        36060.0         40.0
# 114     Swedish krona    30000.0  Monthly        39768.0         40.0
# 149     European Euro     4000.0  Monthly        54996.0        160.0
# 184               NaN        NaN      NaN            NaN          NaN
# ...               ...        ...      ...            ...          ...
# 88873             NaN        NaN      NaN            NaN          NaN
# 88874             NaN        NaN      NaN            NaN          NaN
# 88879             NaN        NaN      NaN            NaN          NaN
# 88880             NaN        NaN      NaN            NaN          NaN
# 88881             NaN        NaN      NaN            NaN          NaN
#
#                                                 Workplan  \
# 26                                                   NaN
# 86     There is a schedule and/or spec (made by me or...
# 114    There is a schedule and/or spec (made by me or...
# 149    There is a schedule and/or spec (made by me or...
# 184                                                  NaN
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                            Workchallenge  \
# 26                                                   NaN
# 86     Distracting work environment;Meetings;Non-work...
# 114    Not enough people for the workload;Time spent ...
# 149    Distracting work environment;Not enough people...
# 184                                                  NaN
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                               Workremote  \
# 26                                                   NaN
# 86                      Less than once per month / Never
# 114                     Less than once per month / Never
# 149    Less than half the time, but at least one day ...
# 184                                                  NaN
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                               Workloc                  Impsyn  \
# 26                                                NaN                     NaN
# 86                                               Home  A little above average
# 114    Other place, such as a coworking space or cafe                 Average
# 149                                              Home       Far above average
# 184                                               NaN                     NaN
# ...                                               ...                     ...
# 88873                                             NaN                     NaN
# 88874                                             NaN                     NaN
# 88879                                             NaN                     NaN
# 88880                                             NaN                     NaN
# 88881                                             NaN                     NaN
#
#                                        Coderev  Coderevhrs  \
# 26                                         NaN         NaN
# 86     Yes, because I see value in code review        10.0
# 114           Yes, because I was told to do so         1.0
# 149    Yes, because I see value in code review        20.0
# 184                                        NaN         NaN
# ...                                        ...         ...
# 88873                                      NaN         NaN
# 88874                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
#
#                            Unittests  \
# 26                               NaN
# 86     Yes, it's part of our process
# 114        No, and I'm glad we don't
# 149    Yes, it's part of our process
# 184                              NaN
# ...                              ...
# 88873                            NaN
# 88874                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
#
#                                              Purchasehow  ...  \
# 26                                                   NaN  ...
# 86     Developers and management have nearly equal in...  ...
# 114    The CTO, CIO, or other management purchase new...  ...
# 149    The CTO, CIO, or other management purchase new...  ...
# 184                                                  NaN  ...
# ...                                                  ...  ...
# 88873                                                NaN  ...
# 88874                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
#
#                                   Languagedesirenextyear  \
# 26     Clojure;Dart;Elixir;JavaScript;Python;Ruby;SQL...
# 86                  Go;HTML/CSS;JavaScript;Kotlin;Python
# 114                         HTML/CSS;Java;JavaScript;SQL
# 149    Bash/Shell/PowerShell;C++;C#;Go;Java;Kotlin;Py...
# 184         Assembly;C++;HTML/CSS;Java;JavaScript;Python
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                       Databaseworkedwith  \
# 26     Firebase;MongoDB;Microsoft SQL Server;MySQL;Or...
# 86                                  Microsoft SQL Server
# 114          Firebase;MongoDB;Microsoft SQL Server;MySQL
# 149     Elasticsearch;MongoDB;Microsoft SQL Server;MySQL
# 184                                                  NaN
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                   Databasedesirenextyear  \
# 26     Couchbase;Elasticsearch;MongoDB;MySQL;Oracle;P...
# 86                                                   NaN
# 114                              Firebase;MongoDB;SQLite
# 149           Elasticsearch;MongoDB;Microsoft SQL Server
# 184                                                  NaN
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                       Platformworkedwith  \
# 26                           Docker;Heroku;Linux;Windows
# 86      Android;AWS;Docker;iOS;Linux;MacOS;Slack;Windows
# 114    Android;Arduino;Docker;Google Cloud Platform;i...
# 149     Android;AWS;Docker;Linux;Microsoft Azure;Windows
# 184      Google Cloud Platform;Linux;MacOS;Slack;Windows
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                   Platformdesirenextyear  \
# 26     Android;AWS;Docker;Google Cloud Platform;Herok...
# 86                                AWS;Docker;Linux;MacOS
# 114    Android;Docker;Google Cloud Platform;MacOS;Sla...
# 149    Android;AWS;Docker;Kubernetes;Linux;Microsoft ...
# 184                                                  NaN
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                              Webframeworkedwith  \
# 26     Angular/Angular.js;Express;Ruby on Rails
# 86                       Django;React.js;Spring
# 114              ASP.NET;jQuery;React.js;Spring
# 149                 Angular/Angular.js;React.js
# 184                             jQuery;React.js
# ...                                         ...
# 88873                                       NaN
# 88874                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
#
#                                   Webframedesirenextyear  \
# 26     Angular/Angular.js;Django;Express;Flask;React....
# 86                                       Django;React.js
# 114                                     Express;React.js
# 149                                                  NaN
# 184                       Express;jQuery;React.js;Vue.js
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#           Misctechworkedwith  \
# 26            Node.js;Pandas
# 86              .NET;Node.js
# 114    .NET;Node.js;Unity 3D
# 149           .NET;.NET Core
# 184                  Node.js
# ...                      ...
# 88873                    NaN
# 88874                    NaN
# 88879                    NaN
# 88880                    NaN
# 88881                    NaN
#
#                                   Misctechdesirenextyear  \
# 26     Ansible;Apache Spark;Flutter;Hadoop;Node.js;Pa...
# 86                                               Node.js
# 114                                              Node.js
# 149                                       .NET;.NET Core
# 184    Node.js;React Native;TensorFlow;Unity 3D;Unrea...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                               Devenviron        Opsys  \
# 26     Eclipse;IPython / Jupyter;NetBeans;Visual Stud...  Linux-based
# 86         Android Studio;PyCharm;Vim;Visual Studio Code        MacOS
# 114    Android Studio;IntelliJ;Visual Studio;Visual S...        MacOS
# 149    Android Studio;Notepad++;Visual Studio;Visual ...      Windows
# 184    Atom;IntelliJ;Sublime Text;Vim;Visual Studio;X...        MacOS
# ...                                                  ...          ...
# 88873                                                NaN          NaN
# 88874                                                NaN          NaN
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
#
#                                               Containers Blockchainorg  \
# 26     Development;Outside of work, for personal proj...           NaN
# 86                                   Development;Testing    Not at all
# 114                               Development;Production    Not at all
# 149    Development;Testing;Outside of work, for perso...    Not at all
# 184               Outside of work, for personal projects           NaN
# ...                                                  ...           ...
# 88873                                                NaN           NaN
# 88874                                                NaN           NaN
# 88879                                                NaN           NaN
# 88880                                                NaN           NaN
# 88881                                                NaN           NaN
#
#                                             Blockchainis Betterlife  Itperson  \
# 26     Useful across many domains and could change ma...         No  Also Yes
# 86     Useful for immutable record keeping outside of...        Yes  Also Yes
# 114    Useful for decentralized currency (i.e., Bitcoin)        Yes  Also Yes
# 149                    An irresponsible use of resources        Yes  Also Yes
# 184                                        A passing fad        Yes       Yes
# ...                                                  ...        ...       ...
# 88873                                                NaN        NaN       NaN
# 88874                                                NaN        NaN       NaN
# 88879                                                NaN        NaN       NaN
# 88880                                                NaN        NaN       NaN
# 88881                                                NaN        NaN       NaN
#
#       Offon Socialmedia              Extraversion Screenname Sovisit1st  \
# 26      Yes     YouTube  In real life (in person)   Username       2015
# 86      Yes    WhatsApp                    Online      Login       2010
# 114     Yes     YouTube                    Online     Handle       2014
# 149     Yes     YouTube  In real life (in person)   Username       2010
# 184     Yes    Facebook  In real life (in person)     Handle       2019
# ...     ...         ...                       ...        ...        ...
# 88873   NaN         NaN                       NaN        NaN        NaN
# 88874   NaN         NaN                       NaN        NaN        NaN
# 88879   NaN         NaN                       NaN        NaN        NaN
# 88880   NaN         NaN                       NaN        NaN        NaN
# 88881   NaN         NaN                       NaN        NaN        NaN
#
#                   Sovisitfreq  \
# 26     Multiple times per day
# 86      Daily or almost daily
# 114    Multiple times per day
# 149     Daily or almost daily
# 184     Daily or almost daily
# ...                       ...
# 88873                     NaN
# 88874                     NaN
# 88879                     NaN
# 88880                     NaN
# 88881                     NaN
#
#                                                Sovisitto  \
# 26     Find answers to specific questions;Learn how t...
# 86                    Find answers to specific questions
# 114    Find answers to specific questions;Contribute ...
# 149    Find answers to specific questions;Learn how t...
# 184    Find answers to specific questions;Learn how t...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                       Sofindanswer                     Sotimesaved  \
# 26              3-5 times per week  Stack Overflow was much faster
# 86              3-5 times per week  Stack Overflow was much faster
# 114    More than 10 times per week  Stack Overflow was much faster
# 149             3-5 times per week        They were about the same
# 184    More than 10 times per week  Stack Overflow was much faster
# ...                            ...                             ...
# 88873                          NaN                             NaN
# 88874                          NaN                             NaN
# 88879                          NaN                             NaN
# 88880                          NaN                             NaN
# 88881                          NaN                             NaN
#
#        Sohowmuchtime Soaccount  \
# 26     11-30 minutes       Yes
# 86       60+ minutes       Yes
# 114    11-30 minutes       Yes
# 149              NaN       Yes
# 184    11-30 minutes       Yes
# ...              ...       ...
# 88873            NaN       NaN
# 88874            NaN       NaN
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
#
#                                               Sopartfreq  \
# 26     I have never participated in Q&A on Stack Over...
# 86     I have never participated in Q&A on Stack Over...
# 114    I have never participated in Q&A on Stack Over...
# 149                  Less than once per month or monthly
# 184    I have never participated in Q&A on Stack Over...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                                   Sojobs  \
# 26                                                   Yes
# 86     No, I knew that Stack Overflow had a job board...
# 114                                                  Yes
# 149    No, I knew that Stack Overflow had a job board...
# 184    No, I didn't know that Stack Overflow had a jo...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                                 Entteams           Socomm  \
# 26                   No, and I don't know what those are   No, not really
# 86                   No, and I don't know what those are   No, not really
# 114                  No, and I don't know what those are  Yes, definitely
# 149                  No, and I don't know what those are          Neutral
# 184    No, I've heard of them, but I am not part of a...    Yes, somewhat
# ...                                                  ...              ...
# 88873                                                NaN              NaN
# 88874                                                NaN              NaN
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
#
#                                   Welcomechange  \
# 26        A lot more welcome now than last year
# 86     Somewhat more welcome now than last year
# 114     Just as welcome now as I felt last year
# 149     Just as welcome now as I felt last year
# 184     Just as welcome now as I felt last year
# ...                                         ...
# 88873                                       NaN
# 88874                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
#
#                                             Sonewcontent   Age Gender  Trans  \
# 26     Tech articles written by other developers;Indu...  22.0    Man     No
# 86     Industry news about technologies you're intere...  36.0    Man     No
# 114    Tech articles written by other developers;Indu...  21.0    Man     No
# 149    Tech articles written by other developers;Indu...  34.0    Man     No
# 184    Tech articles written by other developers;Indu...  26.0  Woman     No
# ...                                                  ...   ...    ...    ...
# 88873                                                NaN   NaN    NaN    NaN
# 88874                                                NaN   NaN    NaN    NaN
# 88879                                                NaN   NaN    NaN    NaN
# 88880                                                NaN   NaN    NaN    NaN
# 88881                                                NaN   NaN    NaN    NaN
#
#                      Sexuality                     Ethnicity Dependents  \
# 26     Straight / Heterosexual     Hispanic or Latino/Latina         No
# 86     Straight / Heterosexual  White or of European descent        Yes
# 114    Straight / Heterosexual                           NaN         No
# 149    Straight / Heterosexual  White or of European descent        Yes
# 184    Straight / Heterosexual                   South Asian        Yes
# ...                        ...                           ...        ...
# 88873                      NaN                           NaN        NaN
# 88874                      NaN                           NaN        NaN
# 88879                      NaN                           NaN        NaN
# 88880                      NaN                           NaN        NaN
# 88881                      NaN                           NaN        NaN
#
#                 Surveylength                  Surveyease MAIN_BRANCH
# 26     Appropriate in length  Neither easy nor difficult         nan
# 86     Appropriate in length                        Easy         nan
# 114    Appropriate in length  Neither easy nor difficult         nan
# 149                Too short                        Easy         nan
# 184    Appropriate in length                        Easy         nan
# ...                      ...                         ...         ...
# 88873                    NaN                         NaN         nan
# 88874                    NaN                         NaN         nan
# 88879                    NaN                         NaN         nan
# 88880                    NaN                         NaN         nan
# 88881                    NaN                         NaN         nan
#
# [88883 rows x 86 columns]

# %%
# making one column ascending and the other column descending
df.sort_values(by=['Hobbyist','Student'], ascending=[False,True])#use inplace to make it permanent
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 8               9                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88873       88062                                                NaN       No
# 88874       88076                                                NaN       No
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
#                       Opensourcer  \
# 0                           Never
# 2                           Never
# 4      Once a month or more often
# 5                           Never
# 8      Once a month or more often
# ...                           ...
# 88873                       Never
# 88874                       Never
# 88879                       Never
# 88880                       Never
# 88881                       Never
#
#                                               Opensource  \
# 0      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# 5      The quality of OSS and closed source software ...
# 8      The quality of OSS and closed source software ...
# ...                                                  ...
# 88873  OSS is, on average, of LOWER quality than prop...
# 88874  OSS is, on average, of HIGHER quality than pro...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment         Country  \
# 0                 Not employed, and not looking for work  United Kingdom
# 2                                     Employed full-time        Thailand
# 4                                     Employed full-time         Ukraine
# 5                                     Employed full-time          Canada
# 8                                     Employed full-time     New Zealand
# ...                                                  ...             ...
# 88873                                                NaN             NaN
# 88874                                 Employed full-time             NaN
# 88879                                                NaN             NaN
# 88880                                 Employed full-time             NaN
# 88881  Independent contractor, freelancer, or self-em...             NaN
#
#       Student                                            Edlevel  \
# 0          No                          Primary/elementary school
# 2          No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4          No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5          No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8          No  Some college/university study without earning ...
# ...       ...                                                ...
# 88873     NaN                                                NaN
# 88874     NaN                                                NaN
# 88879     NaN                                                NaN
# 88880     NaN                                                NaN
# 88881     NaN                                                NaN
#
#                                           Undergradmajor  \
# 0                                                    NaN
# 2                          Web development or web design
# 4      Computer science, computer engineering, or sof...
# 5                              Mathematics or statistics
# 8      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                                 Eduother  \
# 0      Taught yourself a new language, framework, or ...
# 2      Taught yourself a new language, framework, or ...
# 4      Taken an online course in programming or softw...
# 5      Taken an online course in programming or softw...
# 8      Taken an online course in programming or softw...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                         Orgsize  \
# 0                           NaN
# 2          100 to 499 employees
# 4      10,000 or more employees
# 5                           NaN
# 8            10 to 19 employees
# ...                         ...
# 88873                       NaN
# 88874                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
#
#                                                  Devtype Yearscode Age1stcode  \
# 0                                                    NaN         4         10
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 4      Academic researcher;Developer, desktop or ente...        16         14
# 5      Data or business analyst;Data scientist or mac...        13         15
# 8      Database administrator;Developer, back-end;Dev...        12         11
# ...                                                  ...       ...        ...
# 88873                                                NaN       NaN        NaN
# 88874                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
#
#       Yearscodepro           Careersat                 Jobsat  \
# 0              NaN                 NaN                    NaN
# 2                1  Slightly satisfied     Slightly satisfied
# 4                9   Very dissatisfied  Slightly dissatisfied
# 5                3      Very satisfied     Slightly satisfied
# 8                4  Slightly satisfied     Slightly satisfied
# ...            ...                 ...                    ...
# 88873          NaN                 NaN                    NaN
# 88874          NaN                 NaN                    NaN
# 88879          NaN                 NaN                    NaN
# 88880          NaN                 NaN                    NaN
# 88881          NaN                 NaN                    NaN
#
#                    Mgridiot  Mgrmoney   Mgrwant  \
# 0                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 4        Somewhat confident       Yes        No
# 5            Very confident        No       Yes
# 8        Somewhat confident        No  Not sure
# ...                     ...       ...       ...
# 88873                   NaN       NaN       NaN
# 88874                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
#
#                                                  Jobseek  \
# 0                                                    NaN
# 2      I’m not actively looking, but I am open to new...
# 4           I am not interested in new job opportunities
# 5           I am not interested in new job opportunities
# 8      I’m not actively looking, but I am open to new...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                Lasthiredate  \
# 0                       NaN
# 2             1-2 years ago
# 4      Less than a year ago
# 5             1-2 years ago
# 8      Less than a year ago
# ...                     ...
# 88873                   NaN
# 88874                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
#
#                                                  Lastint Fizzbuzz  \
# 0                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# 5      Write any code;Complete a take-home project;In...       No
# 8      Write any code;Interview with people in peer r...      Yes
# ...                                                  ...      ...
# 88873                                                NaN      NaN
# 88874                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
#
#                                               Jobfactors  \
# 0                                                    NaN
# 2      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# 5      Financial performance or funding status of the...
# 8      Financial performance or funding status of the...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                             Resumeupdate Currencysymbol  \
# 0                                                    NaN            NaN
# 2                       I was preparing for a job search            THB
# 4                       I was preparing for a job search            UAH
# 5      I heard about a job opportunity (from a recrui...            CAD
# 8                       I was preparing for a job search            NZD
# ...                                                  ...            ...
# 88873                                                NaN            NaN
# 88874                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
#
#              Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 0                     NaN        NaN      NaN            NaN          NaN
# 2               Thai baht    23000.0  Monthly         8820.0         40.0
# 4       Ukrainian hryvnia        NaN      NaN            NaN         55.0
# 5         Canadian dollar    40000.0  Monthly       366420.0         15.0
# 8      New Zealand dollar   138000.0   Yearly        95179.0         32.0
# ...                   ...        ...      ...            ...          ...
# 88873                 NaN        NaN      NaN            NaN          NaN
# 88874                 NaN        NaN      NaN            NaN          NaN
# 88879                 NaN        NaN      NaN            NaN          NaN
# 88880                 NaN        NaN      NaN            NaN          NaN
# 88881                 NaN        NaN      NaN            NaN          NaN
#
#                                                 Workplan  \
# 0                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# 5      There's no schedule or spec; I work on what se...
# 8      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                            Workchallenge  \
# 0                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 4      Being tasked with non-development work;Inadequ...
# 5                                                    NaN
# 8      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                              Workremote Workloc                  Impsyn  \
# 0                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 4                 A few days each month  Office  A little above average
# 5                 A few days each month    Home  A little above average
# 8      Less than once per month / Never  Office  A little above average
# ...                                 ...     ...                     ...
# 88873                               NaN     NaN                     NaN
# 88874                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
#
#                                        Coderev  Coderevhrs  \
# 0                                          NaN         NaN
# 2                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# 5                                           No         NaN
# 8      Yes, because I see value in code review        12.0
# ...                                        ...         ...
# 88873                                      NaN         NaN
# 88874                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
#
#                                                Unittests Purchasehow  ...  \
# 0                                                    NaN         NaN  ...
# 2                              No, but I think we should    Not sure  ...
# 4                          Yes, it's part of our process    Not sure  ...
# 5      Yes, it's not part of our process but the deve...    Not sure  ...
# 8      Yes, it's not part of our process but the deve...    Not sure  ...
# ...                                                  ...         ...  ...
# 88873                                                NaN         NaN  ...
# 88874                                                NaN         NaN  ...
# 88879                                                NaN         NaN  ...
# 88880                                                NaN         NaN  ...
# 88881                                                NaN         NaN  ...
#
#                                   Languagedesirenextyear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                                        Elixir;HTML/CSS
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 5                                       Python;Scala;SQL
# 8      Bash/Shell/PowerShell;C;HTML/CSS;JavaScript;Ru...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                      Databaseworkedwith  \
# 0                                                SQLite
# 2                                            PostgreSQL
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 5                                    MongoDB;PostgreSQL
# 8                            DynamoDB;PostgreSQL;SQLite
# ...                                                 ...
# 88873                                               NaN
# 88874                                               NaN
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
#
#                                   Databasedesirenextyear  \
# 0                                                  MySQL
# 2                                             PostgreSQL
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 5                                             PostgreSQL
# 8                                PostgreSQL;Redis;SQLite
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                 Platformworkedwith  \
# 0                                    MacOS;Windows
# 2                                              NaN
# 4                Android;Linux;MacOS;Slack;Windows
# 5      Android;Google Cloud Platform;Linux;Windows
# 8              AWS;Docker;Heroku;Linux;MacOS;Slack
# ...                                            ...
# 88873                                          NaN
# 88874                                          NaN
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
#
#                               Platformdesirenextyear  \
# 0                            Android;Arduino;Windows
# 2                                                NaN
# 4              Android;Docker;Kubernetes;Linux;Slack
# 5        Android;Google Cloud Platform;Linux;Windows
# 8      AWS;Docker;Heroku;Linux;MacOS;Slack;Other(s):
# ...                                              ...
# 88873                                            NaN
# 88874                                            NaN
# 88879                                            NaN
# 88880                                            NaN
# 88881                                            NaN
#
#                                 Webframeworkedwith  \
# 0                                     Django;Flask
# 2                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# 5                                              NaN
# 8                  Express;Ruby on Rails;Other(s):
# ...                                            ...
# 88873                                          NaN
# 88874                                          NaN
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
#
#                 Webframedesirenextyear Misctechworkedwith  \
# 0                         Flask;jQuery            Node.js
# 2                            Other(s):                NaN
# 4         Flask;jQuery;React.js;Spring    Cordova;Node.js
# 5                                  NaN             Hadoop
# 8      Express;Ruby on Rails;Other(s):   Node.js;Unity 3D
# ...                                ...                ...
# 88873                              NaN                NaN
# 88874                              NaN                NaN
# 88879                              NaN                NaN
# 88880                              NaN                NaN
# 88881                              NaN                NaN
#
#                          Misctechdesirenextyear  \
# 0                                       Node.js
# 2                                           NaN
# 4      Apache Spark;Hadoop;Node.js;React Native
# 5             Hadoop;Pandas;TensorFlow;Unity 3D
# 8                                       Node.js
# ...                                         ...
# 88873                                       NaN
# 88874                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
#
#                                               Devenviron        Opsys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# 5      Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 8                                                    Vim        MacOS
# ...                                                  ...          ...
# 88873                                                NaN          NaN
# 88874                                                NaN          NaN
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
#
#                                    Containers Blockchainorg  \
# 0                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 4      Outside of work, for personal projects    Not at all
# 5                     I do not use containers    Not at all
# 8              Development;Testing;Production    Not at all
# ...                                       ...           ...
# 88873                                     NaN           NaN
# 88874                                     NaN           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
#
#                             Blockchainis Betterlife  \
# 0                                    NaN        Yes
# 2                                    NaN        Yes
# 4                                    NaN        Yes
# 5                                    NaN         No
# 8      An irresponsible use of resources         No
# ...                                  ...        ...
# 88873                                NaN        NaN
# 88874                                NaN        NaN
# 88879                                NaN        NaN
# 88880                                NaN        NaN
# 88881                                NaN        NaN
#
#                                        Itperson Offon Socialmedia  \
# 0      Fortunately, someone else has that title   Yes     Twitter
# 2                                           Yes   Yes      Reddit
# 4                                      Also Yes   Yes    Facebook
# 5                                           Yes    No     YouTube
# 8                                          SIGH   Yes     Twitter
# ...                                         ...   ...         ...
# 88873                                       NaN   NaN         NaN
# 88874                                       NaN   NaN         NaN
# 88879                                       NaN   NaN         NaN
# 88880                                       NaN   NaN         NaN
# 88881                                       NaN   NaN         NaN
#
#                    Extraversion Screenname        Sovisit1st  \
# 0                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 4      In real life (in person)   Username  I don't remember
# 5      In real life (in person)      Login              2011
# 8      In real life (in person)   Username              2013
# ...                         ...        ...               ...
# 88873                       NaN        NaN               NaN
# 88874                       NaN        NaN               NaN
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
#
#                            Sovisitfreq  \
# 0      A few times per month or weekly
# 2                 A few times per week
# 4               Multiple times per day
# 5      A few times per month or weekly
# 8                Daily or almost daily
# ...                                ...
# 88873                              NaN
# 88874                              NaN
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
#
#                                                Sovisitto  \
# 0      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 4                     Find answers to specific questions
# 5                     Find answers to specific questions
# 8      Find answers to specific questions;Contribute ...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                       Sofindanswer                         Sotimesaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 4      More than 10 times per week      Stack Overflow was much faster
# 5          Less than once per week  Stack Overflow was slightly faster
# 8               3-5 times per week            They were about the same
# ...                            ...                                 ...
# 88873                          NaN                                 NaN
# 88874                          NaN                                 NaN
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
#
#        Sohowmuchtime Soaccount  \
# 0      31-60 minutes        No
# 2                NaN       Yes
# 4                NaN       Yes
# 5        60+ minutes       Yes
# 8                NaN       Yes
# ...              ...       ...
# 88873            NaN       NaN
# 88874            NaN       NaN
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
#
#                                               Sopartfreq  \
# 0                                                    NaN
# 2                    Less than once per month or monthly
# 4                        A few times per month or weekly
# 5      I have never participated in Q&A on Stack Over...
# 8                    Less than once per month or monthly
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                                   Sojobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 2                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# 5      No, I knew that Stack Overflow had a job board...
# 8      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88873                                                NaN
# 88874                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
#
#                                                 Entteams           Socomm  \
# 0                    No, and I don't know what those are          Neutral
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# 5                    No, and I don't know what those are   No, not really
# 8                    No, and I don't know what those are    Yes, somewhat
# ...                                                  ...              ...
# 88873                                                NaN              NaN
# 88874                                                NaN              NaN
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
#
#                                  Welcomechange  \
# 0      Just as welcome now as I felt last year
# 2      Just as welcome now as I felt last year
# 4      Just as welcome now as I felt last year
# 5      Just as welcome now as I felt last year
# 8      Just as welcome now as I felt last year
# ...                                        ...
# 88873                                      NaN
# 88874                                      NaN
# 88879                                      NaN
# 88880                                      NaN
# 88881                                      NaN
#
#                                             Sonewcontent   Age Gender  Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man     No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man     No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man     No
# 5      Tech articles written by other developers;Indu...  28.0    Man     No
# 8                                                    NaN  23.0    Man     No
# ...                                                  ...   ...    ...    ...
# 88873                                                NaN   NaN    NaN    NaN
# 88874                                                NaN   NaN    NaN    NaN
# 88879                                                NaN   NaN    NaN    NaN
# 88880                                                NaN   NaN    NaN    NaN
# 88881                                                NaN   NaN    NaN    NaN
#
#                      Sexuality                                 Ethnicity  \
# 0      Straight / Heterosexual                                       NaN
# 2      Straight / Heterosexual                                       NaN
# 4      Straight / Heterosexual  White or of European descent;Multiracial
# 5      Straight / Heterosexual                                East Asian
# 8                     Bisexual              White or of European descent
# ...                        ...                                       ...
# 88873                      NaN                                       NaN
# 88874                      NaN                                       NaN
# 88879                      NaN                                       NaN
# 88880                      NaN                                       NaN
# 88881                      NaN                                       NaN
#
#       Dependents           Surveylength                  Surveyease  \
# 0             No  Appropriate in length  Neither easy nor difficult
# 2            Yes  Appropriate in length  Neither easy nor difficult
# 4             No  Appropriate in length                        Easy
# 5             No               Too long  Neither easy nor difficult
# 8             No  Appropriate in length  Neither easy nor difficult
# ...          ...                    ...                         ...
# 88873        NaN                    NaN                         NaN
# 88874        NaN                    NaN                         NaN
# 88879        NaN                    NaN                         NaN
# 88880        NaN                    NaN                         NaN
# 88881        NaN                    NaN                         NaN
#
#           MAIN_BRANCH
# 0                 nan
# 2      I am a student
# 4                 nan
# 5                 nan
# 8                 nan
# ...               ...
# 88873             nan
# 88874             nan
# 88879             nan
# 88880             nan
# 88881             nan
#
# [88883 rows x 86 columns]

# %%
# sorting by index
df.sort_index()
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              Opensourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               Opensource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  Edlevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           Undergradmajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 Eduother  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         Orgsize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  Devtype Yearscode Age1stcode  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            Yearscodepro           Careersat                 Jobsat  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    Mgridiot  Mgrmoney   Mgrwant  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  Jobseek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                Lasthiredate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  Lastint Fizzbuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               Jobfactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             Resumeupdate Currencysymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 Workplan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            Workchallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              Workremote Workloc                  Impsyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        Coderev  Coderevhrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            Unittests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              Purchasehow  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                               Not sure  ...
# 3      Developers typically have the most influence o...  ...
# 4                                               Not sure  ...
# ...                                                  ...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882                                                NaN  ...
#
#                                   Languagedesirenextyear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      Databaseworkedwith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   Databasedesirenextyear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       Platformworkedwith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   Platformdesirenextyear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 Webframeworkedwith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              Webframedesirenextyear      Misctechworkedwith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          Misctechdesirenextyear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               Devenviron        Opsys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers Blockchainorg  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             Blockchainis Betterlife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        Itperson  Offon Socialmedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    Extraversion Screenname        Sovisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            Sovisitfreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                Sovisitto  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       Sofindanswer                         Sotimesaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        Sohowmuchtime Soaccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               Sopartfreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   Sojobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 Entteams           Socomm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   Welcomechange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             Sonewcontent   Age Gender  Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man     No
# 1      Tech articles written by other developers;Indu...  19.0    Man     No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man     No
# 3      Tech articles written by other developers;Indu...  22.0    Man     No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man     No
# ...                                                  ...   ...    ...    ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man     No
# 88879                                                NaN   NaN    NaN    NaN
# 88880                                                NaN   NaN    NaN    NaN
# 88881                                                NaN   NaN    NaN    NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man     No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 Surveylength                  Surveyease     MAIN_BRANCH
# 0      Appropriate in length  Neither easy nor difficult             nan
# 1      Appropriate in length  Neither easy nor difficult             nan
# 2      Appropriate in length  Neither easy nor difficult  I am a student
# 3      Appropriate in length                        Easy             nan
# 4      Appropriate in length                        Easy             nan
# ...                      ...                         ...             ...
# 88878  Appropriate in length                        Easy             nan
# 88879                    NaN                         NaN             nan
# 88880                    NaN                         NaN             nan
# 88881                    NaN                         NaN             nan
# 88882  Appropriate in length                        Easy             nan
#
# [88883 rows x 86 columns]

# %%
# you can call out a column and sort it
df['Student'].sort_values()
# Out:
# 0         No
# 46409     No
# 46410     No
# 46411     No
# 46412     No
#         ...
# 88874    NaN
# 88875    NaN
# 88879    NaN
# 88880    NaN
# 88881    NaN
# Name: Student, Length: 88883, dtype: object

# %%
df['Convertedcomp'].nlargest(10) # to see it in series
# Out:
# 57      2000000.0
# 101     2000000.0
# 164     2000000.0
# 434     2000000.0
# 450     2000000.0
# 489     2000000.0
# 537     2000000.0
# 767     2000000.0
# 786     2000000.0
# 1228    2000000.0
# Name: Convertedcomp, dtype: float64

# %%
df.nlargest(10, 'Convertedcomp') #to see it in a dataframe
# Out:
#       Respondent                      Mainbranch Hobbyist  \
# 57            58  I am a developer by profession      Yes
# 101          102  I am a developer by profession       No
# 164          166  I am a developer by profession      Yes
# 434          436  I am a developer by profession      Yes
# 450          452  I am a developer by profession      Yes
# 489          491  I am a developer by profession      Yes
# 537          539  I am a developer by profession       No
# 767          770  I am a developer by profession      Yes
# 786          789  I am a developer by profession      Yes
# 1228        1232  I am a developer by profession       No
#
#                                             Opensourcer  \
# 57                           Once a month or more often
# 101                                               Never
# 164                             Less than once per year
# 434                             Less than once per year
# 450                                               Never
# 489                             Less than once per year
# 537   Less than once a month but more than once per ...
# 767                             Less than once per year
# 786                             Less than once per year
# 1228                                              Never
#
#                                              Opensource          Employment  \
# 57    OSS is, on average, of LOWER quality than prop...  Employed full-time
# 101   The quality of OSS and closed source software ...  Employed full-time
# 164   The quality of OSS and closed source software ...  Employed full-time
# 434   The quality of OSS and closed source software ...  Employed full-time
# 450   The quality of OSS and closed source software ...  Employed full-time
# 489                                                 NaN  Employed full-time
# 537   OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 767   The quality of OSS and closed source software ...  Employed full-time
# 786   The quality of OSS and closed source software ...  Employed full-time
# 1228  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#             Country         Student  \
# 57    United States              No
# 101   United States              No
# 164   United States              No
# 434   United States              No
# 450   United States  Yes, full-time
# 489   United States              No
# 537   United States              No
# 767   United States              No
# 786   United States  Yes, full-time
# 1228  United States              No
#
#                                                 Edlevel  \
# 57             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 101            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 164            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 434            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 450              I never completed any formal education
# 489            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 537   Some college/university study without earning ...
# 767         Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 786         Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1228           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                          Undergradmajor  \
# 57    Computer science, computer engineering, or sof...
# 101   Computer science, computer engineering, or sof...
# 164   A social science (ex. anthropology, psychology...
# 434   Computer science, computer engineering, or sof...
# 450                                                 NaN
# 489   Computer science, computer engineering, or sof...
# 537                           Mathematics or statistics
# 767   A humanities discipline (ex. literature, histo...
# 786   Computer science, computer engineering, or sof...
# 1228  Computer science, computer engineering, or sof...
#
#                                                Eduother  \
# 57    Received on-the-job training in software devel...
# 101   Taught yourself a new language, framework, or ...
# 164   Participated in a full-time developer training...
# 434   Taken an online course in programming or softw...
# 450   Taken an online course in programming or softw...
# 489   Taken an online course in programming or softw...
# 537   Taken an online course in programming or softw...
# 767   Taken an online course in programming or softw...
# 786   Taken an online course in programming or softw...
# 1228  Taken an online course in programming or softw...
#
#                        Orgsize  \
# 57                         NaN
# 101   5,000 to 9,999 employees
# 164         20 to 99 employees
# 434         20 to 99 employees
# 450       100 to 499 employees
# 489   10,000 or more employees
# 537   10,000 or more employees
# 767   1,000 to 4,999 employees
# 786   10,000 or more employees
# 1228             2-9 employees
#
#                                                 Devtype Yearscode Age1stcode  \
# 57    Developer, back-end;Developer, desktop or ente...        28         19
# 101                               Developer, full-stack         8         29
# 164   Developer, back-end;Developer, front-end;Devel...         7         15
# 434   Database administrator;Developer, back-end;Dev...        20         18
# 450          Database administrator;Developer, back-end         7         28
# 489             Developer, full-stack;Developer, mobile         4         18
# 537   Data scientist or machine learning specialist;...        22         14
# 767                               Developer, full-stack         5         17
# 786      Developer, back-end;Engineer, site reliability        12          9
# 1228  Developer, front-end;Developer, game or graphi...         4         15
#
#           Yearscodepro              Careersat  \
# 57                  23         Very satisfied
# 101                  5     Slightly satisfied
# 164                  6     Slightly satisfied
# 434                 17     Slightly satisfied
# 450                  7         Very satisfied
# 489   Less than 1 year         Very satisfied
# 537                 20         Very satisfied
# 767                  3         Very satisfied
# 786                  6  Slightly dissatisfied
# 1228                 2     Slightly satisfied
#
#                                   Jobsat              Mgridiot Mgrmoney  \
# 57                        Very satisfied        Very confident      Yes
# 101                   Slightly satisfied    Somewhat confident       No
# 164                   Slightly satisfied        Very confident       No
# 434                   Slightly satisfied    Somewhat confident      Yes
# 450                       Very satisfied        Very confident       No
# 489                       Very satisfied        Very confident       No
# 537                   Slightly satisfied        Very confident      Yes
# 767                       Very satisfied    Somewhat confident       No
# 786   Neither satisfied nor dissatisfied  Not at all confident      Yes
# 1228               Slightly dissatisfied    Somewhat confident      Yes
#
#                      Mgrwant  \
# 57                        No
# 101                       No
# 164                 Not sure
# 434   I am already a manager
# 450                       No
# 489                 Not sure
# 537                       No
# 767                 Not sure
# 786                 Not sure
# 1228                     Yes
#
#                                                 Jobseek          Lasthiredate  \
# 57         I am not interested in new job opportunities         1-2 years ago
# 101   I’m not actively looking, but I am open to new...         1-2 years ago
# 164   I’m not actively looking, but I am open to new...         3-4 years ago
# 434   I’m not actively looking, but I am open to new...         3-4 years ago
# 450   I’m not actively looking, but I am open to new...  Less than a year ago
# 489        I am not interested in new job opportunities  Less than a year ago
# 537   I’m not actively looking, but I am open to new...         1-2 years ago
# 767        I am not interested in new job opportunities         1-2 years ago
# 786   I’m not actively looking, but I am open to new...         3-4 years ago
# 1228  I’m not actively looking, but I am open to new...         1-2 years ago
#
#                                                 Lastint Fizzbuzz  \
# 57                                                  NaN      Yes
# 101   Write any code;Write code by hand (e.g., on a ...      Yes
# 164   Write any code;Complete a take-home project;So...       No
# 434   Write any code;Write code by hand (e.g., on a ...       No
# 450   Solve a brain-teaser style puzzle;Interview wi...       No
# 489   Write any code;Write code by hand (e.g., on a ...       No
# 537   Write any code;Complete a take-home project;In...      Yes
# 767   Interview with people in peer roles;Interview ...       No
# 786   Write any code;Write code by hand (e.g., on a ...       No
# 1228  Write code by hand (e.g., on a whiteboard);Sol...       No
#
#                                              Jobfactors  \
# 57    Office environment or company culture;Remote w...
# 101   Office environment or company culture;Opportun...
# 164   Financial performance or funding status of the...
# 434   Specific department or team I'd be working on;...
# 450   Specific department or team I'd be working on;...
# 489   Specific department or team I'd be working on;...
# 537   Languages, frameworks, and other technologies ...
# 767   Office environment or company culture;Remote w...
# 786   Specific department or team I'd be working on;...
# 1228  Industry that I'd be working in;Specific depar...
#
#                                            Resumeupdate Currencysymbol  \
# 57                          Re-entry into the workforce            USD
# 101   Something else changed (education, award, medi...            USD
# 164   I had a negative experience or interaction at ...            USD
# 434    My job status changed (promotion, new job, etc.)            USD
# 450   Something else changed (education, award, medi...            USD
# 489                    I was preparing for a job search            USD
# 537                    I was preparing for a job search            USD
# 767   Something else changed (education, award, medi...            USD
# 786   I had a negative experience or interaction at ...            USD
# 1228  Something else changed (education, award, medi...            USD
#
#               Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 57    United States dollar   113000.0   Weekly      2000000.0         40.0
# 101   United States dollar    67800.0   Weekly      2000000.0         40.0
# 164   United States dollar   137000.0   Weekly      2000000.0         45.0
# 434   United States dollar    85000.0   Weekly      2000000.0         45.0
# 450   United States dollar    75000.0   Weekly      2000000.0         40.0
# 489   United States dollar   160000.0   Weekly      2000000.0         45.0
# 537   United States dollar   140000.0   Weekly      2000000.0         50.0
# 767   United States dollar    68000.0   Weekly      2000000.0         38.0
# 786   United States dollar   180000.0  Monthly      2000000.0         40.0
# 1228  United States dollar   800000.0   Weekly      2000000.0         40.0
#
#                                                Workplan  \
# 57    There's no schedule or spec; I work on what se...
# 101   There is a schedule and/or spec (made by me or...
# 164   There is a schedule and/or spec (made by me or...
# 434   There is a schedule and/or spec (made by me or...
# 450   There is a schedule and/or spec (made by me or...
# 489   There is a schedule and/or spec (made by me or...
# 537   There is a schedule and/or spec (made by me or...
# 767   There is a schedule and/or spec (made by me or...
# 786   There is a schedule and/or spec (made by me or...
# 1228  There is a schedule and/or spec (made by me or...
#
#                                           Workchallenge  \
# 57    Being tasked with non-development work;Non-wor...
# 101   Being tasked with non-development work;Distrac...
# 164   Distracting work environment;Not enough people...
# 434   Lack of support from management;Meetings;Not e...
# 450   Being tasked with non-development work;Meeting...
# 489   Distracting work environment;Inadequate access...
# 537   Being tasked with non-development work;Non-wor...
# 767   Being tasked with non-development work;Non-wor...
# 786   Lack of support from management;Toxic work env...
# 1228  Distracting work environment;Non-work commitme...
#
#                                              Workremote Workloc  \
# 57    Less than half the time, but at least one day ...    Home
# 101                    Less than once per month / Never  Office
# 164                    Less than once per month / Never    Home
# 434                               A few days each month  Office
# 450                               A few days each month    Home
# 489                    Less than once per month / Never  Office
# 537                               A few days each month  Office
# 767   All or almost all the time (I'm full-time remote)    Home
# 786                               A few days each month  Office
# 1228                              A few days each month  Office
#
#                       Impsyn                                  Coderev  \
# 57    A little above average  Yes, because I see value in code review
# 101                  Average                                       No
# 164   A little above average  Yes, because I see value in code review
# 434        Far above average  Yes, because I see value in code review
# 450                  Average  Yes, because I see value in code review
# 489                  Average  Yes, because I see value in code review
# 537   A little above average  Yes, because I see value in code review
# 767                  Average  Yes, because I see value in code review
# 786   A little above average  Yes, because I see value in code review
# 1228  A little below average  Yes, because I see value in code review
#
#       Coderevhrs                                          Unittests  \
# 57           1.0                          No, but I think we should
# 101          NaN                          No, but I think we should
# 164          8.0                      Yes, it's part of our process
# 434          NaN                          No, but I think we should
# 450          5.0                      Yes, it's part of our process
# 489          2.0                      Yes, it's part of our process
# 537         10.0  Yes, it's not part of our process but the deve...
# 767          6.0                      Yes, it's part of our process
# 786          2.0  Yes, it's not part of our process but the deve...
# 1228         5.0                          No, but I think we should
#
#                                             Purchasehow  ...  \
# 57    Developers and management have nearly equal in...  ...
# 101                                            Not sure  ...
# 164   The CTO, CIO, or other management purchase new...  ...
# 434   The CTO, CIO, or other management purchase new...  ...
# 450   Developers and management have nearly equal in...  ...
# 489                                            Not sure  ...
# 537   The CTO, CIO, or other management purchase new...  ...
# 767   Developers and management have nearly equal in...  ...
# 786   Developers and management have nearly equal in...  ...
# 1228  Developers and management have nearly equal in...  ...
#
#                                  Languagedesirenextyear  \
# 57                                C#;F#;Java;Kotlin;SQL
# 101                    C;C++;Elixir;Go;Ruby;WebAssembly
# 164   Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 434   Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 450                                          Python;SQL
# 489                              Java;Objective-C;Swift
# 537                     Go;JavaScript;Python;TypeScript
# 767      Go;HTML/CSS;Python;Ruby;TypeScript;WebAssembly
# 786                                   F#;Go;Python;Rust
# 1228  Java;Kotlin;Objective-C;Python;Swift;TypeScrip...
#
#                                      Databaseworkedwith  \
# 57                   Microsoft SQL Server;Oracle;SQLite
# 101                                Microsoft SQL Server
# 164   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redi...
# 434             Microsoft SQL Server;MySQL;Redis;SQLite
# 450                                Microsoft SQL Server
# 489                                                 NaN
# 537                                   PostgreSQL;SQLite
# 767                                MariaDB;MySQL;SQLite
# 786                             Elasticsearch;Other(s):
# 1228                                              MySQL
#
#                               Databasedesirenextyear  \
# 57                Microsoft SQL Server;Oracle;SQLite
# 101                        MongoDB;PostgreSQL;SQLite
# 164                          PostgreSQL;Redis;SQLite
# 434                     Couchbase;MySQL;Oracle;Redis
# 450   MongoDB;Microsoft SQL Server;Oracle;PostgreSQL
# 489                                              NaN
# 537        Couchbase;MongoDB;PostgreSQL;Redis;SQLite
# 767                 Elasticsearch;MariaDB;PostgreSQL
# 786                                        Other(s):
# 1228                                         MongoDB
#
#                                      Platformworkedwith  \
# 57                                      Android;Windows
# 101                                     Microsoft Azure
# 164                                    AWS;Docker;Linux
# 434   Android;AWS;Docker;Google Cloud Platform;Linux...
# 450                                             Windows
# 489                                         Android;iOS
# 537                        AWS;Docker;Linux;MacOS;Slack
# 767                 AWS;Docker;Linux;Raspberry Pi;Slack
# 786                              Docker;Microsoft Azure
# 1228                                                NaN
#
#                                  Platformdesirenextyear  \
# 57                         Android;Raspberry Pi;Windows
# 101                      AWS;Kubernetes;Microsoft Azure
# 164                     AWS;Docker;iOS;Kubernetes;Linux
# 434   Android;Arduino;Docker;Google Cloud Platform;L...
# 450                   AWS;Linux;Microsoft Azure;Windows
# 489                                         Android;iOS
# 537        AWS;Docker;Google Cloud Platform;Linux;MacOS
# 767         Arduino;AWS;Docker;Linux;Raspberry Pi;Slack
# 786                                              Docker
# 1228                      Android;AWS;iOS;MacOS;Windows
#
#                            Webframeworkedwith  \
# 57                             ASP.NET;jQuery
# 101         ASP.NET;jQuery;React.js;Other(s):
# 164             jQuery;React.js;Ruby on Rails
# 434            jQuery;Laravel;React.js;Vue.js
# 450                                       NaN
# 489                                       NaN
# 537                    Express;Flask;React.js
# 767   Angular/Angular.js;jQuery;Ruby on Rails
# 786                                   ASP.NET
# 1228                                 React.js
#
#                        Webframedesirenextyear  \
# 57          Angular/Angular.js;ASP.NET;jQuery
# 101                 Angular/Angular.js;Vue.js
# 164                    React.js;Ruby on Rails
# 434                   Laravel;React.js;Vue.js
# 450                                   ASP.NET
# 489                                       NaN
# 537                            Flask;React.js
# 767   Angular/Angular.js;Django;Ruby on Rails
# 786                                       NaN
# 1228                                 React.js
#
#                            Misctechworkedwith  \
# 57                                       .NET
# 101                            .NET;.NET Core
# 164                                       NaN
# 434                                   Node.js
# 450                                      .NET
# 489                                       NaN
# 537   Node.js;Pandas;TensorFlow;Torch/PyTorch
# 767                                   Node.js
# 786                            .NET;.NET Core
# 1228                        Node.js;Other(s):
#
#                             Misctechdesirenextyear  \
# 57    Hadoop;.NET;.NET Core;Node.js;Puppet;Xamarin
# 101                                        Node.js
# 164                                            NaN
# 434                Node.js;React Native;TensorFlow
# 450                                           .NET
# 489                          React Native;Unity 3D
# 537                          Node.js;Torch/PyTorch
# 767          Apache Spark;TensorFlow;Torch/PyTorch
# 786                           .NET Core;TensorFlow
# 1228                             Node.js;Other(s):
#
#                                              Devenviron        Opsys  \
# 57                         Android Studio;Visual Studio      Windows
# 101          Notepad++;Visual Studio;Visual Studio Code      Windows
# 164                                                 Vim  Linux-based
# 434   Android Studio;Atom;Sublime Text;Visual Studio...      Windows
# 450                             Notepad++;Visual Studio      Windows
# 489                   Android Studio;IntelliJ;Vim;Xcode        MacOS
# 537                      PyCharm;Vim;Visual Studio Code        MacOS
# 767                       PyCharm;RubyMine;Sublime Text  Linux-based
# 786   IntelliJ;Notepad++;Visual Studio;Visual Studio...        MacOS
# 1228                                 Visual Studio Code        MacOS
#
#                                   Containers  \
# 57                   I do not use containers
# 101                  I do not use containers
# 164           Development;Testing;Production
# 434           Development;Testing;Production
# 450                  I do not use containers
# 489   Outside of work, for personal projects
# 537           Development;Testing;Production
# 767                      Development;Testing
# 786           Development;Testing;Production
# 1228                 I do not use containers
#
#                                 Blockchainorg  \
# 57                                        NaN
# 101   Non-currency applications of blockchain
# 164                                Not at all
# 434                                Not at all
# 450                                Not at all
# 489                                       NaN
# 537                                Not at all
# 767   Non-currency applications of blockchain
# 786   Non-currency applications of blockchain
# 1228  Non-currency applications of blockchain
#
#                                            Blockchainis Betterlife  \
# 57                                                  NaN        Yes
# 101   Useful for immutable record keeping outside of...         No
# 164                                       A passing fad        Yes
# 434   Useful across many domains and could change ma...        Yes
# 450                                                 NaN        Yes
# 489                                       A passing fad        Yes
# 537                                       A passing fad         No
# 767                                                 NaN         No
# 786                   An irresponsible use of resources         No
# 1228  Useful across many domains and could change ma...        Yes
#
#                                       Itperson  Offon  \
# 57                                         Yes    Yes
# 101                                        Yes    Yes
# 164                                       SIGH    Yes
# 434                                       SIGH    Yes
# 450   Fortunately, someone else has that title  What?
# 489                                       SIGH  What?
# 537                                   Also Yes    Yes
# 767                                       SIGH    Yes
# 786   Fortunately, someone else has that title    Yes
# 1228                                       Yes  What?
#
#                    Socialmedia              Extraversion   Screenname  \
# 57    I don't use social media  In real life (in person)        Login
# 101   I don't use social media  In real life (in person)     Username
# 164                    Twitter                    Online     Username
# 434                     Reddit                   Neither     Username
# 450                   Facebook  In real life (in person)  Screen Name
# 489                    YouTube  In real life (in person)     Username
# 537                     Reddit  In real life (in person)     Username
# 767                     Reddit                    Online     Username
# 786                   Facebook                    Online       Handle
# 1228                 WeChat 微信  In real life (in person)     Username
#
#             Sovisit1st                          Sovisitfreq  \
# 57    I don't remember               Multiple times per day
# 101               2012                Daily or almost daily
# 164               2011      A few times per month or weekly
# 434               2010                Daily or almost daily
# 450               2013                Daily or almost daily
# 489               2014                 A few times per week
# 537   I don't remember                Daily or almost daily
# 767               2011                Daily or almost daily
# 786               2009  Less than once per month or monthly
# 1228              2014                 A few times per week
#
#                                               Sovisitto  \
# 57                   Find answers to specific questions
# 101   Find answers to specific questions;Learn how t...
# 164                  Find answers to specific questions
# 434   Find answers to specific questions;Contribute ...
# 450   Find answers to specific questions;Learn how t...
# 489   Find answers to specific questions;Learn how t...
# 537   Find answers to specific questions;Learn how t...
# 767   Find answers to specific questions;Learn how t...
# 786                  Find answers to specific questions
# 1228                 Find answers to specific questions
#
#                      Sofindanswer                         Sotimesaved  \
# 57    More than 10 times per week      Stack Overflow was much faster
# 101            1-2 times per week      Stack Overflow was much faster
# 164       Less than once per week  Stack Overflow was slightly faster
# 434            3-5 times per week            They were about the same
# 450            1-2 times per week  Stack Overflow was slightly faster
# 489            1-2 times per week            They were about the same
# 537            3-5 times per week      Stack Overflow was much faster
# 767            1-2 times per week  Stack Overflow was slightly faster
# 786       Less than once per week  Stack Overflow was slightly faster
# 1228           1-2 times per week  Stack Overflow was slightly faster
#
#       Sohowmuchtime Soaccount  \
# 57              NaN       Yes
# 101     60+ minutes       Yes
# 164   11-30 minutes       Yes
# 434             NaN       Yes
# 450    0-10 minutes       Yes
# 489             NaN        No
# 537    0-10 minutes       Yes
# 767   31-60 minutes       Yes
# 786   31-60 minutes       Yes
# 1228  11-30 minutes       Yes
#
#                                              Sopartfreq  \
# 57                  Less than once per month or monthly
# 101                 Less than once per month or monthly
# 164                 Less than once per month or monthly
# 434                     A few times per month or weekly
# 450                              Multiple times per day
# 489                                                 NaN
# 537   I have never participated in Q&A on Stack Over...
# 767   I have never participated in Q&A on Stack Over...
# 786   I have never participated in Q&A on Stack Over...
# 1228                Less than once per month or monthly
#
#                                                  Sojobs  \
# 57    No, I knew that Stack Overflow had a job board...
# 101                                                 Yes
# 164   No, I knew that Stack Overflow had a job board...
# 434   No, I didn't know that Stack Overflow had a jo...
# 450                                                 Yes
# 489                                                 Yes
# 537   No, I knew that Stack Overflow had a job board...
# 767                                                 Yes
# 786   No, I knew that Stack Overflow had a job board...
# 1228                                                Yes
#
#                                                Entteams           Socomm  \
# 57                  No, and I don't know what those are   No, not really
# 101   No, I've heard of them, but I am not part of a...          Neutral
# 164   No, I've heard of them, but I am not part of a...   No, not at all
# 434                 No, and I don't know what those are    Yes, somewhat
# 450   No, I've heard of them, but I am not part of a...  Yes, definitely
# 489   No, I've heard of them, but I am not part of a...          Neutral
# 537                 No, and I don't know what those are   No, not really
# 767   No, I've heard of them, but I am not part of a...          Neutral
# 786   No, I've heard of them, but I am not part of a...   No, not really
# 1228                No, and I don't know what those are    Yes, somewhat
#
#                                  Welcomechange  \
# 57     Just as welcome now as I felt last year
# 101    Just as welcome now as I felt last year
# 164    Just as welcome now as I felt last year
# 434    Just as welcome now as I felt last year
# 450   Somewhat more welcome now than last year
# 489    Just as welcome now as I felt last year
# 537    Just as welcome now as I felt last year
# 767    Just as welcome now as I felt last year
# 786    Just as welcome now as I felt last year
# 1228   Just as welcome now as I felt last year
#
#                                            Sonewcontent   Age Gender  Trans  \
# 57                                                  NaN  47.0    Man     No
# 101   Tech articles written by other developers;Indu...  37.0    Man     No
# 164                                                 NaN  30.0    Man     No
# 434   Tech articles written by other developers;Tech...  38.0    Man     No
# 450   Tech articles written by other developers;Cour...  35.0    Man     No
# 489   Tech articles written by other developers;Tech...  22.0    Man     No
# 537        Courses on technologies you're interested in  40.0    Man     No
# 767   Tech articles written by other developers;Tech...  29.0    Man     No
# 786   Tech articles written by other developers;Cour...  31.0  Woman     No
# 1228          Tech articles written by other developers  25.0    Man     No
#
#                     Sexuality  \
# 57    Straight / Heterosexual
# 101   Straight / Heterosexual
# 164   Straight / Heterosexual
# 434   Straight / Heterosexual
# 450                       NaN
# 489   Straight / Heterosexual
# 537   Straight / Heterosexual
# 767   Straight / Heterosexual
# 786                  Bisexual
# 1228  Straight / Heterosexual
#
#                                               Ethnicity Dependents  \
# 57                         White or of European descent        Yes
# 101                        White or of European descent        Yes
# 164                        White or of European descent         No
# 434                        White or of European descent        Yes
# 450                        White or of European descent         No
# 489   Hispanic or Latino/Latina;White or of European...         No
# 537                        White or of European descent        Yes
# 767                        White or of European descent         No
# 786                                         South Asian         No
# 1228                                         East Asian         No
#
#                Surveylength                  Surveyease MAIN_BRANCH
# 57                      NaN                        Easy         nan
# 101                Too long                        Easy         nan
# 164   Appropriate in length  Neither easy nor difficult         nan
# 434                Too long                        Easy         nan
# 450   Appropriate in length                        Easy         nan
# 489   Appropriate in length  Neither easy nor difficult         nan
# 537   Appropriate in length                        Easy         nan
# 767   Appropriate in length                        Easy         nan
# 786   Appropriate in length  Neither easy nor difficult         nan
# 1228  Appropriate in length  Neither easy nor difficult         nan
#
# [10 rows x 86 columns]

# %%
df['Convertedcomp'].nsmallest(10) # to see it in series
# Out:
# 278     0.0
# 291     0.0
# 719     0.0
# 1101    0.0
# 1494    0.0
# 1678    0.0
# 1774    0.0
# 2011    0.0
# 2087    0.0
# 2656    0.0
# Name: Convertedcomp, dtype: float64

# %%
df.nsmallest(10, 'Convertedcomp') #to see it in a dataframe
# Out:
#       Respondent                      Mainbranch Hobbyist  \
# 278          280  I am a developer by profession      Yes
# 291          293  I am a developer by profession      Yes
# 719          722  I am a developer by profession       No
# 1101        1105  I am a developer by profession       No
# 1494        1501  I am a developer by profession      Yes
# 1678        1685  I am a developer by profession      Yes
# 1774        1782  I am a developer by profession      Yes
# 2011        2019  I am a developer by profession       No
# 2087        2095  I am a developer by profession      Yes
# 2656        2665  I am a developer by profession      Yes
#
#                                             Opensourcer  \
# 278                             Less than once per year
# 291                             Less than once per year
# 719   Less than once a month but more than once per ...
# 1101                                              Never
# 1494                         Once a month or more often
# 1678  Less than once a month but more than once per ...
# 1774                                              Never
# 2011                         Once a month or more often
# 2087                                              Never
# 2656                                              Never
#
#                                              Opensource  \
# 278   OSS is, on average, of HIGHER quality than pro...
# 291   OSS is, on average, of HIGHER quality than pro...
# 719   The quality of OSS and closed source software ...
# 1101  OSS is, on average, of LOWER quality than prop...
# 1494  OSS is, on average, of LOWER quality than prop...
# 1678  The quality of OSS and closed source software ...
# 1774  OSS is, on average, of HIGHER quality than pro...
# 2011  The quality of OSS and closed source software ...
# 2087  The quality of OSS and closed source software ...
# 2656  The quality of OSS and closed source software ...
#
#                                              Employment  \
# 278                                  Employed full-time
# 291                                  Employed full-time
# 719                                                 NaN
# 1101  Independent contractor, freelancer, or self-em...
# 1494                                 Employed full-time
# 1678  Independent contractor, freelancer, or self-em...
# 1774                                 Employed full-time
# 2011                                 Employed full-time
# 2087                                 Employed full-time
# 2656                                 Employed full-time
#
#                                Country         Student  \
# 278                      United States              No
# 291                        Netherlands              No
# 719                        Afghanistan             NaN
# 1101                            Canada              No
# 1494                             India  Yes, full-time
# 1678                            Brazil              No
# 1774  Other Country (Not Listed Above)              No
# 2011                           Georgia              No
# 2087                             India              No
# 2656                             India              No
#
#                                           Edlevel  \
# 278      Bachelor’s degree (BA, BS, B.Eng., etc.)
# 291      Bachelor’s degree (BA, BS, B.Eng., etc.)
# 719                                           NaN
# 1101           Professional degree (JD, MD, etc.)
# 1494     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1678     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1774     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2011    Other doctoral degree (Ph.D, Ed.D., etc.)
# 2087     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2656  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                          Undergradmajor  \
# 278   Information systems, information technology, o...
# 291   Computer science, computer engineering, or sof...
# 719                                                 NaN
# 1101  A health science (ex. nursing, pharmacy, radio...
# 1494  Computer science, computer engineering, or sof...
# 1678  Computer science, computer engineering, or sof...
# 1774                      Web development or web design
# 2011                      Web development or web design
# 2087  Computer science, computer engineering, or sof...
# 2656  Computer science, computer engineering, or sof...
#
#                                                Eduother  \
# 278   Taken an online course in programming or softw...
# 291   Taken an online course in programming or softw...
# 719                                                 NaN
# 1101  Taken an online course in programming or softw...
# 1494  Received on-the-job training in software devel...
# 1678  Taken an online course in programming or softw...
# 1774  Participated in a full-time developer training...
# 2011  Taken an online course in programming or softw...
# 2087  Taken an online course in programming or softw...
# 2656  Taken an online course in programming or softw...
#
#                                                 Orgsize  \
# 278                                  20 to 99 employees
# 291                                  20 to 99 employees
# 719                                                 NaN
# 1101                                      2-9 employees
# 1494                               500 to 999 employees
# 1678  Just me - I am a freelancer, sole proprietor, ...
# 1774                                 10 to 19 employees
# 2011                                 10 to 19 employees
# 2087                           10,000 or more employees
# 2656                                 10 to 19 employees
#
#                                                 Devtype         Yearscode  \
# 278   Developer, back-end;Developer, front-end;Devel...                25
# 291   Developer, back-end;Developer, full-stack;Deve...                 9
# 719                                                 NaN  Less than 1 year
# 1101  Database administrator;Designer;Developer, bac...                 9
# 1494  Database administrator;Designer;Developer, bac...                 9
# 1678  Designer;Developer, full-stack;Developer, game...                 8
# 1774  Developer, full-stack;Product manager;Student;...                 3
# 2011  Academic researcher;Data or business analyst;D...                 5
# 2087                              Developer, full-stack                11
# 2656  Developer, back-end;Developer, full-stack;Engi...                12
#
#                 Age1stcode      Yearscodepro  \
# 278                     12                22
# 291                     14                 6
# 719   Younger than 5 years  Less than 1 year
# 1101                    50                 9
# 1494                    16                 3
# 1678                    16                 3
# 1774                    28                 2
# 2011                    18                 6
# 2087                    17                 8
# 2656                    15                 9
#
#                                Careersat                              Jobsat  \
# 278                       Very satisfied                      Very satisfied
# 291                       Very satisfied                  Slightly satisfied
# 719                       Very satisfied                      Very satisfied
# 1101                      Very satisfied                      Very satisfied
# 1494  Neither satisfied nor dissatisfied                   Very dissatisfied
# 1678  Neither satisfied nor dissatisfied  Neither satisfied nor dissatisfied
# 1774               Slightly dissatisfied                   Very dissatisfied
# 2011                      Very satisfied                                 NaN
# 2087  Neither satisfied nor dissatisfied  Neither satisfied nor dissatisfied
# 2656  Neither satisfied nor dissatisfied  Neither satisfied nor dissatisfied
#
#                   Mgridiot  Mgrmoney   Mgrwant  \
# 278                    NaN       NaN       NaN
# 291     Somewhat confident        No  Not sure
# 719                    NaN       NaN       NaN
# 1101                   NaN       NaN       NaN
# 1494  Not at all confident  Not sure       Yes
# 1678                   NaN       NaN       NaN
# 1774  Not at all confident       Yes  Not sure
# 2011                   NaN       NaN       NaN
# 2087    Somewhat confident       Yes        No
# 2656    Somewhat confident        No  Not sure
#
#                                                 Jobseek  \
# 278        I am not interested in new job opportunities
# 291   I’m not actively looking, but I am open to new...
# 719        I am not interested in new job opportunities
# 1101       I am not interested in new job opportunities
# 1494                    I am actively looking for a job
# 1678  I’m not actively looking, but I am open to new...
# 1774                    I am actively looking for a job
# 2011       I am not interested in new job opportunities
# 2087  I’m not actively looking, but I am open to new...
# 2656  I’m not actively looking, but I am open to new...
#
#                                            Lasthiredate  \
# 278                                       3-4 years ago
# 291                                       3-4 years ago
# 719   NA - I am an independent contractor or self em...
# 1101  NA - I am an independent contractor or self em...
# 1494                                      1-2 years ago
# 1678                               Less than a year ago
# 1774                                      1-2 years ago
# 2011                                      3-4 years ago
# 2087                                      1-2 years ago
# 2656                               Less than a year ago
#
#                                                 Lastint Fizzbuzz  \
# 278   Interview with people in senior / management r...      Yes
# 291   Complete a take-home project;Interview with pe...      Yes
# 719                                                 NaN       No
# 1101                                                NaN       No
# 1494                       Complete a take-home project      Yes
# 1678  Interview with people in peer roles;Interview ...       No
# 1774  Complete a take-home project;Solve a brain-tea...       No
# 2011  Write any code;Write code by hand (e.g., on a ...      Yes
# 2087  Write any code;Write code by hand (e.g., on a ...       No
# 2656  Write code by hand (e.g., on a whiteboard);Com...      Yes
#
#                                              Jobfactors  \
# 278   Financial performance or funding status of the...
# 291   Financial performance or funding status of the...
# 719                                                 NaN
# 1101                                                NaN
# 1494  Remote work options;Opportunities for professi...
# 1678  Specific department or team I'd be working on;...
# 1774  Financial performance or funding status of the...
# 2011  Languages, frameworks, and other technologies ...
# 2087  Financial performance or funding status of the...
# 2656  Financial performance or funding status of the...
#
#                                            Resumeupdate Currencysymbol  \
# 278                    I was preparing for a job search            USD
# 291                    I was preparing for a job search            EUR
# 719   I heard about a job opportunity (from a recrui...            AFN
# 1101                                                NaN            CAD
# 1494                   I was preparing for a job search            INR
# 1678                   I was preparing for a job search            BRL
# 1774  I had a negative experience or interaction at ...            MKD
# 2011                   I was preparing for a job search            USD
# 2087                   I was preparing for a job search            INR
# 2656                   I was preparing for a job search            INR
#
#               Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 278   United States dollar        0.0   Yearly            0.0         50.0
# 291          European Euro        0.0  Monthly            0.0         40.0
# 719         Afghan afghani        1.0   Yearly            0.0          1.0
# 1101       Canadian dollar        0.0   Yearly            0.0         70.0
# 1494          Indian rupee        4.0   Yearly            0.0         50.0
# 1678        Brazilian real        0.0  Monthly            0.0         40.0
# 1774      Macedonian denar       18.0  Monthly            0.0          NaN
# 2011  United States dollar        0.0   Yearly            0.0         24.0
# 2087          Indian rupee        0.0  Monthly            0.0         40.0
# 2656          Indian rupee        0.0   Yearly            0.0         50.0
#
#                                                Workplan  \
# 278   There is a schedule and/or spec (made by me or...
# 291   There is a schedule and/or spec (made by me or...
# 719                                                 NaN
# 1101  There's no schedule or spec; I work on what se...
# 1494  There's no schedule or spec; I work on what se...
# 1678  There is a schedule and/or spec (made by me or...
# 1774  There's no schedule or spec; I work on what se...
# 2011  There is a schedule and/or spec (made by me or...
# 2087  There is a schedule and/or spec (made by me or...
# 2656  There's no schedule or spec; I work on what se...
#
#                                           Workchallenge  \
# 278   Distracting work environment;Meetings;Not enou...
# 291   Lack of support from management;Meetings;Toxic...
# 719                                                 NaN
# 1101               Inadequate access to necessary tools
# 1494  Distracting work environment;Lack of support f...
# 1678  Distracting work environment;Meetings;Toxic wo...
# 1774  Lack of support from management;Not enough peo...
# 2011  Distracting work environment;Inadequate access...
# 2087                                                NaN
# 2656  Distracting work environment;Meetings;Not enou...
#
#                                              Workremote  \
# 278   Less than half the time, but at least one day ...
# 291                               A few days each month
# 719                    Less than once per month / Never
# 1101                   Less than once per month / Never
# 1494                                   It's complicated
# 1678  All or almost all the time (I'm full-time remote)
# 1774                   Less than once per month / Never
# 2011  All or almost all the time (I'm full-time remote)
# 2087                   Less than once per month / Never
# 2656                              A few days each month
#
#                                              Workloc                  Impsyn  \
# 278                                           Office       Far above average
# 291                                           Office  A little above average
# 719   Other place, such as a coworking space or cafe       Far above average
# 1101                                            Home       Far below average
# 1494                                          Office                 Average
# 1678                                            Home                 Average
# 1774  Other place, such as a coworking space or cafe  A little below average
# 2011  Other place, such as a coworking space or cafe                 Average
# 2087                                          Office       Far above average
# 2656                                          Office  A little above average
#
#                                       Coderev  Coderevhrs  \
# 278   Yes, because I see value in code review         8.0
# 291   Yes, because I see value in code review         2.0
# 719   Yes, because I see value in code review         1.0
# 1101  Yes, because I see value in code review        30.0
# 1494  Yes, because I see value in code review        12.0
# 1678  Yes, because I see value in code review         6.0
# 1774  Yes, because I see value in code review         NaN
# 2011         Yes, because I was told to do so         1.0
# 2087  Yes, because I see value in code review         5.0
# 2656  Yes, because I see value in code review        10.0
#
#                                               Unittests  \
# 278                       Yes, it's part of our process
# 291                       Yes, it's part of our process
# 719                           No, and I'm glad we don't
# 1101                                                NaN
# 1494                      Yes, it's part of our process
# 1678                                                NaN
# 1774  Yes, it's not part of our process but the deve...
# 2011  Yes, it's not part of our process but the deve...
# 2087                      Yes, it's part of our process
# 2656                          No, but I think we should
#
#                                             Purchasehow  ...  \
# 278   Developers typically have the most influence o...  ...
# 291   Developers and management have nearly equal in...  ...
# 719                                                 NaN  ...
# 1101                                                NaN  ...
# 1494  The CTO, CIO, or other management purchase new...  ...
# 1678                                                NaN  ...
# 1774  The CTO, CIO, or other management purchase new...  ...
# 2011                                           Not sure  ...
# 2087  Developers and management have nearly equal in...  ...
# 2656  Developers and management have nearly equal in...  ...
#
#                                  Languagedesirenextyear  \
# 278                                       C#;TypeScript
# 291                                Go;Kotlin;TypeScript
# 719                                                 NaN
# 1101               C;HTML/CSS;JavaScript;PHP;Python;SQL
# 1494           Kotlin;Objective-C;PHP;Swift;WebAssembly
# 1678                                   C#;Kotlin;Python
# 1774                Assembly;C#;HTML/CSS;JavaScript;SQL
# 2011  Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 2087  Elixir;Erlang;Java;JavaScript;PHP;Python;R;Rub...
# 2656                                 Clojure;Go;R;Scala
#
#                                      Databaseworkedwith  \
# 278                                Microsoft SQL Server
# 291      Firebase;MongoDB;MySQL;Oracle;PostgreSQL;Redis
# 719                                                 NaN
# 1101                                              MySQL
# 1494                  Firebase;Oracle;PostgreSQL;SQLite
# 1678               Cassandra;MariaDB;MongoDB;PostgreSQL
# 1774        MariaDB;MongoDB;Microsoft SQL Server;SQLite
# 2011  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 2087  MariaDB;MongoDB;Microsoft SQL Server;MySQL;Pos...
# 2656  Cassandra;Couchbase;Elasticsearch;MongoDB;MySQ...
#
#                                  Databasedesirenextyear  \
# 278                                Microsoft SQL Server
# 291                              Firebase;MongoDB;Redis
# 719                                                 NaN
# 1101                           MariaDB;MySQL;PostgreSQL
# 1494               Cassandra;Microsoft SQL Server;MySQL
# 1678               Cassandra;MariaDB;MongoDB;PostgreSQL
# 1774               MariaDB;MongoDB;Microsoft SQL Server
# 2011           Oracle;PostgreSQL;Redis;SQLite;Other(s):
# 2087  Cassandra;Couchbase;MariaDB;MongoDB;MySQL;Post...
# 2656  Cassandra;Couchbase;Elasticsearch;MongoDB;MySQ...
#
#                                      Platformworkedwith  \
# 278                                             Windows
# 291          Docker;Heroku;Linux;Raspberry Pi;WordPress
# 719                                                 NaN
# 1101                                    MacOS;WordPress
# 1494  Android;Google Cloud Platform;Linux;Slack;Windows
# 1678                            Docker;Kubernetes;MacOS
# 1774                                    Slack;Other(s):
# 2011                                                NaN
# 2087                            AWS;Linux;MacOS;Windows
# 2656                                        Linux;Slack
#
#                                  Platformdesirenextyear  \
# 278                                             Windows
# 291   Android;Arduino;AWS;Kubernetes;Linux;Microsoft...
# 719                                                 NaN
# 1101                                    MacOS;WordPress
# 1494                                     AWS;Docker;iOS
# 1678                              Android;Linux;Windows
# 1774              Android;Microsoft Azure;Slack;Windows
# 2011  Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 2087  Arduino;AWS;Docker;Kubernetes;Linux;MacOS;Micr...
# 2656                    Docker;Linux;Raspberry Pi;Slack
#
#                                   Webframeworkedwith  \
# 278                       Angular/Angular.js;ASP.NET
# 291                                           Spring
# 719                                              NaN
# 1101                                             NaN
# 1494                                         ASP.NET
# 1678                                         Laravel
# 1774               Angular/Angular.js;ASP.NET;jQuery
# 2011                                             NaN
# 2087  Angular/Angular.js;jQuery;Ruby on Rails;Spring
# 2656                 Angular/Angular.js;Django;Flask
#
#                                  Webframedesirenextyear  \
# 278                          Angular/Angular.js;ASP.NET
# 291                                             Express
# 719                                                 NaN
# 1101                                                NaN
# 1494  Angular/Angular.js;Django;jQuery;React.js;Ruby...
# 1678                        Django;Flask;Laravel;Vue.js
# 1774                  Angular/Angular.js;ASP.NET;jQuery
# 2011  Angular/Angular.js;ASP.NET;Django;Drupal;Expre...
# 2087  Angular/Angular.js;jQuery;React.js;Ruby on Rai...
# 2656                                       Django;Flask
#
#                                      Misctechworkedwith  \
# 278                                                .NET
# 291                                             Node.js
# 719                                                 NaN
# 1101                                                NaN
# 1494                                     .NET;.NET Core
# 1678                                            Node.js
# 1774                             .NET;.NET Core;Node.js
# 2011  Ansible;Apache Spark;Chef;Cordova;CryEngine;Fl...
# 2087                                    Cordova;Node.js
# 2656                        Apache Spark;Node.js;Pandas
#
#                                  Misctechdesirenextyear  \
# 278                                                .NET
# 291                                                 NaN
# 719                                                 NaN
# 1101                                            Node.js
# 1494  Ansible;Apache Spark;Cordova;Hadoop;Node.js;Re...
# 1678                    .NET;Node.js;Unity 3D;Other(s):
# 1774                             .NET;.NET Core;Node.js
# 2011  Hadoop;.NET;.NET Core;Node.js;Pandas;Puppet;Re...
# 2087     Apache Spark;Cordova;Hadoop;Node.js;TensorFlow
# 2656  Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
#
#                                              Devenviron        Opsys  \
# 278          Notepad++;Visual Studio;Visual Studio Code      Windows
# 291                    Android Studio;Atom;IntelliJ;Vim  Linux-based
# 719                                                 NaN          NaN
# 1101                         Eclipse;Visual Studio Code        MacOS
# 1494  Android Studio;Atom;IntelliJ;Notepad++;Sublime...      Windows
# 1678  Android Studio;PHPStorm;PyCharm;Visual Studio ...      Windows
# 1774         Notepad++;Visual Studio;Visual Studio Code      Windows
# 2011                                     Android Studio          BSD
# 2087  Atom;Eclipse;IntelliJ;Notepad++;Sublime Text;V...  Linux-based
# 2656  IPython / Jupyter;RStudio;Sublime Text;Vim;Vis...        MacOS
#
#                                              Containers  \
# 278                             I do not use containers
# 291                      Development;Testing;Production
# 719                                                 NaN
# 1101                            I do not use containers
# 1494                             Development;Production
# 1678                                        Development
# 1774                            I do not use containers
# 2011  Development;Testing;Production;Outside of work...
# 2087                            I do not use containers
# 2656                     Development;Testing;Production
#
#                                 Blockchainorg  \
# 278   Non-currency applications of blockchain
# 291   Non-currency applications of blockchain
# 719                                       NaN
# 1101                                      NaN
# 1494                               Not at all
# 1678                                      NaN
# 1774                               Not at all
# 2011                                      NaN
# 2087  Non-currency applications of blockchain
# 2656                                      NaN
#
#                                            Blockchainis Betterlife  Itperson  \
# 278                                                 NaN         No      SIGH
# 291   Useful for immutable record keeping outside of...        Yes       Yes
# 719                                                 NaN         No      SIGH
# 1101  Useful for immutable record keeping outside of...        Yes       Yes
# 1494  Useful across many domains and could change ma...         No       Yes
# 1678  Useful across many domains and could change ma...         No       Yes
# 1774                                                NaN         No       Yes
# 2011  Useful for decentralized currency (i.e., Bitcoin)         No  Also Yes
# 2087  Useful across many domains and could change ma...        Yes       Yes
# 2656                                                NaN        NaN       Yes
#
#       Offon               Socialmedia              Extraversion Screenname  \
# 278     Yes                  Facebook  In real life (in person)   Username
# 291     Yes                 Instagram  In real life (in person)   Username
# 719   What?                       NaN                   Neither        NaN
# 1101    Yes  I don't use social media  In real life (in person)   Username
# 1494  What?                  Facebook                   Neither      Login
# 1678    Yes                  WhatsApp  In real life (in person)        NaN
# 1774    Yes                  Facebook  In real life (in person)      Login
# 2011    Yes                  Facebook                    Online     UserID
# 2087  What?                  WhatsApp                   Neither        NaN
# 2656    Yes                  WhatsApp                    Online   Username
#
#      Sovisit1st             Sovisitfreq  \
# 278        2008    A few times per week
# 291        2011    A few times per week
# 719        2008  Multiple times per day
# 1101       2008  Multiple times per day
# 1494       2017  Multiple times per day
# 1678       2010    A few times per week
# 1774       2013    A few times per week
# 2011       2019  Multiple times per day
# 2087       2011   Daily or almost daily
# 2656       2008   Daily or almost daily
#
#                                               Sovisitto  \
# 278   Find answers to specific questions;Learn how t...
# 291                  Find answers to specific questions
# 719                                                 NaN
# 1101                 Find answers to specific questions
# 1494  Find answers to specific questions;Contribute ...
# 1678                 Find answers to specific questions
# 1774  Find answers to specific questions;Learn how t...
# 2011  Find answers to specific questions;Learn how t...
# 2087  Find answers to specific questions;Contribute ...
# 2656  Find answers to specific questions;Learn how t...
#
#                      Sofindanswer                         Sotimesaved  \
# 278            1-2 times per week      Stack Overflow was much faster
# 291       Less than once per week      Stack Overflow was much faster
# 719   More than 10 times per week  The other resource was much faster
# 1101           1-2 times per week  The other resource was much faster
# 1494  More than 10 times per week  Stack Overflow was slightly faster
# 1678           1-2 times per week  Stack Overflow was slightly faster
# 1774           3-5 times per week            They were about the same
# 2011          6-10 times per week  Stack Overflow was slightly faster
# 2087      Less than once per week  Stack Overflow was slightly faster
# 2656           3-5 times per week            They were about the same
#
#       Sohowmuchtime                  Soaccount  \
# 278   11-30 minutes                        Yes
# 291   11-30 minutes                        Yes
# 719     60+ minutes  Not sure / can't remember
# 1101   0-10 minutes                        Yes
# 1494  31-60 minutes                        Yes
# 1678  11-30 minutes                        Yes
# 1774            NaN                         No
# 2011    60+ minutes  Not sure / can't remember
# 2087  11-30 minutes                        Yes
# 2656            NaN                        Yes
#
#                                              Sopartfreq  \
# 278                 Less than once per month or monthly
# 291                                A few times per week
# 719                                                 NaN
# 1101  I have never participated in Q&A on Stack Over...
# 1494                Less than once per month or monthly
# 1678                Less than once per month or monthly
# 1774                                                NaN
# 2011                                                NaN
# 2087                               A few times per week
# 2656                Less than once per month or monthly
#
#                                                  Sojobs  \
# 278                                                 Yes
# 291                                                 Yes
# 719                                                 Yes
# 1101  No, I knew that Stack Overflow had a job board...
# 1494                                                Yes
# 1678                                                Yes
# 1774  No, I knew that Stack Overflow had a job board...
# 2011  No, I didn't know that Stack Overflow had a jo...
# 2087                                                Yes
# 2656                                                Yes
#
#                                                Entteams           Socomm  \
# 278                 No, and I don't know what those are          Neutral
# 291   No, I've heard of them, but I am not part of a...    Yes, somewhat
# 719                                                 Yes         Not sure
# 1101  No, I've heard of them, but I am not part of a...   No, not at all
# 1494  No, I've heard of them, but I am not part of a...  Yes, definitely
# 1678                No, and I don't know what those are   No, not really
# 1774                No, and I don't know what those are   No, not really
# 2011  No, I've heard of them, but I am not part of a...          Neutral
# 2087                No, and I don't know what those are    Yes, somewhat
# 2656                No, and I don't know what those are    Yes, somewhat
#
#                                           Welcomechange  \
# 278   Not applicable - I did not use Stack Overflow ...
# 291             Just as welcome now as I felt last year
# 719   Not applicable - I did not use Stack Overflow ...
# 1101            Just as welcome now as I felt last year
# 1494              A lot more welcome now than last year
# 1678            Just as welcome now as I felt last year
# 1774           Somewhat more welcome now than last year
# 2011              A lot more welcome now than last year
# 2087            Just as welcome now as I felt last year
# 2656            Just as welcome now as I felt last year
#
#                                            Sonewcontent   Age Gender  Trans  \
# 278                                                 NaN  47.0    Man     No
# 291   Tech articles written by other developers;Indu...  31.0    Man     No
# 719                                                 NaN   1.0    NaN    NaN
# 1101       Courses on technologies you're interested in  65.0    Man     No
# 1494  Tech articles written by other developers;Indu...  24.0  Woman     No
# 1678  Tech articles written by other developers;Indu...  29.0    Man     No
# 1774  Tech articles written by other developers;Indu...   NaN    Man     No
# 2011  Tech articles written by other developers;Indu...   NaN    Man     No
# 2087                                                NaN  28.0    Man     No
# 2656  Tech articles written by other developers;Indu...  34.0    Man     No
#
#                     Sexuality                                 Ethnicity  \
# 278   Straight / Heterosexual              White or of European descent
# 291   Straight / Heterosexual              White or of European descent
# 719                       NaN                                       NaN
# 1101  Straight / Heterosexual              White or of European descent
# 1494                      NaN                                       NaN
# 1678  Straight / Heterosexual  White or of European descent;Multiracial
# 1774  Straight / Heterosexual              White or of European descent
# 2011                      NaN               Black or of African descent
# 2087  Straight / Heterosexual                                       NaN
# 2656  Straight / Heterosexual                                       NaN
#
#      Dependents           Surveylength                  Surveyease MAIN_BRANCH
# 278         Yes  Appropriate in length                        Easy         nan
# 291          No               Too long                        Easy         nan
# 719         NaN               Too long                   Difficult         nan
# 1101        Yes  Appropriate in length                        Easy         nan
# 1494        Yes               Too long                   Difficult         nan
# 1678         No  Appropriate in length  Neither easy nor difficult         nan
# 1774         No               Too long                        Easy         nan
# 2011        Yes               Too long                        Easy         nan
# 2087        Yes               Too long                   Difficult         nan
# 2656        Yes               Too long                        Easy         nan
#
# [10 rows x 86 columns]

# %%
# GROUPING AND AGGREGATION
# the describe method can give us a brief overview of what we want to see
df.describe()
# Out:
#          Respondent     Comptotal  Convertedcomp   Workweekhrs    Coderevhrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
# median value for a column
df['Convertedcomp'].median()
# Out:
# 57287.0

# %%
# median value for multiple column
df[['Convertedcomp','Age']].median()
# Out:
# Convertedcomp    57287.0
# Age                 29.0
# dtype: float64

# %%
df['Convertedcomp'].count() # this method returns the number of non-null values in a series or Datafram
# Out:
# 55823

# %%
df['Convertedcomp'].value_counts() # used to count the frequency of unique values in a panda series
# Out:
# Convertedcomp
# 2000000.0    709
# 1000000.0    558
# 120000.0     502
# 100000.0     480
# 150000.0     434
#             ...
# 411096.0       1
# 261228.0       1
# 82322.0        1
# 66424.0        1
# 588012.0       1
# Name: count, Length: 9162, dtype: int64

# %%
df
# Out:
#        Respondent                                         Mainbranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              Opensourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               Opensource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  Edlevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           Undergradmajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 Eduother  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         Orgsize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  Devtype Yearscode Age1stcode  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            Yearscodepro           Careersat                 Jobsat  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    Mgridiot  Mgrmoney   Mgrwant  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  Jobseek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                Lasthiredate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  Lastint Fizzbuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               Jobfactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             Resumeupdate Currencysymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                Currencydesc  Comptotal Compfreq  Convertedcomp  Workweekhrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 Workplan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            Workchallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              Workremote Workloc                  Impsyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        Coderev  Coderevhrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            Unittests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              Purchasehow  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                               Not sure  ...
# 3      Developers typically have the most influence o...  ...
# 4                                               Not sure  ...
# ...                                                  ...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882                                                NaN  ...
#
#                                   Languagedesirenextyear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      Databaseworkedwith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   Databasedesirenextyear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       Platformworkedwith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   Platformdesirenextyear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 Webframeworkedwith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              Webframedesirenextyear      Misctechworkedwith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          Misctechdesirenextyear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               Devenviron        Opsys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers Blockchainorg  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             Blockchainis Betterlife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        Itperson  Offon Socialmedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    Extraversion Screenname        Sovisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            Sovisitfreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                Sovisitto  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       Sofindanswer                         Sotimesaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        Sohowmuchtime Soaccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               Sopartfreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   Sojobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 Entteams           Socomm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   Welcomechange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             Sonewcontent   Age Gender  Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man     No
# 1      Tech articles written by other developers;Indu...  19.0    Man     No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man     No
# 3      Tech articles written by other developers;Indu...  22.0    Man     No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man     No
# ...                                                  ...   ...    ...    ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man     No
# 88879                                                NaN   NaN    NaN    NaN
# 88880                                                NaN   NaN    NaN    NaN
# 88881                                                NaN   NaN    NaN    NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man     No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 Surveylength                  Surveyease     MAIN_BRANCH
# 0      Appropriate in length  Neither easy nor difficult             nan
# 1      Appropriate in length  Neither easy nor difficult             nan
# 2      Appropriate in length  Neither easy nor difficult  I am a student
# 3      Appropriate in length                        Easy             nan
# 4      Appropriate in length                        Easy             nan
# ...                      ...                         ...             ...
# 88878  Appropriate in length                        Easy             nan
# 88879                    NaN                         NaN             nan
# 88880                    NaN                         NaN             nan
# 88881                    NaN                         NaN             nan
# 88882  Appropriate in length                        Easy             nan
#
# [88883 rows x 86 columns]

# %%
df['Socialmedia'].value_counts()
# Out:
# Socialmedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
df['Socialmedia'].value_counts(normalize=True)
# Out:
# Socialmedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
# Grouping - Groupby

# we grouping by country. So lets bring the column out first
df['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Chad')
# Out:
#        Respondent                      Mainbranch Hobbyist Opensourcer  \
# 80878       81382  I am a developer by profession       No       Never
#
#                                               Opensource  \
# 80878  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment Country Student  \
# 80878  Independent contractor, freelancer, or self-em...    Chad      No
#
#                                         Edlevel  \
# 80878  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                           Undergradmajor  \
# 80878  Information systems, information technology, o...
#
#                                                 Eduother  \
# 80878  Taken an online course in programming or softw...
#
#                         Orgsize  \
# 80878  10,000 or more employees
#
#                                                  Devtype Yearscode Age1stcode  \
# 80878  Database administrator;Developer, back-end;Dev...         6         21
#
#       Yearscodepro           Careersat                 Jobsat Mgridiot  \
# 80878            3  Slightly satisfied  Slightly dissatisfied      NaN
#
#       Mgrmoney Mgrwant                                            Jobseek  \
# 80878      NaN     NaN  I’m not actively looking, but I am open to new...
#
#         Lasthiredate                              Lastint Fizzbuzz  \
# 80878  1-2 years ago  Interview with people in peer roles       No
#
#                                               Jobfactors  \
# 80878  Office environment or company culture;Opportun...
#
#                                             Resumeupdate Currencysymbol  \
# 80878  I heard about a job opportunity (from a recrui...            XAF
#
#                     Currencydesc  Comptotal Compfreq  Convertedcomp  \
# 80878  Central African CFA franc   300000.0  Monthly         6288.0
#
#        Workweekhrs                                           Workplan  \
# 80878         40.0  There's no schedule or spec; I work on what se...
#
#                                            Workchallenge  \
# 80878  Inadequate access to necessary tools;Toxic wor...
#
#                              Workremote Workloc                  Impsyn  \
# 80878  Less than once per month / Never    Home  A little below average
#
#       Coderev  Coderevhrs Unittests Purchasehow  ...  \
# 80878      No         NaN       NaN         NaN  ...
#
#                                   Languagedesirenextyear Databaseworkedwith  \
# 80878  HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...              MySQL
#
#                        Databasedesirenextyear       Platformworkedwith  \
# 80878  MongoDB;MySQL;Oracle;PostgreSQL;SQLite  Android;Linux;WordPress
#
#                                   Platformdesirenextyear Webframeworkedwith  \
# 80878  Android;Arduino;Docker;iOS;Linux;MacOS;Raspber...             jQuery
#
#                         Webframedesirenextyear Misctechworkedwith  \
# 80878  Angular/Angular.js;Drupal;jQuery;Spring                NaN
#
#                                   Misctechdesirenextyear  \
# 80878  Apache Spark;Cordova;Hadoop;Node.js;Unity 3D;U...
#
#                                      Devenviron        Opsys  \
# 80878  Android Studio;Atom;Eclipse;PHPStorm;Vim  Linux-based
#
#                     Containers Blockchainorg Blockchainis Betterlife Itperson  \
# 80878  I do not use containers           NaN          NaN        Yes     SIGH
#
#        Offon               Socialmedia              Extraversion Screenname  \
# 80878  What?  I don't use social media  In real life (in person)   Username
#
#       Sovisit1st                      Sovisitfreq  \
# 80878       2016  A few times per month or weekly
#
#                                                Sovisitto  \
# 80878  Find answers to specific questions;Get a sense...
#
#                   Sofindanswer Sotimesaved Sohowmuchtime Soaccount  \
# 80878  Less than once per week         NaN   60+ minutes       Yes
#
#                                 Sopartfreq Sojobs  \
# 80878  Less than once per month or monthly    Yes
#
#                                   Entteams          Socomm  \
# 80878  No, and I don't know what those are  No, not really
#
#                                   Welcomechange  \
# 80878  Somewhat less welcome now than last year
#
#                                             Sonewcontent   Age Gender  Trans  \
# 80878  Tech articles written by other developers;Indu...  27.0    Man     No
#
#       Sexuality                    Ethnicity Dependents  \
# 80878       NaN  Black or of African descent        Yes
#
#                 Surveylength                  Surveyease MAIN_BRANCH
# 80878  Appropriate in length  Neither easy nor difficult         nan
#
# [1 rows x 86 columns]

# %%
filt = df['Country'] == 'India'
df.loc[filt]["Socialmedia"].value_counts()
# Out:
# Socialmedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['Socialmedia'].value_counts()
# Out:
# Country      Socialmedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              LinkedIn                     2
#              Instagram                    2
#              Reddit                       1
# Name: count, Length: 1220, dtype: int64

# %%
country_grp['Socialmedia'].value_counts().head(50)
# Out:
# Country              Socialmedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# Algeria              YouTube                      42
#                      Facebook                     41
#                      Twitter                      14
#                      LinkedIn                      9
#                      Instagram                     7
#                      I don't use social media      7
#                      Reddit                        2
#                      WhatsApp                      2
# Andorra              Facebook                      2
#                      I don't use social media      2
#                      YouTube                       1
#                      Reddit                        1
#                      Snapchat                      1
# Angola               Twitter                       2
#                      YouTube                       1
#                      Facebook                      1
# Antigua and Barbuda  YouTube                       2
#                      Facebook                      1
#                      Instagram                     1
#                      Twitter                       1
#                      VK ВКонта́кте                 1
# Argentina            WhatsApp                    202
#                      Twitter                      80
#                      YouTube                      62
#                      Instagram                    53
#                      Reddit                       50
#                      Facebook                     45
#                      I don't use social media     22
#                      LinkedIn                     16
# Armenia              Facebook                     38
#                      YouTube                      23
#                      LinkedIn                      5
#                      Instagram                     3
# Name: count, dtype: int64

# %%
country_grp['Socialmedia'].value_counts().loc['India']
# Out:
# Socialmedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
k = df.groupby('Country')['Socialmedia']
k.value_counts().loc['United States']
# Out:
# Socialmedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: count, dtype: int64

# %%
df.groupby('Country')['Convertedcomp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: Convertedcomp, Length: 179, dtype: float64

# %%
df.groupby('Country')['Convertedcomp'].median().loc['Germany']
# Out:
# 63016.0

# %%
df.groupby('Country')['Convertedcomp'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
df.groupby('Country')['Convertedcomp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]["Languageworkedwith"].str.contains('Python').sum()
# Out:
# 3105

# %% [markdown]
# # Cleaning Data- Casting Datatypes and Handling Missing Values

# %%
import numpy as np

# %%
# creating a dataframe
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
# droping missing values
df.dropna()
# by default, what it actually did was...
#  df.dropna(axis='index', how='any')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df = pd.DataFrame(people)

df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)

df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
# filling missing values randomly
df.fillna(0) # dont forget to use inplace = True
# i dont want to use it right now because i still want to use the dataset
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df.dtypes
# from the result, we see that the age column is a string instead of an integer. So lets convert it to an int
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
#### df['age'] = df['age'].astype(int) # converting to an integer datatype
'''Since the age column has missing values, to convert it to an integer will throw an error. 
So we either fill the missing values or we convert to a float instead.
But in this case i'm going to be converting to a float'''

df['age'] = df['age'].astype(float)

# %%
# so lets check if it changed
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
# now lets take the average/mean of the age column

df['age'].mean()

#We cannont take the average/mean of a string datatype.
#Technically, it doesnt make sense.
#So we convert to an int or a float.
# Out:
# 46.75

# %% [markdown]
# # Date and Time Series
